# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#데이터-불러오기" data-toc-modified-id="데이터-불러오기-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>데이터 불러오기</a></span></li><li><span><a href="#결측값-확인" data-toc-modified-id="결측값-확인-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>결측값 확인</a></span></li><li><span><a href="#price-/-pre_price-변수" data-toc-modified-id="price-/-pre_price-변수-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>price / pre_price 변수</a></span><ul class="toc-item"><li><ul class="toc-item"><li><ul class="toc-item"><li><span><a href="#price-/-pre_price-의-분석을-위해-,-제거" data-toc-modified-id="price-/-pre_price-의-분석을-위해-,-제거-3.0.0.1"><span class="toc-item-num">3.0.0.1&nbsp;&nbsp;</span>price / pre_price 의 분석을 위해 , 제거</a></span></li></ul></li></ul></li></ul></li><li><span><a href="#brand_name-encoded-(-brand_-name-텍스트를-숫자로-)" data-toc-modified-id="brand_name-encoded-(-brand_-name-텍스트를-숫자로-)-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>brand_name encoded ( brand_ name 텍스트를 숫자로 )</a></span><ul class="toc-item"><li><ul class="toc-item"><li><ul class="toc-item"><li><span><a href="#각-카테고리를-다른-정수값으로-매핑해주는-factorize()-매서드-사용" data-toc-modified-id="각-카테고리를-다른-정수값으로-매핑해주는-factorize()-매서드-사용-4.0.0.1"><span class="toc-item-num">4.0.0.1&nbsp;&nbsp;</span>각 카테고리를 다른 정수값으로 매핑해주는 factorize() 매서드 사용</a></span></li><li><span><a href="#새로운-변수-brand_name2" data-toc-modified-id="새로운-변수-brand_name2-4.0.0.2"><span class="toc-item-num">4.0.0.2&nbsp;&nbsp;</span>새로운 변수 brand_name2</a></span></li></ul></li></ul></li></ul></li><li><span><a href="#index-다시-지정" data-toc-modified-id="index-다시-지정-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>index 다시 지정</a></span></li><li><span><a href="#brand_name-워드클라우드" data-toc-modified-id="brand_name-워드클라우드-6"><span class="toc-item-num">6&nbsp;&nbsp;</span>brand_name 워드클라우드</a></span></li><li><span><a href="#상품별-그룹화" data-toc-modified-id="상품별-그룹화-7"><span class="toc-item-num">7&nbsp;&nbsp;</span>상품별 그룹화</a></span><ul class="toc-item"><li><ul class="toc-item"><li><span><a href="#스킨케어" data-toc-modified-id="스킨케어-7.0.1"><span class="toc-item-num">7.0.1&nbsp;&nbsp;</span>스킨케어</a></span></li></ul></li><li><span><a href="#바디케어" data-toc-modified-id="바디케어-7.1"><span class="toc-item-num">7.1&nbsp;&nbsp;</span>바디케어</a></span></li><li><span><a href="#헤어케어" data-toc-modified-id="헤어케어-7.2"><span class="toc-item-num">7.2&nbsp;&nbsp;</span>헤어케어</a></span></li><li><span><a href="#메이크업" data-toc-modified-id="메이크업-7.3"><span class="toc-item-num">7.3&nbsp;&nbsp;</span>메이크업</a></span></li><li><span><a href="#향수-&amp;-탈취" data-toc-modified-id="향수-&amp;-탈취-7.4"><span class="toc-item-num">7.4&nbsp;&nbsp;</span>향수 &amp; 탈취</a></span></li><li><span><a href="#쉐이빙-&amp;-잡화" data-toc-modified-id="쉐이빙-&amp;-잡화-7.5"><span class="toc-item-num">7.5&nbsp;&nbsp;</span>쉐이빙 &amp; 잡화</a></span></li></ul></li><li><span><a href="#[-category-별-항목그룹에-포함되지않는-제품들-]" data-toc-modified-id="[-category-별-항목그룹에-포함되지않는-제품들-]-8"><span class="toc-item-num">8&nbsp;&nbsp;</span>[ category 별 항목그룹에 포함되지않는 제품들 ]</a></span><ul class="toc-item"><li><span><a href="#스킨케어-index-정리" data-toc-modified-id="스킨케어-index-정리-8.1"><span class="toc-item-num">8.1&nbsp;&nbsp;</span>스킨케어 index 정리</a></span></li><li><span><a href="#바디케어-index-정리" data-toc-modified-id="바디케어-index-정리-8.2"><span class="toc-item-num">8.2&nbsp;&nbsp;</span>바디케어 index 정리</a></span></li><li><span><a href="#헤어케어-index-정리" data-toc-modified-id="헤어케어-index-정리-8.3"><span class="toc-item-num">8.3&nbsp;&nbsp;</span>헤어케어 index 정리</a></span></li><li><span><a href="#메이크업-index-정리" data-toc-modified-id="메이크업-index-정리-8.4"><span class="toc-item-num">8.4&nbsp;&nbsp;</span>메이크업 index 정리</a></span></li><li><span><a href="#쉐이빙-&amp;-잡화-index-정리" data-toc-modified-id="쉐이빙-&amp;-잡화-index-정리-8.5"><span class="toc-item-num">8.5&nbsp;&nbsp;</span>쉐이빙 &amp; 잡화 index 정리</a></span></li></ul></li></ul></div>

# %%
import pandas as pd
import warnings
warnings.filterwarnings('ignore')
import numpy as np
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = 'all'
from warnings import simplefilter
import os
from sklearn.preprocessing import OneHotEncoder
from sklearn.base import BaseEstimator, TransformerMixin
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = 'all'

simplefilter(action='ignore', category=FutureWarning)

# %% [markdown]
# # 데이터 불러오기

# %%
olive_man=pd.read_csv("C:/Users/haneul/Desktop/DNA/프로젝트1-올리브영/OliveYoung-for-Man/dataset/oliveyoung_product_info.csv")
olive_man.head(5)
# Out:
#   category    brand_name                             product_name   price  \
# 0     스킨케어  보타닉힐보 아이디얼포맨                             퍼펙트 올인원 기획세트  21,900
# 1     스킨케어          우르오스             우르오스 올인원 스킨밀크&스킨로션 200ml 택 1  25,200
# 2     스킨케어            불독              불독 오리지널 수분크림 100ml+30ml 기획팩  16,000
# 3     스킨케어          우르오스                          우르오스 스킨밀크 200ml  25,200
# 4     스킨케어           XTM  XTM 올인원 엑스퍼트 200mL 대용량기획(멀티 토너 50mL 증정)  23,200
#
#   pre_price  sales_rank
# 0    28,000           1
# 1    29,700           2
# 2    20,000           3
# 3    29,700           4
# 4    29,000           5

# %%
olive_man.head()
olive_man.tail()
# Out:
#   category    brand_name                             product_name   price  \
# 0     스킨케어  보타닉힐보 아이디얼포맨                             퍼펙트 올인원 기획세트  21,900
# 1     스킨케어          우르오스             우르오스 올인원 스킨밀크&스킨로션 200ml 택 1  25,200
# 2     스킨케어            불독              불독 오리지널 수분크림 100ml+30ml 기획팩  16,000
# 3     스킨케어          우르오스                          우르오스 스킨밀크 200ml  25,200
# 4     스킨케어           XTM  XTM 올인원 엑스퍼트 200mL 대용량기획(멀티 토너 50mL 증정)  23,200
#
#   pre_price  sales_rank
# 0    28,000           1
# 1    29,700           2
# 2    20,000           3
# 3    29,700           4
# 4    29,000           5
#      category brand_name                        product_name    price  \
# 1124   쉐이빙/잡화         펀샵     [온라인단독]플러스마이너스제로 공기청정기 C021 화이트  299,000
# 1125   쉐이빙/잡화         펀샵              [온라인단독]DSPTCH 캡스냅 모자홀더   12,900
# 1126   쉐이빙/잡화         펀샵            [온라인단독]Feather 멀티 헤어 트리머   12,800
# 1127   쉐이빙/잡화         펀샵  [온라인단독]인생의자 (ALUMINIUM LIFE CHAIR)  129,000
# ...

# %% [markdown]
# + 총 품목은 1188갠데 3107개로 나와 데이터처리 필요

# %% [markdown]
# # 결측값 확인

# %%
olive_man.isnull().sum()
# Out:
# category        0
# brand_name      0
# product_name    0
# price           0
# pre_price       0
# sales_rank      0
# dtype: int64

# %% [markdown]
# + 칼럼별 결측값 개수확인 ( 결측값 존재하지않음 )

# %% [markdown]
# # price / pre_price 변수

# %% [markdown]
# #### price / pre_price 의 분석을 위해 , 제거

# %%
olive_man['price']= olive_man['price'].str.replace(',', '').astype('int64')
olive_man['pre_price']=olive_man['pre_price'].str.replace(',',"").astype('int64') #할인상품이 아닌경우 할인전 가격은 0

# %%
olive_man.head()
# Out:
#   category    brand_name                             product_name  price  \
# 0     스킨케어  보타닉힐보 아이디얼포맨                             퍼펙트 올인원 기획세트  21900
# 1     스킨케어          우르오스             우르오스 올인원 스킨밀크&스킨로션 200ml 택 1  25200
# 2     스킨케어            불독              불독 오리지널 수분크림 100ml+30ml 기획팩  16000
# 3     스킨케어          우르오스                          우르오스 스킨밀크 200ml  25200
# 4     스킨케어           XTM  XTM 올인원 엑스퍼트 200mL 대용량기획(멀티 토너 50mL 증정)  23200
#
#    pre_price  sales_rank
# 0      28000           1
# 1      29700           2
# 2      20000           3
# 3      29700           4
# 4      29000           5

# %% [markdown]
# # brand_name encoded ( brand_ name 텍스트를 숫자로 )

# %%
olive_man['brand_name'].values
# Out:
# array(['보타닉힐보 아이디얼포맨', '우르오스', '불독', ..., '펀샵', '펀샵', '펀샵'], dtype=object)

# %%
olive_man_cat=olive_man['brand_name']
olive_man_cat.head(10)
# Out:
# 0    보타닉힐보 아이디얼포맨
# 1            우르오스
# 2              불독
# 3            우르오스
# 4             XTM
# 5    보타닉힐보 아이디얼포맨
# 6             XTM
# 7              불독
# 8            티르티르
# 9             XTM
# Name: brand_name, dtype: object

# %% [markdown]
# #### 각 카테고리를 다른 정수값으로 매핑해주는 factorize() 매서드 사용

# %%
olive_man_cat_encoded,olive_man_cat_categories=olive_man_cat.factorize()
olive_man_cat_encoded
olive_man_cat_categories
# Out:
# array([ 0,  1,  2, ..., 36, 36, 36], dtype=int64)
# Index(['보타닉힐보 아이디얼포맨', '우르오스', '불독', 'XTM', '티르티르', '랩시리즈', '블랙몬스터', '클럽맨피노드',
#        '보닌', '라끄베르',
#        ...
#        'GNC', '포레오', '에보쉐이브', '에스지생활안전', '네오바디', '선패밀리', '페브리즈', '솔가', '나인투식스',
#        '쎄컨스킨'],
#       dtype='object', length=103)

# %%
olive_man_cat_encoded[:10]
# Out:
# array([0, 1, 2, 1, 3, 0, 3, 2, 4, 3], dtype=int64)

# %% [markdown]
# + 텍스트가 숫자로 바뀐것 확인

# %% [markdown]
# #### 새로운 변수 brand_name2

# %%
olive_man['brand_name2']=olive_man_cat_encoded

# %%
olive_man.head()
# Out:
#   category    brand_name                             product_name  price  \
# 0     스킨케어  보타닉힐보 아이디얼포맨                             퍼펙트 올인원 기획세트  21900
# 1     스킨케어          우르오스             우르오스 올인원 스킨밀크&스킨로션 200ml 택 1  25200
# 2     스킨케어            불독              불독 오리지널 수분크림 100ml+30ml 기획팩  16000
# 3     스킨케어          우르오스                          우르오스 스킨밀크 200ml  25200
# 4     스킨케어           XTM  XTM 올인원 엑스퍼트 200mL 대용량기획(멀티 토너 50mL 증정)  23200
#
#    pre_price  sales_rank  brand_name2
# 0      28000           1            0
# 1      29700           2            1
# 2      20000           3            2
# 3      29700           4            1
# 4      29000           5            3

# %% [markdown]
# # index 다시 지정

# %%
olive_man=olive_man.reset_index()
olive_man.tail(5) # 개수 확인위해 데이터끝부분확인
# Out:
#       index category brand_name                        product_name   price  \
# 1124   1124   쉐이빙/잡화         펀샵     [온라인단독]플러스마이너스제로 공기청정기 C021 화이트  299000
# 1125   1125   쉐이빙/잡화         펀샵              [온라인단독]DSPTCH 캡스냅 모자홀더   12900
# 1126   1126   쉐이빙/잡화         펀샵            [온라인단독]Feather 멀티 헤어 트리머   12800
# 1127   1127   쉐이빙/잡화         펀샵  [온라인단독]인생의자 (ALUMINIUM LIFE CHAIR)  129000
# 1128   1128   쉐이빙/잡화         펀샵                         클립 지갑 Rev.2   15900
#
#       pre_price  sales_rank  brand_name2
# 1124          0         599           36
# 1125          0         600           36
# 1126          0         601           36
# 1127          0         602           36
# 1128          0         603           36

# %% [markdown]
# + 위에서 처리해주지않은 index 처리
# + 이로써 , 총 1128개의 상품 데이터 정리 완료

# %% [markdown]
# # brand_name 워드클라우드

# %%
from konlpy.tag import Twitter
from collections import Counter

# %%
count=Counter(olive_man['brand_name'])

# %%
words=dict(count.most_common())

# %%
words
# Out:
# {'펀샵': 451,
#  '다슈': 39,
#  '아디다스': 38,
#  'XTM': 37,
#  '갸스비': 30,
#  '그라펜': 28,
#  '엠도씨': 26,
#  '니베아': 21,
#  '랩시리즈': 20,
#  '보타닉힐보 아이디얼포맨': 19,
#  '우르오스': 17,
#  '블랙몬스터': 17,
#  '디티알티': 17,
#  '헤지스 맨 룰429': 17,
#  '질레트': 15,
#  '불독': 14,
#  '보닌': 14,
#  '클럽맨피노드': 12,
#  '미쟝센': 12,
#  '크리니크': 11,
#  '포맨트': 10,
#  '몽블랑': 10,
#  '미프': 9,
#  '쉬크': 9,
#  '케어존 옴므': 8,
#  '차앤박옴므': 7,
#  '이아소': 7,
#  '스웨거': 7,
#  '필립스': 7,
#  '포뷰트': 7,
#  '유닉스': 7,
#  '페라리': 7,
#  '존바바토스': 7,
#  '버버리': 7,
#  '블락': 7,
#  '눅스': 6,
#  '세븐피엠': 6,
#  '알페신': 6,
#  '캘빈클라인': 6,
#  '코오롱': 6,
#  '비욘드 옴므': 5,
#  '불가리': 5,
#  '겐조': 5,
#  '올리브영': 5,
#  '라끄베르': 4,
#  '브로앤팁스': 4,
#  '리얼쉐이빙': 4,
#  '메르세데스 벤츠': 4,
#  '브라운': 4,
#  '네오바디': 4,
#  '티지 베드헤드': 3,
#  '아르코맨': 3,
#  '카이': 3,
#  '로이체': 3,
#  '세노비스': 3,
#  '선패밀리': 3,
#  '비알티씨옴므': 2,
#  '지베르니': 2,
#  '엠솔릭': 2,
#  '닥터자르트포맨': 2,
#  '블루비어드': 2,
#  '박준뷰티랩': 2,
#  '듀크레이': 2,
#  '백스터': 2,
#  '바비리스': 2,
#  '에너지팩토리': 2,
#  '베르사체': 2,
#  '이세이미야케': 2,
#  '돌체&가바나': 2,
# ...

# %%
from wordcloud import WordCloud 
import matplotlib.pyplot as plt 
import nltk 
from nltk.corpus import stopwords

# %%
# %matplotlib inline
import matplotlib 
from IPython.display import set_matplotlib_formats 
matplotlib.rc('font',family = 'Malgun Gothic')
set_matplotlib_formats('retina')

matplotlib.rc('axes',unicode_minus = False)

# %%
wordcloud = WordCloud(font_path = 'C:/Windows/Fonts/malgun.ttf', background_color='white',colormap = "Accent_r", width=1500, height=1000).generate_from_frequencies(words) 
plt.imshow(wordcloud)
plt.axis('off') 
plt.show()
# Out:
# (-0.5, 1499.5, 999.5, -0.5)

# %% [markdown]
# # 상품별 그룹화

# %% [markdown]
# ### 스킨케어

# %%
olive_man_skin=olive_man[olive_man['category']=='스킨케어']
olive_man_skin.tail(2)
# Out:
#      index category brand_name                  product_name  price  \
# 211    211     스킨케어        XTM       XTM스타일옴므 스타일링 박스(4주년기획)  14000
# 212    212     스킨케어        이아소  [닥터이아소] 스킨케어 포 맨 멀티 액션 폼 클렌저  20000
#
#      pre_price  sales_rank  brand_name2
# 211      28000         212            3
# 212          0         213           23

# %%
스킨_list,토너_list,크림_list,에센스_list,로션_list,기획_list,세트_list,기초_list,세럼_list,클렌저_list,클렌징_list,필링_list,마스크_list = [],[],[],[],[],[],[],[],[],[],[],[],[]
스킨_idx,토너_idx,크림_idx,에센스_idx,로션_idx,기획_idx,세트_idx,기초_idx,세럼_idx,클렌저_idx,클렌징_idx,필링_idx,마스크_idx = [],[],[],[],[],[],[],[],[],[],[],[],[]
p_name = ['스킨' ,'토너' ,'크림' ,'에센스' ,'로션' ,'기획' ,'세트' ,'기초' ,'세럼' ,'클렌저','클렌징','필링','마스크']
prod_list = [스킨_list,토너_list,크림_list,에센스_list,로션_list,기획_list,세트_list,기초_list,세럼_list,클렌저_list,클렌징_list,필링_list,마스크_list]
prod_idx = [스킨_idx,토너_idx,크림_idx,에센스_idx,로션_idx,기획_idx,세트_idx,기초_idx,세럼_idx,클렌저_idx,클렌징_idx,필링_idx,마스크_idx]

for li,idx, p_nm in zip(prod_list,prod_idx,p_name):
    for name, index in zip(olive_man_skin['product_name'],olive_man_skin['index']):
        if p_nm in name:
            li.append(name)
            idx.append(index)

# %% [markdown]
# ## 바디케어

# %%
olive_man_body=olive_man[olive_man['category']=='바디케어']
olive_man_body.tail(2)
# Out:
#      index category brand_name                           product_name  price  \
# 263    263     바디케어        갸스비  [온라인단독]갸스비 스팟 데오도란트 롤온 아쿠아틱 시트러스 60ml  12500
# 264    264     바디케어        니베아              니베아 맨 데오드란트 스프레이-쿨킥 200ml   9200
#
#      pre_price  sales_rank  brand_name2
# 263          0          51           39
# 264      13200          52           18

# %%
스킨워시_list,바디워시_list,바디로션_list,립_바디_list,미스트_list,데오드란트_list,젤_바디_list= [],[],[],[],[],[],[]
스킨워시_idx,바디워시_idx,바디로션_idx,립_바디_idx,미스트_idx,데오드란트_idx,젤_바디_idx = [],[],[],[],[],[],[]
p_name = ['스킨워시' ,'바디워시' ,'바디로션' ,'립' ,'미스트' ,'데오드란트' ,'젤']
prod_list = [스킨워시_list,바디워시_list,바디로션_list,립_바디_list,미스트_list,데오드란트_list,젤_바디_list]
prod_idx = [스킨워시_idx,바디워시_idx,바디로션_idx,립_바디_idx,미스트_idx,데오드란트_idx,젤_바디_idx]

for li,idx, p_nm in zip(prod_list,prod_idx,p_name):
    for name, index in zip(olive_man_body['product_name'],olive_man_body['index']):
        if p_nm in name:
            li.append(name)
            idx.append(index)

# %% [markdown]
# ## 헤어케어

# %%
olive_man_hair=olive_man[olive_man['category']=='헤어케어']
olive_man_hair.tail(2)
# Out:
#      index category brand_name                product_name  price  pre_price  \
# 387    387     헤어케어        알페신     알페신 카페인 샴푸 더블 이펙트 200ml  12750      15000
# 388    388     헤어케어         펀샵  [온라인단독]난각막 필메그 트리트먼트 500ml  19000          0
#
#      sales_rank  brand_name2
# 387         123           46
# 388         124           36

# %%
샴푸_list,왁스_list,스프레이_list,포마드_list,다운펌_list,컬_list,고데기_list,젤_헤어_list= [],[],[],[],[],[],[],[]
샴푸_idx,왁스_idx,스프레이_idx,포마드_idx,다운펌_idx,컬_idx,고데기_idx,젤_헤어_idx= [],[],[],[],[],[],[],[]
p_name = ['샴푸' ,'왁스' ,'스프레이' ,'포마드' ,'다운펌','컬','고데기','젤']
prod_list = [샴푸_list,왁스_list,스프레이_list,포마드_list,다운펌_list,컬_list,고데기_list,젤_헤어_list]
prod_idx = [샴푸_idx,왁스_idx,스프레이_idx,포마드_idx,다운펌_idx,컬_idx,고데기_idx,젤_헤어_idx]

for li,idx, p_nm in zip(prod_list,prod_idx,p_name):
    for name, index in zip(olive_man_hair['product_name'],olive_man_hair['index']):
        if p_nm in name:
            li.append(name)
            idx.append(index)

# %% [markdown]
# ## 메이크업

# %%
olive_man_makeup=olive_man[olive_man['category']=='메이크업']
olive_man_makeup.tail(2)
# Out:
#      index category brand_name                                 product_name  \
# 452    452     메이크업       랩시리즈  랩시리즈 BB 틴티드 모이스춰라이저 SPF35 PA+++ 50ml (2W6L)
# 453    453     메이크업        XTM                              XTM 노세범 멀티 프라이머
#
#      price  pre_price  sales_rank  brand_name2
# 452  59000          0          64            5
# 453  16000          0          65            3

# %%
비비_list,쿠션_list,브로우_list,립_list,스틱_list,선_list,컨실러_list,프라이머_list= [],[],[],[],[],[],[],[]
비비_idx,쿠션_idx,브로우_idx,립_idx,스틱_idx,선_idx,컨실러_idx,프라이머_idx= [],[],[],[],[],[],[],[]
p_name = ['비비' ,'쿠션' ,'브로우' ,'립' ,'스틱','선','컨실러','프라이머']
prod_list = [비비_list,쿠션_list,브로우_list,립_list,스틱_list,선_list,컨실러_list,프라이머_list]
prod_idx = [비비_idx,쿠션_idx,브로우_idx,립_idx,스틱_idx,선_idx,컨실러_idx,프라이머_idx]

for li,idx, p_nm in zip(prod_list,prod_idx,p_name):
    for name, index in zip(olive_man_makeup['product_name'],olive_man_makeup['index']):
        if p_nm in name:
            li.append(name)
            idx.append(index)

# %% [markdown]
# ## 향수 & 탈취

# %%
olive_man_perfume=olive_man[olive_man['category']=='향수/탈취']
olive_man_perfume.tail(15)
# Out:
#      index category brand_name                              product_name  \
# 511    511    향수/탈취         펀샵  [온라인단독]300년 기소편백 히노키 프레쉬 워터 - 편백나무 300ml
# 512    512    향수/탈취   메르세데스 벤츠                       메르세데스 벤츠 맨 EDT 50ml
# 513    513    향수/탈취        몽블랑                      몽블랑 레전드 스피릿 EDT 50ml
# 514    514    향수/탈취        몽블랑                      몽블랑 레전드 스피릿 EDT 30ml
# 515    515    향수/탈취      캘빈클라인                  CK 캘빈클라인 원 모이스처라이저 250ml
# 516    516    향수/탈취         겐조                            겐조 옴므 EDP 50ml
# 517    517    향수/탈취       페라가모                    페라가모 아쿠아에센셜 블루EDT 30ml
# 518    518    향수/탈취      존바바토스                    존바바토스 아티산 블루 EDT 125ml
# 519    519    향수/탈취      캘빈클라인             CK 캘빈클라인 One EDT 50ml / 100ml
# 520    520    향수/탈취         겐조                            겐조 옴므 EDT 50ml
# 521    521    향수/탈취         겐조                       로 겐조 뿌르 옴므 EDT 30ml
# 522    522    향수/탈취         겐조                       로 겐조 뿌르 옴므 EDT 50ml
# ...

# %%
# 판매순위가 높은 브랜드 / 그 외의 브랜드는 하나로 묶기 
페라리_list,포맨트_list,존바바토스_list,불가리_list,버버리_list,겐조_list,캘빈클라인_list= [],[],[],[],[],[],[]
페라리_idx,포맨트_idx,존바바토스_idx,불가리_idx,버버리_idx,겐조_idx,캘빈클라인_idx= [],[],[],[],[],[],[]
p_name = ['페라리' ,'포맨트' ,'존바바토스' ,'불가리' ,'버버리','겐조','캘빈클라인']
prod_list = [페라리_list,포맨트_list,존바바토스_list,불가리_list,버버리_list,겐조_list,캘빈클라인_list]
prod_idx = [페라리_idx,포맨트_idx,존바바토스_idx,불가리_idx,버버리_idx,겐조_idx,캘빈클라인_idx]

for li,idx, p_nm in zip(prod_list,prod_idx,p_name):
    for name, index in zip(olive_man_perfume['product_name'],olive_man_perfume['index']):
        if p_nm in name:
            li.append(name)
            idx.append(index)

# %% [markdown]
# ## 쉐이빙 & 잡화

# %%
olive_man_shaving=olive_man[olive_man['category']=='쉐이빙/잡화']
olive_man_shaving.tail(2)
# Out:
#       index category brand_name                        product_name   price  \
# 1127   1127   쉐이빙/잡화         펀샵  [온라인단독]인생의자 (ALUMINIUM LIFE CHAIR)  129000
# 1128   1128   쉐이빙/잡화         펀샵                         클립 지갑 Rev.2   15900
#
#       pre_price  sales_rank  brand_name2
# 1127          0         602           36
# 1128          0         603           36

# %%
면도_list,쉐이빙_list,쉐이브_list,비타민_list,부스터_list= [],[],[],[],[]
면도_idx,쉐이빙_idx,쉐이브_idx,비타민_idx,부스터_idx= [],[],[],[],[]
p_name = ['면도' ,'쉐이빙' ,'쉐이브','비타민' ,'부스터']
prod_list = [면도_list,쉐이빙_list,쉐이브_list,비타민_list,부스터_list]
prod_idx = [면도_idx,쉐이빙_idx,쉐이브_idx,비타민_idx,부스터_idx]

for li,idx, p_nm in zip(prod_list,prod_idx,p_name):
    for name, index in zip(olive_man_shaving['product_name'],olive_man_shaving['index']):
        if p_nm in name:
            li.append(name)
            idx.append(index)

# %% [markdown]
# # [ category 별 항목그룹에 포함되지않는 제품들 ]

# %% [markdown]
# ## 스킨케어 index 정리

# %%
# 위의 지정항목들을 제외한 나머지 항목
olive_man_skin_drop=olive_man_skin.drop(스킨_idx+토너_idx+크림_idx+에센스_idx+로션_idx+기획_idx+세트_idx+기초_idx+세럼_idx+클렌저_idx+클렌징_idx+필링_idx+마스크_idx)
olive_man_skin_drop.head(3)
# Out:
#     index category brand_name              product_name  price  pre_price  \
# 12     12     스킨케어      블랙몬스터     블랙몬스터 옴므 올인원 데이 앤 나이트  27500      28900
# 14     14     스킨케어         보닌        보닌 퓨어 에센셜 에멀전150ml  14000      20000
# 22     22     스킨케어        포맨트  [온라인단독]포맨트 블랙헤드 바이 클리어패드  18400      23000
#
#     sales_rank  brand_name2
# 12          13            6
# 14          15            8
# 22          23           11

# %%
# 중요항목을 제외한 스킨케어category의 나머지 품목들 ( 다른 category와도 겹치는게 많음)
list(olive_man_skin_drop['product_name'])
# Out:
# ['블랙몬스터 옴므 올인원 데이 앤 나이트',
#  '보닌 퓨어 에센셜 에멀전150ml',
#  '[온라인단독]포맨트 블랙헤드 바이 클리어패드',
#  '보닌 더스타일 스탠다드 에멀전135ml',
#  '랩시리즈 멀티액션 훼이스 워시 100ml',
#  'XTM 데일리 톤업 선블록 SPF50+/PA++++',
#  '우르오스 페이스시트 14매',
#  'XTM 노세범 선스틱 SPF50+/PA++++',
#  '[온라인단독]DTRT 히어로즈 커밍 순 키트',
#  '헤지스맨 룰429 올인원 젤 하이드레이터 150ml',
#  '불독 오일컨트롤 페이스스크럽 125ml',
#  'XTM 올인원 톤업 120 mL',
#  '[온라인단독] 랩시리즈 인스턴트 필터 모이스춰라이저 50ml',
#  '블랙몬스터 블랙 스크러버',
#  '이아소 포맨 화이트 이엑스 애프터쉐이브 130ml',
#  '[온라인단독] 눅스 맨 올인원 모이스춰라이징 젤 50ml',
#  '[온라인단독]랩시리즈 오일 컨트롤 데일리 모이스춰라이저 50ml',
#  '셀라피 레드시카 올인원 앰플 S.O.S 키트',
#  '다슈 데일리 비타플렉스 선스틱 15g',
#  '클럽맨피노드 머스크 에프터쉐이브코롱 177ml',
#  'XTM 아웃도어 워터프루프 선블록 SPF50+/PA++++',
#  '우르오스 플러스 선블럭 SPF50 (25ml)(R)',
#  '[온라인단독] 눅스 맨 애프터쉐이브 수딩 밤 50ml',
#  '클럽맨피노드 머스크 에프터쉐이브코롱 50ml',
#  '클럽맨리저브 위스키우즈 에프터쉐이브 177ml',
#  '클럽맨리저브 젠트진 에프터쉐이브 50ml',
#  '클럽맨리저브 위스키우즈 에프터쉐이브 50ml',
#  '클럽맨리저브 브랜디스파이스 에프터쉐이브 177ml',
#  'XTM 쉐이빙 젤 센서티브 120 mL',
#  '클럽맨리저브 브랜디스파이스 에프터쉐이브 50ml',
#  '클럽맨리저브 젠트진 에프터쉐이브 177ml',
# ...

# %% [markdown]
# ## 바디케어 index 정리

# %%
# 위의 지정항목들을 제외한 나머지 항목
olive_man_body_drop=olive_man_body.drop(스킨워시_idx+바디워시_idx+바디로션_idx+립_바디_idx+미스트_idx+데오드란트_idx+젤_바디_idx)
olive_man_body_drop
# Out:
#      index category brand_name                           product_name  price  \
# 214    214     바디케어      블랙몬스터                          블랙몬스터 블랙밤 (N)   8500
# 226    226     바디케어         눅스             [온라인단독] 눅스 맨 데오도란트 롤온 50ml  15300
# 229    229     바디케어        XTM                                퍼퓸 핸드크림   3000
# 244    244     바디케어        엠도씨                        엠도씨 릴리프 바디 겔 로션  17000
# 247    247     바디케어        엠도씨                 엠도씨 세붐 스트라이크 HD 파우더 티슈   3200
# 253    253     바디케어       랩시리즈                   랩시리즈 쿨링 쉐이브 크림 100ml  32000
# 254    254     바디케어        갸스비           [온라인단독]갸스비 샤워 프레쉬 샤이니블루 60ml  13000
# 255    255     바디케어         빌리                     빌리 데오 스프레이 맨 200ml   9900
# 257    257     바디케어        낫포유                             낫포유 키스밤 포맨   7900
# 258    258     바디케어        갸스비          [온라인단독]갸스비 샤워 프레쉬 오션시트러스 60ml  13000
# 259    259     바디케어        챕스틱           [온라인단독]챕스틱 엠 맨케어 SPF 15 4.2g   4200
# ...

# %% [markdown]
# ## 헤어케어 index 정리

# %%
# 위의 지정항목들을 제외한 나머지 항목
olive_man_hair_drop=olive_man_hair.drop(샴푸_idx+왁스_idx+스프레이_idx+포마드_idx+다운펌_idx+컬_idx+고데기_idx+젤_헤어_idx)
olive_man_hair_drop
# Out:
#      index category brand_name                             product_name  \
# 266    266     헤어케어        필립스  [온라인전용]필립스 휴대용 헤어드라이어 (BHC010) 블랙 1200W
# 269    269     헤어케어        그라펜                                그라펜 엣지 핑거
# 273    273     헤어케어         다슈                 다슈 안티 헤어로스 허브 헤어토닉 150ml
# 275    275     헤어케어        포뷰트                                포뷰트 엠스타일러
# 291    291     헤어케어        갸스비                     갸스비 수퍼하드 스타일링 폼 185g
# 305    305     헤어케어        그라펜                         그라펜 콜드 부스터 100ml
# 312    312     헤어케어        그라펜                         그라펜 콜드 부스터 200ml
# 313    313     헤어케어        갸스비                  갸스비 스타일 & 케어오일 내츄럴 75ML
# 324    324     헤어케어        포맨트                      [온라인단독]포맨트 올데이 다운스틱
# 330    330     헤어케어       세븐피엠                               세븐피엠 매직모히칸
# 367    367     헤어케어         다슈                [올리브영 단독] 다슈 퍼펙트 에디션 기획세트
# 370    370     헤어케어         다슈      다슈 데일리 원데이 매직 볼륨 스타일링 파우더(펌프형) 40ml
# ...

# %% [markdown]
# ## 메이크업 index 정리

# %%
# 위의 지정항목들을 제외한 나머지 항목
olive_man_makeup_drop=olive_man_makeup.drop(비비_idx+쿠션_idx+브로우_idx+립_idx+스틱_idx+선_idx+컨실러_idx+프라이머_idx)
olive_man_makeup_drop
# Out:
#      index category brand_name                                 product_name  \
# 389    389     메이크업      블랙몬스터                                블랙몬스터 블랙밤 (N)
# 400    400     메이크업        XTM                                    XTM 멀티 씨씨
# 404    404     메이크업      블랙몬스터                              블랙몬스터 블랙 이레이징 펜
# 413    413     메이크업     에너지팩토리                       스킨핏 맨즈밤 위드 토트넘(어두운피부용)
# 414    414     메이크업        엠도씨                          엠도씨 세붐 스트라이크 HD 파우더
# 417    417     메이크업       세븐피엠        세븐피엠 이지아미 위장크림세트(본품 21g, 증정 15ml) (R)
# 426    426     메이크업       디티알티                  [DTRT] 틴티드 모이스처라이저 넌센스 50ml
# 428    428     메이크업         보닌                        보닌 더스타일 블루 스타일 피니셔 BB
# 433    433     메이크업         미프                                  미남프로젝트 눈썹엔딩
# 434    434     메이크업     에너지팩토리                        스킨핏 맨즈밤 위드 토트넘(밝은피부용)
# 440    440     메이크업       랩시리즈              랩시리즈 파워 프로텍터 SPF 50 PA+++ 100ml
# ...

# %% [markdown]
# ## 쉐이빙 & 잡화 index 정리

# %%
# 위의 지정항목들을 제외한 나머지 항목
olive_man_shaving_drop=olive_man_shaving.drop(면도_idx+쉐이빙_idx+쉐이브_idx+비타민_idx+부스터_idx)
olive_man_shaving_drop.head(3)
# Out:
#      index category brand_name                 product_name  price  pre_price  \
# 530    530   쉐이빙/잡화      블랙모어스            블랙모어스 맨스퍼포먼스 멀티30  15000      25000
# 531    531   쉐이빙/잡화       아디다스    [온라인단독]아디다스 뉴 네오프렌 아령 2KG  14000      20000
# 532    532   쉐이빙/잡화       아디다스  [온라인단독]아디다스 AB 트레이닝 매트 10mm  39200      49000
#
#      sales_rank  brand_name2
# 530           5           74
# 531           6           75
# 532           7           75

# %%
# 쉐이빙 & 잡화의 상당부분인 [온라인단독] 상품제거 
온라인단독=olive_man_shaving_drop[olive_man_shaving_drop['product_name'].str.contains('[온라인단독]')]
olive_man_shaving_drop_온라인=olive_man_shaving_drop.drop(list(온라인단독['index']))
olive_man_shaving_drop_온라인
# Out:
#       index category brand_name  \
# 530     530   쉐이빙/잡화      블랙모어스
# 533     533   쉐이빙/잡화         다슈
# 535     535   쉐이빙/잡화       올리브영
# 539     539   쉐이빙/잡화         위거
# 540     540   쉐이빙/잡화       올리브영
# 544     544   쉐이빙/잡화        갸스비
# 546     546   쉐이빙/잡화         펀샵
# 562     562   쉐이빙/잡화         펀샵
# 565     565   쉐이빙/잡화         펀샵
# 566     566   쉐이빙/잡화         펀샵
# 574     574   쉐이빙/잡화       올리브영
# 581     581   쉐이빙/잡화        필립스
# 593     593   쉐이빙/잡화         펀샵
# 594     594   쉐이빙/잡화         펀샵
# 595     595   쉐이빙/잡화         펀샵
# 612     612   쉐이빙/잡화         펀샵
# 617     617   쉐이빙/잡화         펀샵
# 622     622   쉐이빙/잡화         펀샵
# 647     647   쉐이빙/잡화         펀샵
# 651     651   쉐이빙/잡화         펀샵
# 652     652   쉐이빙/잡화         펀샵
# 700     700   쉐이빙/잡화         펀샵
# 701     701   쉐이빙/잡화         펀샵
# 702     702   쉐이빙/잡화         펀샵
# 711     711   쉐이빙/잡화         펀샵
# 714     714   쉐이빙/잡화         펀샵
# 715     715   쉐이빙/잡화         펀샵
# 716     716   쉐이빙/잡화         펀샵
# ...
