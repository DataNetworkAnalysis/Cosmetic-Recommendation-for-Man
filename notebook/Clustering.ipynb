# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#데이터-불러오기" data-toc-modified-id="데이터-불러오기-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>데이터 불러오기</a></span></li><li><span><a href="#전처리" data-toc-modified-id="전처리-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>전처리</a></span></li><li><span><a href="#임베딩" data-toc-modified-id="임베딩-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>임베딩</a></span></li><li><span><a href="#군집분석" data-toc-modified-id="군집분석-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>군집분석</a></span><ul class="toc-item"><li><span><a href="#Join" data-toc-modified-id="Join-4.1"><span class="toc-item-num">4.1&nbsp;&nbsp;</span>Join</a></span></li><li><span><a href="#K-정하기" data-toc-modified-id="K-정하기-4.2"><span class="toc-item-num">4.2&nbsp;&nbsp;</span>K 정하기</a></span></li><li><span><a href="#K-=-5-!!" data-toc-modified-id="K-=-5-!!-4.3"><span class="toc-item-num">4.3&nbsp;&nbsp;</span>K = 5 !!</a></span></li></ul></li><li><span><a href="#군집별-결과" data-toc-modified-id="군집별-결과-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>군집별 결과</a></span><ul class="toc-item"><li><span><a href="#Cluster-1" data-toc-modified-id="Cluster-1-5.1"><span class="toc-item-num">5.1&nbsp;&nbsp;</span>Cluster 1</a></span></li><li><span><a href="#Cluster-2" data-toc-modified-id="Cluster-2-5.2"><span class="toc-item-num">5.2&nbsp;&nbsp;</span>Cluster 2</a></span></li><li><span><a href="#Cluster-3" data-toc-modified-id="Cluster-3-5.3"><span class="toc-item-num">5.3&nbsp;&nbsp;</span>Cluster 3</a></span></li><li><span><a href="#Cluster-4" data-toc-modified-id="Cluster-4-5.4"><span class="toc-item-num">5.4&nbsp;&nbsp;</span>Cluster 4</a></span></li><li><span><a href="#Cluster-5" data-toc-modified-id="Cluster-5-5.5"><span class="toc-item-num">5.5&nbsp;&nbsp;</span>Cluster 5</a></span></li></ul></li></ul></div>

# %%
import pandas as pd
from chatspace import ChatSpace
from gensim.models import FastText
from konlpy.tag import Kkma

import os 
os.listdir('../dataset')
# Out:
# ['glowpick_products.csv',
#  'glowpick_reviews.csv',
#  'glowpick_reviews_old.csv',
#  'oliveyoung_product_info.csv']

# %% [markdown]
# # 데이터 불러오기

# %%
reviews = pd.read_csv('../dataset/glowpick_reviews.csv')
print('reviews shape: ',reviews.shape)
# Out:
# reviews shape:  (5208, 7)

# %% [markdown]
# # 전처리

# %%
import re

# %%
def txt_sub(x):
    pattern1 = '([ㄱ-ㅎㅏ-ㅣ]+)'
    pattern2 = '[^\w\s,.]'
    repl = ''
    x = re.sub(pattern=pattern1, repl=repl, string=x)
    x = re.sub(pattern=pattern2, repl=repl, string=x)
    return x

# %%
texts = reviews.content.apply(lambda x: txt_sub(x)).tolist()

# %%
list(map(txt_sub,reviews.content.tolist()))
# Out:
# ['제일 무난하고 가볍게쓰기 좋아서 몇년째 이거만써요',
#  '남자친구 선물로 사줬는데 그저그렇데요 나쁘지도 좋지도 않데요',
#  '아빠 사드렸는데 저아해여',
#  '향이 좋아요 근데 좀 제 피부가 민감해서 안맞는거 같아요 좀 올라오더라고요',
#  '가격이 저렴하고 냄새가 안 쎄서 좋아요.  다음에도 또 구매할 것 같아요.',
#  '선물용으로 사서 선물했는데 나름 만족했는지 매일 바른다네요',
#  '향이 청량해서 좋아요. 흡수가 잘되면서 끈적이지 않아요. 지금 시즌 잘 사용중인데 가을부터는 건조할듯 합니다. 가볍게 쓰기 좋대요.',
#  '피부 지성이어서 최대한 안 끈적거리고 수분보충 할 수 있는 제품 찾으려고 하는 편인데 이거 써보니까 좋았어요. 피부 기름 클렌징폼으로 세안하고 이거 바르면 저는 괜찮더라고요.',
#  '남치니 사줫는데 앞으로는 이것만 쓰겟다고 넘넘 좋다고 한다  남자들 무거운거 싫어하는데 텍스쳐도 좋고, 수분감도 좋앗다. 향도 나쁘지 않다. 가격대도 용량비해서 나쁘지 않은편이라 앞으로 계속 이것만 쓸듯',
#  '아부지 생신이라서 세트로 사드렸어요 건조하고 각질 있는 피부에 T존에는 기름이 많고 주름으로 걱정중이셨는데 직원 추천으로 사드렸어요 향이 조금 독한걸 좋아하시는데 전 독한지 잘 모르겠더라고요 그래도 아부지가 좋다고 하시네요',
#  '톡 쏘지 않고 은은한 향이 순한 느낌을 줘서 아주 좋더라구요. 알코올 에탄올 성분도 없어서 민감성 피부에 강추하고 다닙니다 이거 패키지도 세련되서 선물용으로도 아주 좋아요',
#  '이거 조음 직접 써본결과 매우만족',
#  ' 성분도 남자꺼 치고 순한 편에 발림성 또한 우수한 편 전체적으로 모든피부에 무난하게 사용할 수 있음. 똑같은 라인에 초록버전보다 파란 버전모이스처 더 유분감도 덜하고 촉촉하니 좋았음   무난한게 가장 큰 장점이지 않나 싶음 향이 일단 매우 좋았어서흔히 남자 화장품에서 나는 아재향 같은게 없음 선물용으로 좋음   초록 라인보단 모든 피부에 파란 모이스처 라인 추천',
#  '이제품은 로션이건 스킨이건 둘다 짱입니당  남성의향이아닌 향기라고 해야하나 암튼 좋아용',
#  '스킨 알콜향은 없어서 좋지만 그린티랑 차이가 ...',
#  '발랐을때 상쾌하고 향도 좋네요 추천합니다',
#  '리뷰에 많이 보인다. 군인들이 많이 쓴다고 외박 나가서 사서 들어와서 전역하고 난 지금까지 계속 쓰고있다. 좋음.',
#  '남자들의 공용 스킨이죠 ',
#  '오 근데 조아요 막 그렇게 강해서 따갑지도 않지만 제가 쓰기에는 충분히 괜찮았어용 양도 많고 굳굳 ',
#  '기름진 물 로션을 탄 물 같은 느낌 난 동생꺼 썻을때 나쁘지 않앗당',
#  '수분이 부족한 남자분들껜 가성비로 치자면 이게 갑이죠',
#  '남편이 애용하는 제품입니다.',
#  '남자친구 피부많이 좋아졌습니다  좋아요',
#  '남자친구선물해줫는데 매우잘쓴다 그래서만족중',
#  '이번에 포레스트 포맨으로 갈아탔는데 지금까진 나쁘지않네요 향도 좋구 피부도 좋아지는 느낌',
#  '효과도 어느정도잇는거같고 괜춘한제품',
#  '군대간 남친 휴가나오더니 알아서 이거 사서 들어감  남자들끼리 모여도 이게 좋다 이건별로다 이야기 하나봐요 결국 남자 군인사이에선 1등인듯 ',
#  '남성 화장품 가끔 향이 너무 강해 불호일때가 있는데 이거 쓴 남편에게서 그런 느낌은 못받았어요. 만족하며 쓰고 있어요. 재구매했고 다시 재구매 할 계획이예요.',
#  '향은 대체로 남자향인데 촉촉하고 발랏을때 흡수도 잘되서 좋아요',
#  '건성인 옆지기가 쓰기에 촉촉하고 무난하게 쓰기좋음. 제일 좋은건 향이 세지 않다는 것.  향수마냥 독한 냄새를 싫어하는 본인 취향임.  첨엔 낯설어 하더니 잘 씀.',
#  '남자스킨은 거의 대부분의 제품들이 향이 참 독한데 이건 그렇지않아요 무난무난하게 사용가능함',
#  '남자친구가 너무 조아해요 산뜻하면서 촉촉하고 무엇보다도.... 간편해서 좋다곸',
#  '스킨로션전혀안바르시는아빠한테피부관리안하면더나이들어서주름자글자글해진다고지금부터라도기초를발라야한다면서이거랑로션사드렸는데지금거의다써간다 색깔은우유같은데별트러블없이무난하게쓰시는거같다',
#  '남친에게 포레스트 맨 스킨케어 세트로 선물줬어요. 만족하고 잘 쓰고있습니다',
#  '남편이 쭉 쓰는 스킨 상쾌해서 좋다고함',
#  '남자친구선물해줬는데 좋아해요',
#  '오빠가 화장품 뭐가 좋냐고 물어보길래 인터넷에서 순위보고 세트로 사다줬는데 냄새도 독하지 않고 트러블 약간 있는 피부인데 많이 안난다고 무난하다고 지금 세트로 네번째 구매하고 있네요 질리지 않냐고 다른거 사보라고 해도 이게 좋다고 안바꾸거라고요',
#  '구닌남친이쓰는스킨로션 워낙 얼굴에뭘 바르는걸 싫어해서.. 근데이건향이정말좋아요 진하지않고 아빠스키냄시도아니고 은은하이 뽀뽀하고싶어지는향.. 좋아용',
#  '아빠께 사다드렸는데 잘 쓰시고 계시네요 향도괜찮구가격대비도 괜찮은거같아요',
#  '남친이거쓴다 가격대비 짱',
#  '친구가 촉촉하고 산뜻하다고 매번 자기 남친 사주는 제품 나는 남친이 없어서 옆에서 조용히 계산하는 거 구경함',
#  '남친이 만족하면서 써요 촉촉하면서 끈적이지도 않고 번들거리지도 않아서 좋대요 그리고 쓰고나서 남친 피부결도 확실히 예전보다 좋아진듯 예전엔 아무것도 안발라서 그랬던 탓도 있겠지만',
#  '남자친구 선물해줬는데 잘쓴당. 그때 사면서 화장솜 샘플로 받았는데 남자친구가 써보고 좋아서 나도 잘 안쓰는 화장솜을 사서쓴다..굿',
#  '어버이날에 아빠 생신선물로 이거 세트 사다 드렸었는데 원래 성격이 뭘 잘 안바르시는 성격이라 ...T.T 딸래미의 성의를 봐서 몇 번 사용하시다가 귀찮으셔서 결국 안바르시고 화장대에 덩그러니... 아까워서 거즘 내 피부에 사용하면서 가끔씩 아빠 피부에도 직접 발라주고 이랬었는데 아빠나 나나 무난무난하니 큰 트러블 없이 잘 사용했다. 용량도 많아서 넉넉히 썼는데 향은 개인적으로 계속 맡다보면 남성스킨향.. 엄청 좋아하는 향은 아니라 그냥 그랬다. 향 빼고는 용량도 많고 산뜻한 타입.',
#  '어느 피부에도 다 사용이가능한 스킨인것같아요 피부가 예민한 저로선 정말 좋게 사용하고잇어요',
#  '남자친구 선물로 줬는데 되게 만족스럽다고 한다',
#  '솜과 함께 사용하는데 정말 만족하고 있습니다',
#  '남편은 토너 하나만 발라도충분하다네요 촉촉한가봐요',
#  '남자가 사용하기에 무난한 제품.. 그냥 일반 토너 특별한 기능 없음',
#  '지성 피부가 바르기에 좋은거 같고, 건성 피부엔 좀 약할듯 합니다. 바른 순간에는 알콜향이 나는 편이라 사람마다 호불호가 갈릴듯합니다. 그래도 알콜향은 금방 날아가고 남은 잔향은 좋은 편입니다.',
#  '내가 써본 토너 중에 최고 그냥 말해뭐해 에요 정말 질이 좀 떨어지는 토너들은 그냥 종말 물바르는건가 싶기도 하고 시간이 지날수록 얼굴이 마르는 느낌인데 이 토너는 그냥 바를때부터 깊게 흡수되는 느낌이에요 향도 정말 예민한 사람인데도 향이 참 좋더라고요.. 정말 인생 토너 강추한다 이 말이에요',
#  '토너향이 너무 좋음 헬스하고 나서보습력도 괜춘',
#  '남친 선물로 샀는데 엄청 좋아해요 촉촉하고 향도 괜찮아요',
#  '여름에 이거 하나만 발라도 보습이 충분해지는 느낌 향이 강해서 향수 뿌린것 처럼 얼굴에서 냄새 나고 개인적으론 아저씨 냄새 될랑 말랑하는 냄새 그냥 흔히들 알고 있는 남자 스킨 냄새 발림감이 산뜻하고 좋네요',
#  '수분감이 부족햇던 때에 썻었습니다 세정 후 이것만 발라도 꽉 채워주는 느낌이라 면도 후에도 잘 썻엇네여 자체 애프터쉐이브 효과 대박 ',
#  '신랑이 끈적이는걸 싫어해서 요것만 써요 향은 좋아요',
#  '전 좀 끈적였는데 자극은 덜 하긴 했어요',
#  '정석 남자스킨냄새 건성은 사용 어려울듯... 머 비오템 전부 다 그렇지만요 저자극이긴 해여',
#  '시원하고 순하고 자극없어서 아주 잘 씁니다 ',
#  '인천공항에서 토너 로션 아이크림 세트로 구매하였고 운동후에 사용중입니다. 자극도 덜한 편이고 수분감을 채워줍니다 향도 마음에 들고요 운동이나 야외활동 하고 샤워후에 사용하니 너무 좋습니다 ',
#  '남친한테 선물해줬는데 유분기는 많으면서 엄청 건성이라 지멋대로였음  피부가 좀 안좋은 편이였는데 이거 쓰고 회복중, 귀차니즘이시라 내가 맨날 바르는걸 꾸준히 관리함  진짜 남성 스킨 인생템이다 거기다 내가 선물해줬지만 향도 너무 좋고 바르고 나면 맨날 코박고 안고있음. 너무 매력적이다 피부에도 도움 많이 돼고, 트러블도 많은데 유분기 심하지 않아서 역효과도 없고 너무 좋음. 가벼워서 발림성도 좋다. 하지만 겨울은 좀 많이 건조해지는 계절이라 수분크림을 같이 쓰거나 다른 토너 써야할거 같긴함 그래서 내 수분크림을 건내주었지  ',
#  '비싼 가격 만큼 아주 훌륭한 제품 향도 좋고 끈적임도 덜해서 만족스럽다',
#  '여친이 사줘서 쓰는중인데 3년째 아이오템것만 쓰다가 이걸로 갈아탐',
#  '짱. 완전 좋음. 비싼것이 흠',
#  '남친이 뾰루지올라와서 면세찬스로 티쀼르 세트사줌 증정용으로따라옴 냄새는 남자스킨냄새 내코엔 다 똑같음 효과는 잘모르겟음 쿨링느낌이 강함',
#  '여름철엔 괜츈하네요',
#  '와타시노 남친 30대 후반. 일평생 스킨 로션 같은 거 안바르고 살았다길래 경악해서 선물해줌. 근데 타고나길 피부가 좋은 건지 트러블 하나 없고 뽀얀 피부였음. 스킨 로션 안바르고 잘 살아왔는데 행여나 내가 준 거 바르고 피부 뒤집어지진 않을까 걱정했는데 엄청 잘 쓰고 있음. 본인도 피부가 부드럽고 촉촉해졌다고 매우 만족하며 사용 중. 이거랑 같이 사서 쓰게 한 제품들도 리뷰하러 가야징.',
#  '가격대는 있지만 향도 좋고 흡수가 잘됩니다 좋네요',
#  '남편 주려고 샀는데요. 남편도 좋아하고 꾸준히 사용하는 토너에요 비오템이 남자든 여자든 가볍게 바르기 좋은거 같아요',
#  '특유의 비오템 향이나서 좋음 근데 쫌 번들거리는 느낌이 있음',
#  '여름철 지친피부에 너무좋아요',
#  '남친 선물해줬는데 오빠가 향이 좀 쏘는 그런 향이라고 하는데 시원하다고 하네요 끈적이지 않고 흡수는 빠른데 정말 촉촉하대요',
#  '향좋고 빠르게흡수되요 근데 막 너무무난한느낌',
#  '좋아요 얼굴이 환해지는 느낌받음',
#  '비오템 시원하고 좋습니다 끈적거림도 없고 보습력도 좋은듯 향도 깔끔하네요',
#  '향도 좋고 끈적거리지 않아 자주 애용하는제품입니다. 보습효과가 좋아 로션대용으로도 사용하고 있습니다. 뚜껑이랑 통이 아다리가 안맞아 줄줄 새는점 말곤 다 좋네요.',
#  '키엘만의 피부가 좋아지는 자연스러운 토너에요. 카렌듈라 잎이 피부 속 끝까지 부드럽게 잡아주는 느낌이 들 정도로 키엘에서 유명한 제품이라고 생각합니다 칼렌듈라 폼클렌저도 좋지만 이 토너와 함께 사용한다면 더 부드러운 피부를 만들수 있어요',
#  '그냥그래요..그리고 안에 들어있는 건더기.. 저는 너무 비위 상합니다 윽',
#  '제 피부엔 너무 잘 맞았어요 향도 홍차향처럼 좋은 향이 나고 제형은 완전 물 같은데 신기하게 보습감이 느껴졌어요. 다른 물같은 토너들은 바르고 나면 건조하다고 느꼈었거든요 그래서 꾸준히 사용하고 싶은데 가격이 나가는 편이라 좀 아쉽네여',
#  '뭐가 좋은건지 잘 모르겠지만 확실히 순한 건 맞는것같아요. 아세톤이 없는건지 잘 모르겠지만 상처난 부위에 토너가 지나가더 따갑지 않아요. 양도 잘 안줄어서 냉장고에 넣어놓고 토너팩으로 쓰면 좋을것같아요',
#  '꿀물향같은게 나는데 왠지 기분 좋아요  가끔 화장솜에 적셔서 얼굴에 올려놓으면 피부가 부들부들하고 넘 좋아요',
#  '솔직히 쓸게요... 수부지 피부입니다 백원도 할인 안받고 정가 주고 사서 썼는데요 뭐가 좋다는건지 1도 모르겟어요 저는 모든 스킨을 화장폼에 부어서 닦아내면서 사용하는데 방법이 잘못된건가요 아까워서 한통 다 쓰고 딴 스킨으로 바꿨습니다',
#  '원래 sk2를 사용하다가 갈아탔는데 순한거같기는 하나 그렇게 피부가 좋아지는데 도움을 주는거는 크게 못느꼈어요 무난한 사용감이긴해요',
#  '가격이 좀 쎄긴 하지만 가격값 하는 것 같아요. 2년전에 얼굴에 뭐가 많이 나서 좋은거 없나 찾아보다가 이거 쓰기 시작했는데 정착하고 있어요. 트러블도 확실히 줄었고요',
#  '면세로 항상 대용량으로 구입하는 제품 제가격 주고 사기엔 가성비가 떨어지지만 면세점 가격정도면 항상 쟁여두고 쓸 가치가 있는 제품 피부가 예민해져있을때 진정하는 용으로 좋음',
#  '면세찬스로만 구입해야하는..근데 너무 좋은 얼굴에 열내려주거나 자극받았을때 스킨팩해주면 진짜 좋아요',
#  '너무 따가워요... 쓰다보면 나아지겠거니 했는데 똑같이 따가워버려... 이 제품 쓰면서 정말 하나도 안 따가울 수가 있나요 피부과에서 필링하면 지옥같은 고통이 한 차례 지나가고, 남아있는 잔고통 정도의 따끔함... 전 포기요',
#  '좀 비싸서 살 때 손 떨리지만 막상 사고 나면 잘 쓰는 제품 가격 때문에 다른 거 잠깐 사용하다가도 이만한 게 없다 싶어 다시 사용하게 됨 그래도 아까워서 아직 스킨팩은 한번도 못해봄... 향은 썩 향기로운 향은 아니지만 딱 꽃잎 같은 냄새 스킨 다 써갈 때 쯤이면 내용물에 있는 꽃잎들도 같이 나온다 비주얼은 좀 그렇지만 민감성 피부에 짱짱인듯',
#  '좋아요 좋아요  피부가 완전 뒤집어졌을 때 피부에 좋다는 토너들을 찾다가 우연히 발견하게 되었습니다 가격은 엄청나게 비싸지만 그래도 한 번 써볼만 해요  쓸 때 살짝 따가울 때도 있지만 괜찮은 것 같습니다 ',
#  '굳이 이걸 써야하는점을 못느꼈음 아무런장점도 단점도 못느낌',
#  '가격만 놓고 보면 정말 별로인데 사용하다보면 꽤나 피부에 잘 맞아서 쭈욱 쓰게 되는 토너입니다.  진정효과가 좋고 자극이 없다는 점, 은근히 촉촉하다는 부분이 만족스러워요. 저는 화장솜으로 닦토 한 차례하고 손에 덜어서 한 번 촵촵 흡수시키는데 때때로 피부 자극이 심한 날엔 크림으로 마무리하지 않아도 심하게 건조하지 않아서 좋더라구요.  다만 사용하다보면 자꾸 꽃잎이 나와서 귀찮아요 ',
#  '그냥 순하고 닦토하기 좋은데 자꾸 꽃잎이 나와요.. 이 정도 느낌으로 쓰려면 솔직히 로드샵에서도 많이 구하실수 있을거 같아요',
#  '괜찮게 쓸만해요. 그냥 솜으로 닦아내는데 그냥저냥 쓸만은한데 다른 저렴이들 중 괜찮은 것들이랑 큰 차이가 없네요. 평범무난',
#  '비싸게 샀는데 쓰자마자 바로 뒤집혔습니다',
#  '거의 10통넘게 쓰고있음. 가벼워서 안쓴거랑 별 차이 없다고 느낄 수도 있겠지만 화장솜으로 한 번 닦아내고 토너그대로 얼굴에 챱챱 흡수시캬주면 좋음. 가볍게 쓰기좋다',
#  '친구가 엄청 좋다고 추천해줘서 면세 찬스로 시중가격보다 저렴하게 사서 사용해봤어요 트러블 피부에 좋다고 입소문이 나서 잔뜩 기대하고 써봤어요 그치만.....저에겐 딱 물같은 느낌이었습니다... 좁쌀트러블은 여전했고, 한통 다 쓸때까지 딱히 좋은지 모르겠더라구요 제 친구한테는 인생템이었지만, 저는 잘 모르겠습니다',
#  '그냥저냥 보습도 잘되고 냄새도 좋고 나쁘지 않은 토너였어요 근데 가격대비로 치먄 그렇게 좋지는 않은것 같구요...',
#  '좋아요 비싼만큼 촉촉하고 정말 좋습니다 키엘 최고',
#  '제일 유명하고 좋은 토너래요.. 하지만 1년 동안 계속 쓰고 있는데도 모공 수축 효과 잘 안 보이고 돈이 아깝다 ',
#  '가격 빼고는 다 좋은 토너에요. 토너 바르면 피부가 촉촉해져요. 가격 때문에 쓰기 망설여져요 ',
#  '가격만 조금 저렴했다면 ,,,, 갑자기 피부 뒤집히거나 하면 화장솜에 아침저녁으로 팩 하듯이 해주면 며칠안에 금방 괜찮아져서 좋았는데 ,,, 팩처럼 너무 막써서 그런지  너무 빨리 다써서 면세점에서 사기 딱 좋은 제품입니다',
#  '피부가 지성이면서 민감성이라서 오랫동안 시행착오를 겪다가 정착한 아이에요 가격이 있는 편이라서 면세찬스로 쟁이고 있습니다 저와같은 피부타입이신 분께 추천해요',
#  '순하고, 끈적임 없고, 수분도 적당히 채워주는 느낌이어서 재구매는 해볼 생각이에요 ',
#  '여드름에 좋다고 추천받아서 썼는데 딱히 효과는 못 느꼈어요. 이거도 사람마다 다른건지 그냥 여드름이 더 나진 않지만 나아지게 하는거도 아닌 느낌',
#  '피부에 트러블이 올라 왔을 때 썼는데 그 다음 날 진정된 느낌을 받아서 좋았음',
#  '흡수 빠르고 까먹고 크림안발라도 그다지 당김없음 화장대 디피용으로도 넘 예븝니다 근데 냄새는 도무지 적응이안됨....',
#  '한통을 다 쓰긴 했는데 재구매 의사 없구 카렌듈라 들어간건 안사요..',
#  '그저 물이군요. 이 쯤 끝내야 꽃잎이 예쁘게 남을 것 같으니 그만 쓸게요. 차라리 장식품으로 남아주시어요. 키엘 당신은 내게 인생클렌저 하나와 수많은 쓸모없템들을 동시에 안기는 모순 덩어리.',
#  '저는 이게 제 인생 토너인거같아요 냄새는 되게 별로고 꽃잎도 올굴에 잘 묻어나는데 이거만큼 피부진정에 좋은 애가 없어서 떠날수가 없네요  가겨은 비싸긴한데 면세가는 살만하고 면세점에서 구매하면 클렌자도 주니까 면세에서 사세요',
#  '홍차냄새 같은게 남 이 토너는 지성한테 좋다길래 써볼수 밖에 없엇음 근데 파라벤이 들어잇엇다니   그러나 토너만 발라도 넘 기름졋는데 이거 바르면 피부 깔끔한 느낌 나고 여드름도 안나여  근딩 250미리짜리 삿는데 1달이면 다쓸듯  아껴써야징',
#  '토너로서의 기능에 충실하다 하지만 너무 비싼가격... 피부 진정시키기에 참 좋다 그러기에 참 비싸긴하다 스킨팩하기에도 좋고 7스킨하기에도 좋다 근데 좀 많이 비싸다...',
#  '여름이 되면 속당김이 심해 항상 사용하는 제품. 성분이 순해 진정도 되고 속당김도 좋아짐',
#  '좁쌀여드름이나 뾰루지가 나올때 솜에 적신 토너로 진정해주면 좋습니다 워낙 천연성분으로 유명한브랜드라 믿고 사용하고 있습니다 사용감 자체는 산뜻한거 보다는 쫀쫀했습니다 가격대가 워낙 있는 브랜드라 양도 적고 사용하기 아까워요 가성비 생각했을때 별로라고 생각이 드네요',
#  '꽃잎이 들어있대서 한번 써봤는데 생각보다 촉촉하지 않고 건조해요이니스프리 블루베리 토너랑 비교해서 꽃잎이 나오는건 신기한데 가격 생각하면 재구매는 안할...',
#  '매우 비싼 제품이죠...면세점으로 샀는데 저에게 여드름을 선사한 제품... 만약 자신이 민감하다면 추천을 안드립니다 이 꽃자체가 안맞나봐요',
#  '토너를 딱 보면 그냥 일단 너무 이뻐요 저는 건성이라 기초를 단단히 하는편이에요 스킨 단독으로 쓰지 않기 때문에 당김은 모르겠었고 사용감 무난했어요 향도 그럭저럭.. 화장품 아무거나써도 트러블 거의 안나는 피부에요 스킨 팍팍 쓰고 싶은데 가격때문에 신경쓰여요',
#  '역시 비싼건 비싼데 이유가 있죠 속당김 해결이 엄청 돼요 몇 번 두들겨주면 다른 제품 없이도 스킨로션 다 바른 느낌 향은 약간 나무차 향이 나는데 그건 화장 하고 나면 다 없어져서 괜찮고 근데 안에 들어있는 꽃이 거슬려요',
#  '토너 안에 진짜 꽃잎이 들어있어요 이런 제품을 처음 사용해봐서 그런지 신기하고 좋더라구요. 안에 들어있는 꽃잎이 딸려나오기도 해서 뭔가 꽃잎물을 바르는 느낌이 들어서 좋아요.  향은 인공적인 꽃향이 아니라 꽃.자연 그대로의 향이 나요. 약간 차 향 아무튼 허브향 비슷한 향이 나는데 자연적인 느낌이 들어서 좋더라구요  자극적이지 않고 순하면서 건조함도 잡아주고 촉촉해요. 흡수도 잘되고 끈적임이 남는게 없어요.  피부 정돈하고 수분감 보충하는 토너로서 아주  만족스러웠네요  또 좋았던게 피부가 편안하게 진정되는 느낌이 든다는 점이었어요. 주기적으로 트러블이 나는데 그때에는 최대한 제품 가지 수를 줄이고 순한 제품 위주로 쓰는 편이에요. 트러블 나서 예민해진 부분에 스킨팩해서 사용했는데 조금 진정되는 느낌이 들어서 좋았어요 흡수시켜서 사용해줘도 좋고 화장솜에 적혀서 스킨팩으로 사용해도 좋더라구요.',
#  '레이어드해서 바르니까 촉촉한느낌이 나고 확실히 당김이없었어요 근데 여러번 바를정도로 가성비가좋지못해서 아쉬웠어요 그래도 써보니 키엘유명한 이유가있어요',
#  '와 진짜 피부가 한번에 흡수해서 지성인저에겐 찐덕거리지도 않고 산뜻해서 너무좋아요',
#  '선물받아서 사용해봤는데 알코올도 없고 무엇보다 토너이지만 너무 촉촉해요 현재 다 쓰고 있는거 다 쓰고 제돈 내고 사려구요  재구매의사 100 입니당',
#  '성분이 완전 좋은건 아니지만 예민한 피부임에도 불구하고 자극적이지 않아서 데일리로 좋았어요 카렌듈라라서 그런가 향이 좋고 촉촉해서 피부결 정돈이 되서 괜찮았어요.다만 진정효과가 있는지는 모르겠어요. 그냥 닦토로 쓰기 좋은것 같아요',
#  '닦토로 좋은데  가성비가 별로...',
#  '일단 다른 토너들과 다르게 물같은 가벼운 토너임에도 흡수력이 굉장히 좋습니다. 5스킨법을 사용하였는데 산뜻하게 마무리됩니다. 이외에 닦토로 사용하여도, 차갑게 하여 화장솜에 묻혀 토너팩으로 사용해도, N스킨법으로 사용해도 좋았습니다. 닦토로 사용할때는 세안 후 남아있는 잔여물을 말끔하게 닦아주는 느낌으로 정리하는 느낌이 좋았고, 특히 토너를 차갑게 하여 스킨팩을 올려두니 피부의 열감을 내리거나, 진정용으로 사용하기에 너무 좋은 토너 입니다. 카렌듈라 토너 특유의 꽃향이 더해진 토너라서 인위적이지 않아서 좋았습니다.  대용량 토너 가격이 10만원을 넘던데 가격대에 비해 성분이 안 좋습니다. 요새 무 파라벤을 지향하는 시대에 대놓고 파라벤 성분이라니... 심지어 이런 가격에... 제 돈주고 살 것 같진 않습니다. 이 가격대보다 훨씬 저렴한 가격으로 좋은 성분의 토너들은 이미 시중에 충분히 많으니까요  파라벤 성분은 접촉성 피부염 알레르기 피부를 가지신 분들에게 치명적입니다. 또한 저처럼 민감한 피부를 가지신 분들은 샘플로 테스트후 구매사용하시길 권장해드립니다. 처음 3일 정도 사용할때는 피부에 맞는줄 알았습니다. 닦토후에 5스킨법으로 여러번 레이어드해서 바르곤 했는데 어느날 부터인가 볼쪽에 여드름이 하나씩 올라오더니 5일쯤 사용한 날부터는 우수수 올라오더라구여 바뀐 화장품은 키엘 토너 하나뿐이였는데... 아쉽지만 이후로 사용 중단 하였습니다.',
#  '아무래도 가격이 아쉬워 처음 쓰시는 분들은 부담스럽다고 하시지만 저처럼 써본사람은 쓰고나서 가격이 생각이 안난다고 하시는 분들도 많더라구요 일단 피부가 밝아지고 피부결이 좋아진다는 느낌을 많이 받았어요 예전에 써보고 토너 유목민으로 살다가 다시 정착하게 되었는데 피부에 처음닿는 제품이 제일 중요한데 정말 좋은거 같아요',
#  '키엘 다른 제품살때 샘플로 받아서 몇번 써봄 꽃향이나고 용기밑에 꽃잎들도 좀 깔려있고 향 좋음 그러나 나는 토너에게 화장솜에 묻혀 피부정돈하는 정도를 바라지 그 이상의 기능을 바라지 않기 때문에 내 돈주고 이 가격으로 토너를 사지는 않을듯...',
#  '키엘 특유의 깔끔한 패키지가 예뻐요 성분이 완전 순한 건 아니지만, 개인적으로 안맞는 성분 몇개만 피하면 트러블 없는 타입이라 아 제품 잘 쓰고 있어요 흔들면 꽃잎이 하늘하늘 보이는 게 포인트예요 향도 좋고 촉촉하고 데일리로 쓰기 좋은 거 같아요 칼렌듈라 로 만든 화장품중엔 제일 먼저 생각나는 아이템',
#  '성분은 그렇게 좋은건 아니지만 자극적이지 않고 은은한 꽃향이 코를 맴돌며 가벼워 데일리 토너로 딱이다.',
#  '진정효과 있고 수분감도 있고 계속 쓰면 얼굴도 살짝 환해지긴 하는데 4스킨 이상 하면 피부에 자극이 되고, 가격도 비싼 편인데 마지막에 꽃잎이 남아서 자꾸 탈출하는 것도 싫어요.',
#  '나 피부 디게 좋았음 하얗고 잡티도 거의없었음 근데 어느날 갑자기 얼굴에 한두개씩 올라옴 평소와 같이 곧 없어지겠지 하면서 대수롭게 넘김 근데 그게아님 더 심해짐... 그래서 로션 바꿔봄 키엘 수분크림 쓰는중이라 토너도 키엘로 바꿨음 향 좋음 향만 좋음 내얼굴엔 안 좋음 내 얼굴 난리남 칼렌듈라가 나랑 안맞는건지.. 그래도 누가이기나 해보자 하며 끝까지 써봄 냉장고에 넣어서 차갑게 팩처럼씀 첨보단 나아졌지만 나랑은 아닌듯.. 가격대비 너무 별루얌',
#  '여드름이 사용 4달만에 거의 없어져서 완전 추천해요 7스킨하면 쫀쫀해요',
#  '화농성 여드름이 많이 났는데 이거 바르고 완전 좋아졌어요',
#  '여름되면 생각나는 화장품  가격만 덜 사악했으면 좋을텐데  피부진정에 좋은 스킨',
#  '은은한 꽃향이 좋아요. 순해서 좋아요. 근데 마지막에 꽃잎이 자꾸 탈출을 해서 입구에 붙고 말라서 좀 더러워보여요...그거 외에는 좋아요.',
#  '토너라고 다 같은 토너가 아님을 알게해준 제품 비싼 값을 하는 제품  35스킨 하고나면 피부가 정말 완전 촉촉해져요 다른 저렴이 토너랑 그 느낌 자체가 다릅니다 일반 중저가 워터에센스에서도 느끼지 못한 깊은 수분감이 피부에서 느껴지는 신세계를 경험했어요',
#  '저 이거 완전 좋다고 할수있어요 트러블이 가장많이 났을시기에 이것만큼 편안하게 피부에 올릴수있는것도 없었구요 카렌듈라 꽃잎 때문인지 피부진정도 빠르게 되었어요 지금은 피부가 변해서 이게 잘 받지않게되었지만... 그래도 정말 추천하고픈 아이입니다',
#  '여드름 짜고 이걸로 스킨팩했는데 그 짓물을 좀 흡수해주고 피부를 진정시켜주는거 같아요 좋아요 근데 가격에비해 양이 좀 적은거 같아요',
#  '저는 미스트로 사용했는데 얼굴이 화끈거렸어요.그리고 향도 호불호가 갈릴것같아요.',
#  '순하고 산뜻해요 가격은 비싼편이지만 흡수도 잘되고 잘쓰고있어요',
#  '스킨팩할때 좋아요 요즘가치 미세먼지 쩌는날 피부에게 휴식을 주기',
#  '커밋뷰티페스티벌에서 샘플받아 쓰고있는데 우와.이건진짜다. 라는 생각이 뙇. 세안 후 이 토너만 발라줬는데 겉도 촉촉하고 속건조도 잘 잡아줘서 전혀 당김현상 없었어요. 완전 개건성피부인데 앰플이나 크림 발라주지않아도 될 정도 향도 인공향이 아니라서 좋았구요. 가격이 최대 진입장벽인데 본품구매의사 100입니다. 미스트 샘플 같이 받았는데, 본품사서 미스트로 사용할거예요 가격땜에 굿굿',
#  '커밋뷰티 페스티벌에서 받아온 샘플인데 향이 칼렌듈라 꽃잎 냄새가 나는거 같은데 처음에는 조금 거부감이 들었는데 계속 쓰다보니 적응됨 다만 아쉬운건 토너에서 꽃잎도 같이 흘러나와서 얼굴에 붙을때가 있음 나이트용으로는 괜찮지만 메이크업 할때는 좀.... 꽃잎 흘러나오는건 보완되었으면....',
#  '칠스킨하려고 대용량으로 사서 사용중인데 진짜 좋아요 순하고 은은한향기로 바를때마다 기분도 좋아집니다  다만 덜어낼때 꽃잎이 같이 딸려나와서 그게조금 불편해요',
#  '이 토너가 트러블에도 좋고 홍조에도 좋고 여러모로 가격값한다길래 구입해서 지금 2주정도 사용중인데 그냥 무난무난한거 같아요. 찻잎 자연적인 냄새가 나서 향은 너무 맘에 들어요 어차피 토너는 정제수가 전성분의 대다수를 차지할텐데 가격이 좀 아쉽구요..파라벤이 전성분 앞쪽에 위치하는것도 별로입니당.. 이건 왜 그런지 모르겠는데 이 토너는 뭔가 덧바르면 덧바를수록 더 건조한거 같아요  그래서 23스킨만 해주고 있어용 어떤 분들은 꽃잎을 트러블부위에 올려놓으면 진정이 잘 된다길래 시도해봤지만,,, 저는 아닌걸로,,, 써본지 얼마 안돼서 아직 진가를 발휘를 못하는 걸수도 있으니 한달 이상 사용해봐야 할 거 같아요 아직까진 딱히 좋은점도 나쁜점도 없는고 같아요',
#  '꽃잎나온거만 빼면 좋은거 같아요 어느정도 진정도 되고 수분감도 돌고 좋아용 솜에 묻혀서 닦아내거나 미스트 병에 담아서 쓰기도 좋은거 같아요 외국에서만 사서 한국에서 얼마인지 몰랐는데 글픽보고 놀랐어요 비싸긴해도 좋아요',
#  '엄마가 사주셨는데 진짜 좋아요 꽃잎이 가끔 같이 나와서 조금 불편하긴한데 그 점만 빼면 좋습니다.',
#  '아침, 저녁 토너팩으로 사용하기에 정말 좋아욧 피부 자극을 완화시키고, 피부 밸런스를 업해주는데 도움을 줍니당.',
#  '꽃잎이 있어서 좋지만 자극됨',
#  '비싸지만 좋아요꽃잎이 그래로 나와서 뭔가 더 신뢰가 가요 가격만 조금 낮으면 더 좋을텐데 ',
#  '산뜻하게 쓰긴 좋지만 산뜻한 가격은 아닌.. 이가격으로 다른걸 사겠다 싶은 제품',
#  '꽃잎도 들어있고 색도 추출물 같아서 미관상 보기는 예쁜데.. 진짜 별다른 효과를 모르겠는 제품이라 닦토로 써야되는 제형 감안하면 이가격에 이걸 굳이.. 싶은 제품. 키엘은 수분크림임미다 녀러분..',
#  '순하긴한데 크게 좋지도 나쁘지도 않아요',
#  '한동안 계속 썼었지만... 가격에 비해 뭐가 좋은지 모르겠음. 트러블이 난다거나 문제는 없었지만 이 돈을 주고 꼭 이 제품을 사야할지는...',
#  '남편과 함께 쓸 수 있어서 너무 감사한 제품. 순하고 촉촉하고 칼렌듈라 너무 애정해요.',
#  '신랑이 쓰고있는데 한번에 바르니 다른것보다 잘 바르고 흡수가 잘된다해서 더 잘 바르는것 같아요.',
#  '아버지 선물로 사드렸는데 촉촉하다고 만족하세요한번에 모든 제품을 바르는 효과를 가진것이 제일 좋은점인거 같네요',
#  '아버지 생신이라서 사드렸는데 저희 아버지는 항상 세안하고 뭐를 바를지 잘 모르겠고 바랐을때 답답한 느낌을 너무너무 싫어하셔서 안발랐어요 그래서인지 이번 겨울엔 얼굴이 너무 트셔서 이것저것 살펴보고 반트 36.5 스킨 사드렸어요  우선 발랐을 때 특유의 답답한 느낌도 없고 잘 흡수되서 좋다고 하셨어요   그리고 제형이 너무 물이 아니라서 이 제품만 후딱 발라도 얼굴이 땡기지 않는다고 좋아하시더라구요 무난하니 좋아요 추천합니다',
#  '아빠 사드렸는데 올인원이라서 귀찮지않아서 좋다고하더라고요 텍스쳐도 좋았대요',
#  '제가써본게 아닌 저희아빠선물로 사줬다가 좋다고해서 뭐가 좋은지물어봤는데 올인원이라 여러가지안바르고 촵촵바르고 나가기에 좋고 끈적거리지않고 겨울에는 건조할수도 있으나 여름에 바르면 시원하고 촉촉 하다고 좋데요',
#  '처음 써본 올인원 간단하고 좋다',
#  '올인원이라 정말 편하다 그냥 앞에 편의점갈때나 아무렇게 할때 바르면 좋다..',
#  '인터넷에 좋은 평가가 많아 써봤는데 편의성은 일단 보통이싱이긴 하는데 장기적으로 썼을 때 피부결 잡는것은 아무래도 부족한듯 합니다',
#  '친오빠 줬는데 겨울에 쓰기에는 좀 건조한데 여름에는 이거 한개로 충분하다고 좋대요 생소한 브랜드라서 괜찮을까 했는데 이거 쓰고 피부결도 매끄럽고 여름에는 3번 레이어링하면 딱 좋고 중요한 끈적임이 없어서 제일 좋대요',
#  '좋습니다. 병 디자인마저 좋습니다. 향부터 느낌까지 개인적으로 굉장히 마음에 듦',
#  '진심 좋습니다. 친구가 쓰는거 보고 몇번 발라보규 저도 구매해서 쓰는 제품인데 솔직히 최고입니다',
#  '남동생사줬는데 끈적인다고 싫어하더라고요 맨즈라서 오히려 더 산뜻할 줄 알았는데 그냥 오가니언스랑 비교해보니 이게 더 끈적이고 기름졌어요 다음엔 그냥 오가니언스로 사줘야겠어요',
#  '이걸로 정착한지 2년째...별다른 트러블 없음',
#  '지성인 피부에 잘맞고 후각에 예민하시는분들은 이걸로 사용하시면 좋아요 긴말은 필요없습니다 한번 써보세요 강추',
#  '원래 키엘 남성라인 썼었는데 오래써서 함 바꿔보자고 해서 바꿔봤는데요 남편한테 물어보니 촉촉하니 좋다고 하네요  아 근데 스킨이 물스킨이 아니고 콧물형 스킨 이라서 남자들 면도후에 약간 에프터쉐이브처럼 쓸수있는건 아니라서 살짝 아쉽다고 하네요',
#  '남자친구가 좋아해요 피부에 편하고 괜찮다네요 성분도 괜찮고 좋아요',
#  '동생이 알레르기피부라 이거만쓰는데 촉촉하고 순하고 정말 좋다고하더라구요',
#  '원래 스킨썼을때 안맞으면 화끈거리는 증상이 있는데 피부가 안정적으로 받아드리고 부담없는향이라 강추요',
#  '우리집 가족들이 사용하고 있는 제품입니다. 알콜향이 강한 남자스킨 향이 아니라, 향도 발림성도 너무 좋네요. 훨씬 순한느낌이에요.',
#  '향이 정말 유혹적이고 남친도 정말 좋아하고 남친얼굴에 계속 뽀뽀하게 만드는 제품이에요',
#  '냄새도 없어서 아저씨향이 아니라는게 좋고, 확실히 순해서 남자친구가 여드름이 줄었어요',
#  '아빠한테 선물했는데 향도 은은하고 촉촉해요 프리메라 순해서 더 믿음이가요',
#  '남동생한테 선물해줬는데 남동생이 좋은거같다며 다쓰고 재구매했어요 앞으로 이걸로 정착한듯  동생은 복합성인거같아요 ',
#  '가격이 싸진 않은데 오히려 역효과만 봤어요. 오히려 트러블이 납니다.',
#  '건성에 민감성인 피부를 가진 저는 바르면 얼굴이 화끈거리고 땡기고 트러블 올라오고 최악이였습니다.',
#  '이런데 리뷰 처음 남깁니다.. 정말 향도 좋고 끈적임도 없고 지복합성 피부에 잘 맞아서 정말 잘 사용중이에요 올인원이라 이것저것 바르기 귀찮아하는 남자들한테 딱인것 같습니다',
#  '1. 용량 펌핑 두세번이면 얼굴에 다 바를 수 있어서 오래오래 쓸 수 있다 2. 가격 올인원이라서 스킨 로션 두 개 값이 아니라 저렴하다 3. 향 진하지도 거북스러운 향도 아니라서 무난하다 4. 내구성 플라스틱이고 펌핑버튼이 매립형이라 떨어져도 잘 부서지지 않는다 5. 접근성 이니스프리 가게가 많고 온라인몰에도 많이 있어서 구하기 쉽다재고도 많다 6. 성분 어지간해서 이거 바르고 트러블같은거 난 사람 거의 없을 것 같다 수분량 부족하게 느껴지지도 많게 느껴지지도 않아서 평상시에만 발라주고 겨울같은 건조한날엔 수분크림과 같이 쓰면 정말 좋다 주변에 많은 사람들이 쓰는데 트러블 난 소릴 아예 듣지도 못했다 혹평하는 것도 못들어봤다 뭐 사람마다 다른 사람도 있겠지만.. 7. 점도 적당히 묽지도 텁텁하지도 않아서 정말 부드럽게 잘 발리고 흡수도 적당하다',
#  '모이스춰만 사주다가 여름이다가와서 남친에게 프레시로 선물해주었는데 좋다네요 봄.여름엔 프레시 가을.겨울엔 모이스춰가 딱입니다',
#  '여름에 사용하기는 좋아요 기름기를 잡아주거든요 하지만 겨울에 사용하기에는 피부가 힘들어해요',
#  '남친한테 추천해줬는데 잘 쓰더라구오  여러개 바를필요 없으니 이런제품이 좋은거같아요 저도 발라봤는데  기름지지도않고 향도 시원산뜻해서 남자들이 좋아할 듯 해요',
#  '아빠 사드렸는데 별로인가봐요 잘 안쓰셔요',
#  '선물로 받아서 쓰게 되었는데 이젠 제가 직접 사서 씁니다. 올인원이라서 여러제품 귀찮게 안발라도 되고 펌프타입이라서 뚜껑 열고 닫는거 없어서 편해요 가격도 이니스프리 세일할때 사면 가성비 굳',
#  '남자들이 쓰기편한 올인원 제품',
#  '남친 선물해줬었는데 귀찮지않고 편하다했다',
#  '트러블 심하고 귀차니즘 가득한 남성에게 무난한 제품 사춘기 남동생이 바르기에 편리했고 무엇보다 중요하다 보습이나 영양이 적절해서 트러블에 안좋은 영향을 끼치지 않음',
#  '남성분들 스킨케어 입문용 제품으로 추천드려요 아무것도 안바르거나 스킨케어 거의 하지 않던 분들이 올인원 제품 찾을 때 추천하고싶어요 무난하게 사용하기 좋고 산뜻하지만 너무 알코올 느낌이 강하지도 않아서 아빠, 오빠 두루두루 잘썼어요  다양한 제품을 많이 써보신 분들이나 건성분들께는 비추드려요',
#  '역시 남성화장품은 올인원이죠  벌 몇년째 쓰고있어요. 제형도 아주 묽지도, 끈적하지도 않아서 좋았고, 수분부족지성인 남편이기 때문에 적당히 촉촉함을 유지하는 제품이라서 만족도가 높습니다. 특히 남성화장품 특유의 향기가 안나서 너무좋아요',
#  '남동생 사줬는데 원래 여드름특히 이마 많이나는 피부였는데 향도 괜찮고 잘쓰고있음 주기적으로 발라주니까 여드름도 좀 들어갔음',
#  '오빠때문에 샀어요 얼굴이 더러워보여서.. 저가 직접 테스터해보고 샀는데 촉촉하고 올인원 에센스로 한번에 하면 되니까 뺏고싶더라고요 남자꺼는 엄청 알콜 막 이럴줄 알았는데 그렇지않더라고요',
#  '남자친구 선물 주기 무난무난한 올인원이에요 향도 진하지 않고 트러블 없이 무난하게 사용했다고 합니다',
#  '피톤치드 캡슐이 들었다고 하던데 그래서 그런지 아주 약간 화한 느낌이 나면서 시원하게 피부에 발리는 느낌이 좋았어요 아빠가 피부에 유분이 많으신 편이라 그런 사용감 덕분에 더 잘 쓰셨던 것 같아요 제 피부는 건성인데 저한테도 잘 맞았어서 피부타입을 딱히 가리는 것 같지는 않아요 쓰기도 간편한 타입이라 좋아요',
#  '극지성피부인 아빠께서 잘 쓰세용 ',
#  '제주도 여행갔다가 이니스프리에서 남친 생각나서 사쥬썼는데 왕조아하더라구요..  남친이 기름뿜뿜 지성피부인데 볼이 하얗게뜨길래 안쓰러워서 일부러 조금 보습될만한 애로 샀어요 남친이 기름이많아서 굉장히 보송보송 프레시한 느낌을 선호하는데 얘두 참 잘썼던거같애요 이거쓰고 볼 하얗게튼거 다 나아졌어요 제가 이니스프리를 조아하기도 하지만 남자들을 위한 기초라인들도 굉장히 잘나온편인거 같애요',
#  '여자친구가 사준 첫번째 올인원 제품입니다. 기름기가 많고 트러블이 간간히 올라오는 제 피부를 알고 여자친구님께서 아무 기념일도 아닌데 흔쾌히 선물하셨지요. 까르륵. 한여름에 썼던거 같은데 만족스러웠습니다. 씻고 나서 피부에 촵촵 뚜둘기면 기분도 한결 산뜻해집니다. 저는 이게 지성피부용인줄 알았는데 나중에 알고보니 복합성피부용이더라구요 뭐 그런거에 연연하지 않고 사랑하는 사람이 준 것이니 잘 썼습니다. 만족도 999999999999',
#  '딱히 좋은지 모르겠어요.. 바르고 나면 금방 번들거리고 그냥 가격대비 싼맛에 쓰고 이것저것 바르기 귀찮으니까 올인원이라 쓰는 그런제품 재구매 의사는 없습니다',
#  '향도 좋고 기름지지않고 산뜻하고 보습력도 괜찮은데... 양이 적다...... 얼굴 크고 지성인 사람은 넉넉하게 쓰기 어렵다',
#  '남친이 극지성인데 향도좋고 이거쓰고 여드름도 덜난다고 했었어요',
#  '트러블에 좋다고 해서 구매한 제품. 향도 괜찮고 발림성도좋고 무엇보다 올인원제품이라 사용하는데 편했지만 트러블에는 전혀 효과를 보지 못했던 제품 겨울에는 좀 건조해서 수분크림이랑 같이 발라야될거같다.',
#  '아빠한테 사줬어요 되게 좋아하시더라구요',
#  '향이 좋아서 계속 재구매해서 사용하는 제품 촉촉하고 수분감 강조되어있어서 잘 사용. 겨울에도 유분기 있는 것을 기피하기 때문에 정말 잘 사용하는 듯  미샤 올인원로션이랑 비교하면 이 제품이 조금더 꾸덕한 느낌이 있고 그쪽이 좀더 머스크한 향',
#  '친구집에서 있길래 써보게되었는데 괜찮았어요. 올인원이 원래 스킨로션이 다들어가있는거라 꾸덕한감이 너무 심하게 있어서 느낌은 안좋았어요.',
#  '오빠 선물로 사줬는데 되게 잘써요 지성피부 20대초반',
#  '귀찮아서 쓰기 시작한 올인원제품중 첫번째 써번 제품임 좋긴 한데 금방 바닥을 보니고 역시나 스킨 로션 에센스 따로 써야 하는게 진리임을 배우게 해준 제품 아주 예전에 썻었던 기억이 나네요',
#  '남친이 진심 화장품관심1도없고 관리도전혀안하는 남자인데 내가신경쓰여서 이니스프리간김에 향 독하지않은걸로 올인원이기도하고 사다줬음 근데향도좋다하고 얼굴에 미끄덩거리는게없는데 안건조하다고 너무좋아함 한달정도지난거같은데 피부트러블안보였음 또사다줘야겠다',
#  '향에 민감하신 아빠 선물로 드렸는데 퇴짜맞지않은 제품. 파우더 향 특히 싫어하시는데 이건 무향도 아닌데 풀향 초록초록한 향이라 통과된듯 특히 하나만 바르면되는게 좋은 점인것같음.',
#  '원래 남성 스킨 로션은 뚜껑을 돌려서 여는 형식이 대부분인데 펌핑형 용기라 너무 좋았고 건성 피부인 저희 아빠가 사용하셨는데, 조금 건조한 감이 없지않아 있었지만 흡수가 빨라 꽤 만족스러우셨대요 아 그리고 아빠가 계속 말씀하셨던건데 향이 독하지 않아서 너무 좋대요 보통 남성 스킨로션하면 머리이플정도로 향이 진한데 이 제품들은 은은해서 아저씨같지 않다고 그러셔서 그냥 무난한 제품 같아요',
#  '일주일간 사용 후 리뷰내용입니다.  장점 1. 향 향이 매우 순하고 독하지 않아 거부감없이 사용 할 수 있는 향 입니다. 2. 진정 피부가 많이 예민해서 어떤 화장품을 사용했는지 따라 바로바로 그 증상이 나타나는데 해당 토너 사용 중에는 시원하고 상쾌한 기분만 나고 거부반응이 일어 나지않았습니다.  단점 1. 휘발성 액체타입의 제형이다 보니 금방날아감을 느꼈고 건조함도 바로 나타나는 현상이 있었습니다. 물론 로션도 함께 사용하겠지만 약간의 점성이 있는 제형이라면 더욱 좋을 것 같습니다.',
#  '평가단리뷰입니다. 같은 라인 토너로션  피부타입  지복합성 트러블피부. 지금은 턱쪽에만 트러블이 있습니다.  제형  묽은 타입에 알코올향이 은은하게 납니다. 엄지손가락에 상처가 있었는데 제품이 닿으니깐 무척 따가웠습니다. 남성용 화장품이라 알콜이 은근 많은듯 했습니다.  로션  흐르지 않을정도로 묽은편. 여름에 바르기 좋게 산뜻한 편입니다.  용기  둘다 펌핑식으로 되어있는데, 손바닥에 대강 뿌려서 바르기 좋습니다.  바른 직후  팔자쪽이 조금 따가웠고 수분은 중간정도. 오가니언스 스킨로션 기준 약간의 당김이 있었습니다. 알코올 함유량이 은근 높은듯 합니다. 피지를 잡아주면서 수분도 앗아가는 느낌이 듭니다. 보습력이 약간 부족한듯 합니다.  하루 후기  기존 남성화장품과 별차이 없습니다. 저같이 예민한 사람은 따가울수가 있습니다. 로션스킨. 스킨은 솔직히 별루고 로션은 괜찮았습니다.  이틀째  사용중단. 집에 온 직후에 선크림을 발랐음에도 불구하고 예민한 부위 콧대 바로옆, 이마로 이어지는 바로위 티자존이 빨갛게 달아올랐습니다. 바르는 느낌은 나쁘지않았으나 햇빛을 그렇게 심하게 맞지않았는데, 더운데서 일하지도 않았는데 달아오른것을 보고 저랑 안맞는 화장품인듯 합니다.   재구매의사  전혀없음. 동일한 가격대의 프리메라 오가니언스 스킨로션이 더 양이많고 더 순하고 보습력 충만한듯 합니다. 아무튼 추가적인 보습이 필요한 제품입니다.',
#  '평가단 리뷰 입니다  당첨되서 남자친구한테 선물해 줬어요 남친은 지성 피부여서 여름엔 산뜻한 느낌의 토너를 좋아하는데 이 제품이 포어 컨트롤 제품이여서 그런지 가벼운 느낌의 촉촉한 제품이라고 하더라구요 그리고 무엇보다 남성 전용 제품인데 향이 강하게 나지 않아서 좋아요 가을 겨울 보다는 여름에 적합한 제품일꺼 같아요 건성이신 분들에게는 조금 보습력이 부족할 수도 있을것 같아요 하지만 지성 분들에게는 추천',
#  '남자친구에게 넘기고 리뷰받음 점성이 부족해서 쓸때마다 바닥에 떨어지는 점은 아쉬움 그러나 보습력과 지속력 우수함 기존에 사용하던 IPKN man 제품에 비해 보습이 오래감 기존 제품을 저녁에 씻고 바르면 아침에 일어나서 얼굴이 땡기는데 이제품은 아침에 일어나서도 얼굴이 안 땡김  재구매의사는  가격보고 결정한다고 ',
#  '안녕하세요 평가단입니다 저는 남성입니다 남성이지만 헤어, 얼굴용 화장품에 굉장히 관심이 많고 제품도 성분,기능 둘다잡을 수 있도록 노력하고 있습니다 올인원은 사용해보니 1봄,초가을에는 손색없을정도로 적당한 느낌입니다 수분보충이 필요한 분은 이거바르고 수분크림 얇게정도 해주시면 적당하다는 생각이듭니다 여름까지도 커버 가능하긴 할 것 같습니다 사용하는양을 줄여서,  2단점으로는 겨울에는 기초단계의 초반부분에 해당하는 보습력이기때문에 무리일 것 같습니다 마찬가지로 이것을 베이스로하고 로션,크림을 덧바르는 것을 추천합니다 둘째로는 안좋은 성분이 좀 많습니다.. 알코올,에탄올도 있어서 사용할땐 청량감이있지만 후에는 건조해지는 특성이있죠 특히 쌓이면 독이되는 원료도 포함하고 있어 저같이 성분을 중요하게 여기는 사람은 기피하게되는,굳이 구매하지않는 제품입니다 이상 솔직후기였습니다',
#  '남자친구에게 일주일간 테스트 해봤어요 일단 남자친구는 그냥저냥한 스킨만 한번 바르고 스킨케어를 끝내는 사람이었는데 일주일간 드라잉 디펜더 올인원 바르더니 피부가 시원하고 촉촉하다며 엄청 좋아했어요. 그리고 세트로 받아서 비비스틱도 함께 사용하길 권했는데 원래 선크림도 안바르던 사람이라서 어색해하다가 이제는 꼭꼭 바르고 다녀요. 자연스럽고 티 안나면서 홍조만 살짝 가려주고 선크림 기능까지 있어서 너무 좋대요 남자는 여자와 피부 타입이 달라서 꼭 남성 전용 스킨케어를 해주어야 한다고 알고 있는데 지성타입에 면도로 턱 부분이 예민하고 울긋불긋, 그리고 볼에 홍조끼와 열감 있으신 남성분들이 사용하면 산뜻하고 시원하게 수분충전 해줘서 좋으실 것 같아요',
#  '일단 저는 피부타입이 조금 변하여 건성에 가까운 복합성입니다 제형은 너무 묽지도 되직하지도 않아요. 스킨90 로션10 느낌입니다. 향은 물티슈 향입니다 에이릴킨 매직노우이트 향과 비슷해요 제품 설명대로 한 번 바르면 바로 흡수되서 끈적거리지는 않아서 좋기는 좋은데 보습력이 좋지는 않은 것 같아요 촉촉하지 않아서 아쉽습니당. 제가 쓰고 피부타입이 지성인 분이 써봤는데 너무 좋다고 했습니다 베이스 제품로션, 스킨, 에센스 등을 얼굴에 바를 수 없어서 다 다른 곳에 발랐는데 이 제품은 한 번에 바르고 할 수 있어서 좋다고 말했습니다 보습력도 좀 있다고 했고요. 지성이신 분들게 추천드립니당',
#  '평가단 당첨을 기회삼아 발라보게 된 제품  먼저 일단 제품을 받고 딱 쓸려고 손등에 짜봣는데 건성전용 로션치곤 묽은 제형이라서 조금 놀랐었지만 얼굴에 발라보니까 묽다고해서 피부에 바로 다 흡수되서 다시 건조해지는게 아니라 피부에선 쫀쫀한 제형으로 변하는 느낌적인 느낌  쫀쫀해서 그런지 이거바르고 베이스 매이크업하면 더 잘먹는다 그리고 무엇보다 일단 각질케어에 한몫하는 제품  원래 봄가을에 피부에 각질올라와서 화장하면 금방떠서 늘 불편했는데 하루전날에 듬뿍바르고 잔뒤에 아침에 이거 한번더 바르고나서 화장하니까 피부표현 완전 대박적으로 그 어느때보다 성공했어요  남성용로션이라서 아빠 드릴까 생각했지만 그냥 내가 쓸게 아빠 ,, 넘 좋은거류 난 진짜진짜 대만족해서 다쓰면 한번더 살의향도 있다는 ',
#  '평가단 제품 제형은 로션과 에센스 그 어딘가.. 에멀젼 같은 느낌.. 향도 좋고 트러블도 유발하지 않는듯한 모양이더라구요. 보습력은 올인원이라는 점을 감안하면 괜찮은것 같구요, 지성분들은 사용하기엔 조금 번들거릴것 같습니다. 보통 여성 화장품에 비하면 역시 못 미치는것 같지만서도 제 피부는 보통 남자 뺨치게 두껍고.. 화장품을 이것저것 안 가리는데 제가 괜찮을 정도면 다들 무난하게 잘 사용하실듯 올인원 치고는 간편함만 내세우는게 아니라 보습력에도 신경 쓴 것 같아 만족합니다. 게다가 양도 많고 용기가 이쁘고 사용하기에 좋아 선물용으로 안성맞춤인듯해요. 무난하게 다들 잘 사용하실듯  추가 구성으로 온 선스틱은 노랗더라구요.. 그래도 그냥 제가 양 조절해서 섀딩용으로 써볼까하는 중입니다. 뜨지고 않고 밀착되고 지속력도 나쁘진 않은데 남자도 얼굴에 그냥 바르기에는 좀 어중간한 색이 아닌가 싶네요. 톤만 여러개 잘 뽑으면 되게 괜찮을것 같아요.',
#  '체험단으로 받아본 제품입니다.  일단 제형은 흰색에 묽은 로션제형이고 올인원이라 그런지 약간의 유분감이 느껴졌어요. 대략 수분4 유분6 정도로 생각되고 보통 남성분들은 건성보다는 지성이 많은걸 감안하면 스킨케어 맨 마지막 단계에 추가하시면 가장 적절하지 않을까 싶습니다. 향도 생각보다 진하지 않은 편이에요.  수분 유지력이나 수분감은 솔직히 여성화장품들 처럼 매우 대단하다거나 뛰어나다는 느낌은 받지 못했어요 그래도 전체적으로 봤을때 평균은 되는것 같네요 개인적으로는 남성화장품은 기본적인 보습력도 무시하고 무조건 간편함만 내세우는 경향이있어서 좀 미심쩍었는데 그정도는 아닌것 같아서 다행입니다. 그래도 이것만 바르고 끝내기엔 수분감면에서 부족할수 있으니 수분위주 제품을 추가해서 쓰시는게 좋을듯 하네요  추가구성으로 받은 선스틱도 생각보다 괜찮았습니다. 여자인 제가 쓰기엔 조금 노랗고 어두웠는데 사람마다 피부색이 다르니 이부분은 테스트 해보시면 될것같네요. 커버력은 거의 없지만 그냥 선스틱이라고 생각하면 적당하고 생각만큼 많이 끈적이지도 않았고 밀착력도 나쁘진 않네요. 심한지성이시라면 되게 금방지워지겠지만 덧바르는게 중요하니 오히려 선스틱 테스트해보시길 추천할게요',
#  '평가단체험 운좋게 평가단체험에 당첨되어서 제품을 받아보았습니다 제형은 하얗고 일반 로션이랑 비슷했습니다 발라봤을때 촉촉하고 두드리면 흡수가 어느정도 됐고 유분이 좀 도는 조금 묵직한 제형인것같아 건성에게 추천드려요 저는 남자친구에게 줄 예정입니다',
#  '체험단 선정되어서 체험해볼수있었습니다 저는 남자친구 선물 해줬구요 남자친구는 티존부위는 지성, 볼 턱은 건성인 복합성 피부입니다 올인원 크림이라 무거운 제형일줄알았는데 생각보다 묽어서 의외였어요 남자친구가 향에 예민한데 향 좋다고 하더라구요 그런데 이틀정도 써보더니 바르고나면 찐득거리는 느낌이 난다고하네요. 그거말고는 같이 온 셋트 구성품들도 다 만족스럽고 좋았습니다',
#  '이것저것 바르기 귀찮을때 하나만 바르면 되니 간편해서 좋았고 깔끔한 용기 디자인과 컴팩트한 용량도 마음에 들었다 다만 건성용이나 전피부용 이라서 그런지 지복합성인 나에겐 살짝 번들거렸다 그래도 좁쌀이나 피부가 뒤집어지진 않았고 올인원이라 보습감이나 기능이 떨어질지 알았는데 아니여서 너무 마음에 들었다 건성에게는 추천',
#  '겨울동안 쓰던 크림이 거의 떨어져 갈 쯤 좋은 기회가 되어서 상품 사용해봤습니다. 제형은 흰색에 로션과 에센스 중간정도 묽기였어요. 올인원답게 보습력이 좋아서 지복합성 피부에게 하나만 발라도 딱히 부족하진 않았습니다. 보습제가 안맞거나 조금이라도 무거우면 좁쌀이 나는 편인데 그런 부작용 없이 깔끔하게 보습 잘 되는 제품같네요. 올인원 제품은 처음 사용해보는데 산뜻한 사용감에 준수한 보습력이 장점인 것 같아요 미백 효과와 주름 개선 효과가 있다는 데 한 통은 다 비워봐야 효과를 알 수 있을 것 같네요. 다쓰고 나면 구매 의향 있습니다.',
#  '평가단 남자친구 줬습니다 남자친구는 아마 중성 귀찮아서 스킨로션 잘 안바름 냄새에 민감 먼저 런칭 기념으로 본품이랑 선 비비 스틱, 그루밍 키트가 같이 들어있었는데요, 본품의 경우 흰 색의 에멀젼 제형으로 향은 거의 없었습니다. 다만 제가 지금 코감기라 냄새에 둔해져있는 상태라 그렇게 느낀 걸수도...  제형은 적당히 수분감이 있고 발랐을 때 끈적임이 크지 않아서 보통 끈적한 느낌 싫다고 스킨로션 안쓰는 남자들도 잘 쓸 것 같아요. 같이 들어있는 선비비의 경우 립스틱보다 좀 큰 크기인데 커버력이나 발림성은 뛰어난 건 아니지만 대충 톤정리 하는 용도로는 알맞을 것 같아요. 다만 비비 안쓰는 남자들한텐 별로일듯. 그루밍 키트의 경우 손발톱 깎이랑 귀이개 등이 들어있는 세트인데 특별한 점은 없지만 생필품이니만큼 잘 쓸 것 같아요 ',
#  '남성용이지만 여성이 사용해도 무난한것 같아요. 저도 화장할때 귀차니즘 발동할때 많거든요. 매일 에센스에 크림 바르는거 귀찮아서 써봤는데. 흡수도 빠르고 뭣보다도 끈적이지 않아서 좋네요. 겨울이지만 보습은 챙기면서 촉촉해서 좋아요 향도 무난하고 오히려 여성제품보다 반했어요',
#  '여드름 있는 트러블 피부에는 안 맞아요 .',
#  '스킨치고는 점성이 있고 로션이라 하기에는 약간 묽고 잘 스며 들어요. 올인원이라서 여러 제품 안 발라도 되서 아빠가 참 편하게 쓰셨습니다. 사요',
#  '남자친구가 몇 년째 쓰는 스킨입니다. 여름에는 이것만 바르고 끝내더라구요. 제가 쓰기에는 이것만 가지고는 부족하지만 스킨과 로션 중간 정도의 느낌입니다.',
#  '18살 남동생이 있는데 귀찮은거 안좋아해서 몇년째 이거 하나만 발랐어요 간편하다고 좋아하네요 근데 요즘은 이거만 바르기엔 건조한가봐요 얼굴이 좀 땡기는것 같다고 뭘 더 찾네요 .. 그래서 라로슈포제 시카플라스트밤까지 바르고 있어요 둘 다 동생이 꽤나 만족하는 제품입니다',
#  '일본 다녀올때마다 두어개씩 사오는데 무난무난함 나쁜것은 하나도 없지만 특별한 좋음은 없다는 점 양으로 치덕치덕하는게 참 조아',
#  '제품명에서 느껴지듯이 스킨처럼 묽으면서 동시에 점성이 있는 제품이에요 콧물제형에 가까운 듯해요. 그래서 아주 약간 끈적이다는 느낌은 들지만 불편할 정도는 아니에요. 또 제형 덕분에 찹찹 피부에 잘 달라붙는 느낌이 들었어요 그리고 겨울보다는 여름에 사용하기 더 적합한 것 같아요 촉촉하기는 하지만 올인원으로 이거 하나만 바르기에는 부족한 느낌이 들었습니다',
#  '피부에 별로 신경안쓰시는 남자분들도 잘 쓸 수 있는 제품이에요. All in one이라 간편합니다 냄새도 나쁘지 않아요',
#  '아빠께 사드렸는데 촉촉하고 바르기 편하다고 좋아하세요. 재구매 의사 있습니다 ',
#  '신랑이 올인원만 써서 잘 쓰고 있는데 겨울에는 다소 부족한 느낌이래요. 봄가을 얘만 쓰다가 겨울엔 크림하나 추가해서 바릅니다.',
#  ' 장점 올인원 제품이라 귀차니즘 남성 분들에게 좋네요 스킨 따로 필요 없이도 수분감이 적당히 느껴져요   단점 사용 후 약간의 속당김이 있어요 건성이신 분들은 전체 도포 후 볼이나 T존에 소량으로 한번씩 더 발라주시면 촉촉함이 오래갈것 같아요   향 은은한 향입니다 약냄새나 꽃냄새는 아니지만 살짝 시원한 느낌이 나는 향이네요   질감 묽어서 주르륵 흐르는 타입이네요 쫀쫀한 타입이 아니라 손억 덜어낸 후에는 바로 얼굴에 바르세요   유수분 밸런스 바르고 얼마 지나지 않아 약간 건조한 느낌이 드네요 봄ㆍ여름에는 하나로 충분하지만 가을이나 겨울에는 질감이 묵직한 유분기 있는 크림을 함께 사용하는게 좋을것 같아요 당김이 있어서 제형이 쫀득한 수분크림도 구매했어요   지속력 바르고 피부 겉표면이 촉촉하긴 합니다 그치만 속에서 당김은 있고 약간 건조해요 한번 흡수 후 소량을 볼이나 T존에 한번 더 바르면 촉촉함이 오래 지속될것 같아요',
#  '남편이 우르오스 노래를 불러서 사줬는데 아주 감탄을 하면서 쓰는 중 바디워시까지 우르오스...스킨로션 이것저것 바르기 귀찮아 하더니 매우 만족하면서 또 다시 구매예정',
#  '맨처음 접했을땐 빠르게 흡수되고 정말 좋았는데 시간이 지나면 지날수록 평범한 느낌임.  스킨로션 두가지를 하나로 합쳐서 좋았는데 겨울철엔 로션을 사용해야 할거 같음.  가격 대비 용량은 커서 오래 쓸 수 있음',
#  '무난하게 쓰기 좋은 템',
#  '아버지 드렸는데 촉촉하고 좋다고 하시더라구요  무난 무난 트러블 안나고 적당히 좋은 템인 것 같아요',
#  '친구네 놀러가서 없는로션 빌려써봤는데 너무좋았습니당 ',
#  '평가단에 당첨되어서 2주동안 써봤습니다. 제형은 흔히쓰는 로션보다 조금 묽습니다. 향도 남자화장품 특유의 시트러스계 향이 안나서 좋았습니다. 흡수가 빨라서 낮에 썬크림을 한 겹 더 올릴때 쓰니까 빨리 스킨케어를 마칠 수 있어서 좋았습니다 다만 밤에는 조금 수분감이 부족해서 티존에만 바르고 다른부위는 다른 제품을 사용했습니다 전체적으로 무난한 좋은 밸런스를 가진 제품이라 생각합니다',
#  '아버지가 써봤는데 되게 만족해 하시네요 일단 하나만 바르면 되니까 편리하고 산뜻하게 잘 발린데요 추천합니다',
#  '너무 그리지해요. 지성피부인데 너무너무 오일리합니다. 향도 그닥 만족스럽지는 않아요. 가격은 좀 쎈 편인데 양은 꽤 있는 듯. 건성이면 모를까 지성피부에게는 절대 추천 안 합니다. 이거 쓰고 모공이 막혔는지 여드름도 더 나는거 같고 홍조도 더 심해졌네요. 조만간 동생한테 넘길 제품. ',
#  '아버지드릴려고신청햇는데 마침되서 써보시게됬어요 아버지피부는 제가봤을때 복합성인것같앗어요 향은 풀향남자화장품스킨향알콜향 그런 냄새가 진하진않지만 나요 묽은 로션느낌에 발랏을태 번들거리지않고 흡수되서 끈적이는느낌자체를별로선호하지않는 아버지께선 만족하셧으나 하나만바르기엔 입가나 볼 주변이 좀건조한느낌이드는거같아요.그래서크림으로부족한부분엔 덧발랐답니다 가격대비 그냥 소소해서 다쓰면 재구매는 안하지않을까싶어요',
#  '평가단 선정되서 배송받자마자 남자친구에서 쓰라고 주고 오늘까지 딱 써본 느낌을 말해달라고 했어요 일단 남자친구는 향이 강한 제품을 정말 싫어하고, 로션을 발랐을 때 쫀득하게 남아있는 느낌을 싫어해요. 바르는 순간 바로 흡수되서 뽀송해져야 좋은거라고 얘기하더라구요. 그래서 이거는 어땠냐니까 너무너무 맘에 든대요 일단 올인원이라 이거 하나만 바르면 되니 덜 귀찮고, 냄새도 그다지 강하지 않아서 너무 좋고, 무엇보다 바르자마자 바로 흡수되서 뽀송뽀송하지만 촉촉한 느낌이라는게 너무 신기하고 좋대요 기초화장품에 3만원이라는 돈을 쓰는걸 아까워 해서 이거 다 쓰고 난 뒤엔 사야할까 말아야할까 고민하길래 다 쓰면 제가 한 번 사주려구요',
#  '많이 손이 가지는 않나봐요  생각보다건조해요 ',
#  '일본여행갔을 때 아빠께 선물드렸던 제품이에요 당첨돼서 엄청 기뻤어요 꾸준히 사용하는 제품이라 더더욱 기뻤던것같아요 일단 올인원이라는 점이 큰 장점이라고 생각해요 뭘 바르기 싫어하는 사람에겐 최고... 건조할까봐 걱정된다면 우르오스에서 나온 중건성용 올인원 바르면돼용 ',
#  ...]

# %%
spacer = ChatSpace()
spaced_texts = spacer.space(texts, batch_size=64)
# Out:
# Loading JIT Compiled ChatSpace Model

# %%
reviews['pre_content'] = spaced_texts

# %%
splitted_texts = reviews['pre_content'].str.split(' ').tolist()

# %%
temp = []
for lst in splitted_texts:
    temp.extend(lst)

# %%
print('unique token count: ',len(temp))
# Out:
# unique token count:  206840

# %% [markdown]
# # 임베딩

# %%
splitted_texts
# Out:
# [['제일', '무난하고', '가볍게', '쓰기', '좋아서', '몇', '년째', '이거만', '써요'],
#  ['남자친구', '선물로', '사줬는데', '그저', '그렇데요', '나쁘지도', '좋지도', '않데요'],
#  ['아빠', '사드렸는데', '저아해여'],
#  ['향이',
#   '좋아요',
#   '근데',
#   '좀',
#   '제',
#   '피부가',
#   '민감해서',
#   '안맞는',
#   '거',
#   '같아요',
#   '좀',
#   '올라오더라고요'],
#  ['가격이', '저렴하고', '냄새가', '안', '쎄서', '좋아요.', '다음에도', '또', '구매할', '것', '같아요.'],
#  ['선물용으로', '사서', '선물했는데', '나름', '만족했는지', '매일', '바른다네요'],
#  ['향이',
#   '청량해서',
#   '좋아요.',
#   '흡수가',
#   '잘되면서',
#   '끈적이지',
#   '않아요.',
#   '지금',
#   '시즌',
#   '잘',
#   '사용중인데',
#   '가을부터는',
#   '건조할',
#   '듯',
#   '합니다.',
#   '가볍게',
#   '쓰기',
#   '좋대요.'],
#  ['피부',
#   '지성이',
#   '어서',
#   '최대한',
#   '안',
#   '끈적거리고',
#   '수분',
#   '보충',
#   '할',
#   '수',
#   '있는',
#   '제품',
#   '찾으려고',
#   '하는',
#   '편인데',
#   '이거',
#   '써보니까',
#   '좋았어요.',
#   '피부',
#   '기름',
#   '클렌징',
#   '폼으로',
#   '세안하고',
#   '이거',
#   '바르면',
#   '저는',
#   '괜찮더라고요.'],
#  ['남치니',
#   '사줫는데',
#   '앞으로는',
#   '이것만',
#   '쓰겟다고',
#   '넘넘',
#   '좋다고',
#   '한다',
#   '남자들',
#   '무거운',
#   '거',
#   '싫어하는데',
#   '텍스쳐도',
#   '좋고,',
#   '수분감도',
#   '좋앗다.',
#   '향도',
#   '나쁘지',
#   '않다.',
#   '가격대도',
#   '용량비해서',
#   '나쁘지',
#   '않은',
#   '편이라',
#   '앞으로',
#   '계속',
#   '이것만',
#   '쓸듯'],
#  ['남자', '화장품', '향을', '중시하시는', '아빠', '선물로', '드렸는데', '만족해하셨네요', '두통째', '사드렸습니다'],
#  ['지금', '오빠가', '쓰고', '있는데', '트러블', '없고', '향기도', '괜찮아서', '애용하고', '있는', '제품이에요'],
#  ['복합성',
#   '피부',
#   '입니다',
#   '생각보다',
#   '별로였습니다',
#   '피부결을',
#   '잘',
#   '잡아주는',
#   '거',
#   '같진',
#   '않고',
#   '생각보다',
#   '많이',
#   '간지러웠습니다',
#   '제',
#   '피부가',
#   '이상한',
#   '걸',
#   '수도',
#   '있는데',
#   '빨갛게',
#   '올라오더라구요'],
#  ['실랑이',
#   '복합성인데',
#   '이거',
#   '쓰고',
#   '진짜',
#   '좋다고',
#   '하네요',
#   '주변에서',
#   '다',
#   '얼굴색이',
#   '좋아졌다고',
#   '해요',
#   '좋아요',
#   '굿이예요'],
#  ['예민한', '분듵은', '트러블', '날', '수도', '있을', '거', '같아요'],
#  ['아빠',
#   '생신',
#   '선물로',
#   '드렸었는데',
#   '향도',
#   '좋고',
#   '아빠가',
#   '완전',
#   '만족하시더라구요',
#   '트러블도',
#   '안났어요',
#   '그냥',
#   '무난템',
#   '선물하기',
#   '좋은',
#   '거',
#   '같아용'],
#  ['가볍게',
#   '바르기',
#   '좋은',
#   '것',
#   '같아요',
#   '향도',
#   '강하지도',
#   '않고',
#   '아빠가',
#   '쓰시는데',
#   '2통',
#   '정도',
#   '쓰셨어요',
#   '무난하게',
#   '쓰기',
#   '좋은',
#   '것',
#   '같네용'],
#  ['제가',
#   '테스터',
#   '써봤을',
#   '때는',
#   '트러블',
#   '안나고',
#   '향도',
#   '괜찮았는데',
#   '남자친구가',
#   '이거',
#   '쓰면',
#   '트러블',
#   '난데요'],
#  ['아빠가',
#   '한',
#   '번',
#   '사시고는',
#   '또',
#   '사셧어요',
#   '향도',
#   '괜찮고',
#   '출근하기',
#   '전에',
#   '가볍게',
#   '바르기',
#   '좋다',
#   '네용'],
#  ['저렴하고',
#   '제품력이',
#   '강하기까지',
#   '하니',
#   '두',
#   '말할',
#   '따위',
#   '없이',
#   '좋으네요.',
#   '가성비가',
#   '좋은',
#   '것',
#   '같네요.',
#   '촉촉하고',
#   '향',
#   '좋고',
#   '대만족'],
#  ['선물로',
#   '드렸는데',
#   '원래',
#   '피부가',
#   '민감하셔서',
#   '선물',
#   '드릴',
#   '때',
#   '고민',
#   '많았는데',
#   '이걸',
#   '쓰시고',
#   '나셔서',
#   '피부가',
#   '가볍고',
#   '좋으시다고',
#   '하네요'],
#  ['편하긴', '하지만', '향이', '세고', '성분도', '순한지는', '잘', '모르겠아요'],
#  ['아버지',
#   '사용하시는',
#   '제품인데',
#   '겨울에',
#   '스킨과',
#   '로션만',
#   '발라도',
#   '충분하다고',
#   '좋아하십니다',
#   '원래',
#   '제가',
#   '준',
#   '화장품',
#   '주로',
#   '사용하시는',
#   '편인데',
#   '이것도',
#   '좋다고',
#   '나중에',
#   '세일하면',
#   '또',
#   '사달라고',
#   '하시네요',
#   '향은',
#   '아빠들',
#   '화장품',
#   '향...',
#   '이고',
#   '트러블도',
#   '없고',
#   '가격도',
#   '세일하면',
#   '싸게',
#   '구입할',
#   '수도',
#   '있어서',
#   '잘',
#   '쓰시는',
#   '제품입니다'],
#  ['사요',
#   '아버지가',
#   '사용하고',
#   '계시는데',
#   '좋아하시는',
#   '거',
#   '같아옹',
#   '아버지',
#   '피부가',
#   '옛날엔',
#   '완전',
#   '지성이셨는데',
#   '피부',
#   '관련된',
#   '화장품',
#   '바꾸시고',
#   '나서부터',
#   '피부가',
#   '더',
#   '좋아지신',
#   '것',
#   '같아',
#   '딸로서는',
#   '기분이',
#   '좋네요'],
#  ['오빠',
#   '선물로',
#   '사줬는데',
#   '진한',
#   '남자',
#   '스킨',
#   '로션',
#   '향이',
#   '아닌',
#   '은은',
#   '한',
#   '향이었어요',
#   '무난하게',
#   '쓰기',
#   '좋을',
#   '것',
#   '같아요'],
#  ['사요',
#   '이번',
#   '설에',
#   '아빠',
#   '설선물로',
#   '드렸어요',
#   '세트를',
#   '팔더라고요',
#   '스킨',
#   '로션',
#   '클렌징',
#   '폼',
#   '해서',
#   '30세일',
#   '하여',
#   '28',
#   '700원에',
#   '팔고',
#   '있어서',
#   '올',
#   '인원',
#   '쓰다가',
#   '함',
#   '바꾸어',
#   '봤습니다',
#   '늘',
#   '쓰던',
#   '제품이라',
#   '촉촉하니',
#   '좋다고',
#   '하시내요',
#   '저렴하게',
#   '사서',
#   '굿이었어요'],
#  ['엥',
#   '이거',
#   '아빠가',
#   '쓰시던',
#   '거,,,',
#   '여기서',
#   '보니',
#   '반갑네용',
#   '뭐',
#   '워낙에',
#   '화장품',
#   '사주는',
#   '거',
#   '가리지',
#   '않고',
#   '잘',
#   '사용하시는',
#   '분이라',
#   '무난하게',
#   '다',
#   '사용하기',
#   '괜찮은',
#   '것',
#   '같아요',
#   '아마',
#   '제',
#   '기억엔',
#   '매장',
#   '직원분께',
#   '추천',
#   '받아서',
#   '샀거든요',
#   '이게',
#   '젤',
#   '무난하게',
#   '잘',
#   '맞으니까',
#   '추천해주신',
#   '것',
#   '같고',
#   '아빠두',
#   '잘',
#   '사용하고',
#   '계셔요',
#   '히히',
#   '피부타입',
#   '가리지',
#   '않고',
#   '두루두루',
#   '사용하기',
#   '좋은',
#   '남성용',
#   '스킨인',
#   '것',
#   '같습니당'],
#  ['오빠',
#   '선물로',
#   '해줬는데',
#   '민감한',
#   '편이여도',
#   '이제품은',
#   '다행히',
#   '피부가',
#   '올라오거나',
#   '그러지',
#   '않더라고요',
#   '무난',
#   '무난하게',
#   '쓸만합니다'],
#  ['아빠한테',
#   '선물로',
#   '사드렸는데',
#   '아빠',
#   '피부가',
#   '거칠했던게',
#   '촉촉해지더라고요',
#   '가격도',
#   '싸고',
#   '진짜',
#   '좋아요'],
#  ['아빠',
#   '선물러',
#   '사드렸는데',
#   '정말',
#   '괜찮타고',
#   '했던',
#   '제',
#   '퓸입니다',
#   '스킨',
#   '찾으시면',
#   '이걸루',
#   '사시는',
#   '게',
#   '어떨까욤'],
#  ['남자친구꺼로',
#   '비오템도',
#   '사보고',
#   '여러',
#   '가지',
#   '사봤는데',
#   '이게',
#   '제일',
#   '순하고',
#   '좋다고',
#   '하더라구요',
#   '냄새도',
#   '좋구요',
#   '여러',
#   '가지',
#   '사보다가',
#   '다시',
#   '돌아오게',
#   '됩니당'],
#  ['저희',
#   '아부지는',
#   '올',
#   '인원',
#   '이런',
#   '거',
#   '별로',
#   '안좋아하셔서',
#   '이거',
#   '로션이랑',
#   '세트로',
#   '사드렸더니',
#   '많이',
#   '좋아라',
#   '하시네요',
#   '아부지',
#   '피셜',
#   '촉촉하고',
#   '안땡기고',
#   '좋다고',
#   '냄새도',
#   '괜찮다고',
#   '하십니당'],
#  ['포레스트...',
#   '제가',
#   '우연찮게',
#   '이',
#   '니스프리',
#   '들려',
#   '파란케이스',
#   '보고',
#   '뭔가',
#   '깔끔해서',
#   '사서',
#   '써봤는데',
#   '정말',
#   '괜찮은',
#   '거',
#   '같아요',
#   '제가',
#   '피부에',
#   '열이',
#   '많은',
#   '편이었는데',
#   '이거',
#   '쓰고',
#   '많이',
#   '진정되고',
#   '피부도',
#   '좀',
#   '사람',
#   '다워져서',
#   '이후에',
#   '애용하는',
#   '스킨이에요',
#   '가격이',
#   '좀',
#   '쎈거',
#   '같은데',
#   '요즘',
#   '남자스킨',
#   '로션',
#   '다',
#   '비싸서',
#   '좋은',
#   '템인듯'],
#  ['이',
#   '제품',
#   '뿐만',
#   '아니라',
#   '이',
#   '니스프리',
#   '특유의',
#   '감귤향이',
#   '나하고',
#   '맞지',
#   '않는',
#   '듯.',
#   '이',
#   '니스프리에서',
#   '감귤향이',
#   '나는',
#   '제품을',
#   '쓰고',
#   '나면',
#   '피부가',
#   '뒤집어지는',
#   '경험을',
#   '함.',
#   '만약',
#   '이',
#   '니스프리',
#   '제품을',
#   '쓰고',
#   '피부가',
#   '뒤집어지면',
#   '향료',
#   '때문일',
#   '수',
#   '있다는',
#   '의심을',
#   '해보셨음',
#   '함.'],
#  ['건조한', '남친', '피부에', '딱', '좋아요', '이번', '겨울에', '또', '사줄', '거에야'],
#  ['저도', '제품', '쓰면서', '피부가', '많이', '좋아졌어요'],
#  ['아빠', '사드렸는데', '잘', '쓰고', '계세요', '무난하게', '쓰기', '괜찮은', '거', '같아요'],
#  ['급하게',
#   '스킨케어',
#   '제품',
#   '사라고',
#   '하면',
#   '살만한',
#   '이',
#   '니스프리',
#   '포맨',
#   '라인.',
#   '여러',
#   '기능성,',
#   '피부',
#   '타입',
#   '별로',
#   '출시되어있긴',
#   '하지만',
#   '전체적으로',
#   '크게',
#   '다른',
#   '점은',
#   '못',
#   '느끼겠고',
#   '그냥',
#   '순하고',
#   '무난하다.',
#   '피부에',
#   '큰',
#   '자극',
#   '없고',
#   '큰',
#   '효과도',
#   '없다.',
#   '급하면',
#   '사고',
#   '아니면',
#   '말',
#   '정도.'],
#  ['순하고', '가볍게', '바르기에', '좋아요', '아빠랑', '같이', '사용하고', '있어요'],
#  ['남편은', '피부가', '좀', '예민한', '편인데', '이거', '쓰고', '따갑다고', '했어요'],
#  ['무난합니다.', '보이는', '것처럼', '파란색이', '시원한', '느낌을', '줍니다'],
#  ['군대',
#   '간',
#   '제',
#   '동생한테',
#   '사줫엇는데',
#   '좋아하네요',
#   '근데',
#   '트러블',
#   '개선',
#   '기능',
#   '같은',
#   '건',
#   '없는',
#   '거',
#   '같네용'],
#  ['겨울에',
#   '코주변',
#   '입주변',
#   '볼따구',
#   '다',
#   '터가지고',
#   '벌겋게',
#   '다니는',
#   '남동생이',
#   '너무',
#   '안쓰러워서',
#   '사줬는데',
#   '좋아요',
#   '건성',
#   '남성분들에게',
#   '좋을',
#   '것',
#   '같습니다',
#   '얼굴에',
#   '뾰루지',
#   '하나',
#   '있던데',
#   '그거',
#   '들어간',
#   '거',
#   '보니',
#   '순한',
#   '것',
#   '같아요',
#   '향',
#   '깔끔'],
#  ['아버지가',
#   '꾸준하게',
#   '쓰시고',
#   '있는',
#   '제품',
#   '향이',
#   '남성들에게',
#   '잘',
#   '어울리는',
#   '향이고',
#   '이',
#   '라인의',
#   '올',
#   '인원',
#   '제품도',
#   '있어서',
#   '그거',
#   '하나',
#   '사드리면',
#   '바르시는',
#   '거',
#   '귀찮은',
#   '분들도',
#   '간편하게',
#   '스킨',
#   '케어',
#   '하실',
#   '수',
#   '있어요'],
#  ['피톤치드',
#   '향이',
#   '나면서',
#   '적당히',
#   '촉촉해서',
#   '좋았어요',
#   '바르고',
#   '나면',
#   '은은하게',
#   '향도',
#   '남아서',
#   '남자들이',
#   '쓰기',
#   '좋음'],
#  ['아부지',
#   '생신이라서',
#   '세트로',
#   '사드렸어요',
#   '건조하고',
#   '각질',
#   '있는',
#   '피부에',
#   'T',
#   '존에는',
#   '기름이',
#   '많고',
#   '주름으로',
#   '걱정중이셨는데',
#   '직원',
#   '추천으로',
#   '사드렸어요',
#   '향이',
#   '조금',
#   '독한',
#   '걸',
#   '좋아하시는데',
#   '전',
#   '독한지',
#   '잘',
#   '모르겠더라고요',
#   '그래도',
#   '아부지가',
#   '좋다고',
#   '하시네요'],
#  ['톡',
#   '쏘지',
#   '않고',
#   '은은한',
#   '향이',
#   '순한',
#   '느낌을',
#   '줘서',
#   '아주',
#   '좋더라구요.',
#   '알코올',
#   '에',
#   '탄올',
#   '성분도',
#   '없어서',
#   '민감성',
#   '피부에',
#   '강추하고',
#   '다닙니다',
#   '이거',
#   '패키지도',
#   '세련되서',
#   '선물용으로도',
#   '아주',
#   '좋아요'],
#  ['이거', '조음', '직접', '써본', '결과', '매우', '만족'],
#  ['성분도',
#   '남자',
#   '꺼',
#   '치고',
#   '순한',
#   '편에',
#   '발림성',
#   '또',
#   '한',
#   '우수',
#   '한',
#   '편',
#   '전체적으로',
#   '모든',
#   '피부에',
#   '무난하게',
#   '사용할',
#   '수',
#   '있음.',
#   '똑같은',
#   '라인에',
#   '초록버전보다',
#   '파란',
#   '버전',
#   '모이스처',
#   '더',
#   '유분감도',
#   '덜하고',
#   '촉촉하니',
#   '좋았음',
#   '무난한',
#   '게',
#   '가장',
#   '큰',
#   '장점이지',
#   '않나',
#   '싶음',
#   '향이',
#   '일단',
#   '매우',
#   '좋았어서',
#   '흔히',
#   '남자',
#   '화장품에서',
#   '나는',
#   '아재향',
#   '같은게',
#   '없음',
#   '선물용으로',
#   '좋음',
#   '초록',
#   '라인보단',
#   '모든',
#   '피부에',
#   '파란',
#   '모이스처',
#   '라인',
#   '추천'],
#  ['이제품은',
#   '로션이건',
#   '스킨이건',
#   '둘다',
#   '짱입니당',
#   '남성의',
#   '향이',
#   '아닌',
#   '향기라고',
#   '해야',
#   '하나',
#   '암튼',
#   '좋아용'],
#  ['스킨', '알콜향은', '없어서', '좋지만', '그린티랑', '차이가', '...'],
#  ['발랐을', '때', '상쾌하고', '향도', '좋네요', '추천합니다'],
#  ['리뷰에',
#   '많이',
#   '보인다.',
#   '군인들이',
#   '많이',
#   '쓴다고',
#   '외박',
#   '나가서',
#   '사서',
#   '들어와서',
#   '전역하고',
#   '난',
#   '지금까지',
#   '계속',
#   '쓰고',
#   '있다.',
#   '좋음.'],
#  ['남자들의', '공용', '스킨이죠'],
#  ['오',
#   '근데',
#   '조아요',
#   '막',
#   '그렇게',
#   '강해서',
#   '따갑지도',
#   '않지만',
#   '제가',
#   '쓰기에는',
#   '충분히',
#   '괜찮았어용',
#   '양도',
#   '많고',
#   '굳굳'],
#  ['기름진',
#   '물',
#   '로션을',
#   '탄',
#   '물',
#   '같은',
#   '느낌',
#   '난',
#   '동생꺼',
#   '썻을',
#   '때',
#   '나쁘지',
#   '않앗당'],
#  ['수분이', '부족한', '남자분들껜', '가성비로', '치자면', '이게', '갑이죠'],
#  ['남편이', '애용하는', '제품입니다.'],
#  ['남자친구', '피부', '많이', '좋아졌습니다', '좋아요'],
#  ['남자친구', '선물', '해줫는데', '매우', '잘', '쓴다', '그래서', '만족중'],
#  ['이번에',
#   '포레스트',
#   '포맨으로',
#   '갈아탔는데',
#   '지금까진',
#   '나쁘지',
#   '않네요',
#   '향도',
#   '좋구',
#   '피부도',
#   '좋아지는',
#   '느낌'],
#  ['효과도', '어느', '정도', '잇는', '거', '같고', '괜춘한', '제품'],
#  ['군대간',
#   '남친',
#   '휴가',
#   '나오더니',
#   '알아서',
#   '이거',
#   '사서',
#   '들어감',
#   '남자들끼리',
#   '모여도',
#   '이게',
#   '좋다',
#   '이건',
#   '별로다',
#   '이야기',
#   '하나봐요',
#   '결국',
#   '남자',
#   '군인',
#   '사이에선',
#   '1등인',
#   '듯'],
#  ['남성',
#   '화장품',
#   '가끔',
#   '향이',
#   '너무',
#   '강해',
#   '불호일',
#   '때가',
#   '있는데',
#   '이거',
#   '쓴',
#   '남편에게서',
#   '그런',
#   '느낌은',
#   '못받았어요.',
#   '만족하며',
#   '쓰고',
#   '있어요.',
#   '재구매',
#   '했고',
#   '다시',
#   '재구매',
#   '할',
#   '계획이예요.'],
#  ['향은', '대체로', '남자향인데', '촉촉하고', '발랏을', '때', '흡수도', '잘되서', '좋아요'],
#  ['건성인',
#   '옆지기가',
#   '쓰기에',
#   '촉촉하고',
#   '무난하게',
#   '쓰기',
#   '좋음.',
#   '제일',
#   '좋은',
#   '건',
#   '향이',
#   '세지',
#   '않다는',
#   '것.',
#   '향수마냥',
#   '독한',
#   '냄새를',
#   '싫어하는',
#   '본인',
#   '취향임.',
#   '첨엔',
#   '낯설어',
#   '하더니',
#   '잘',
#   '씀.'],
#  ['남자스킨은',
#   '거의',
#   '대부분의',
#   '제품들이',
#   '향이',
#   '참',
#   '독한데',
#   '이건',
#   '그렇지',
#   '않아요',
#   '무난',
#   '무난하게',
#   '사용가능함'],
#  ['남자친구가', '너무', '조아해요', '산뜻하면서', '촉촉하고', '무엇보다도....', '간', '편해서', '좋다곸'],
#  ['스킨로션',
#   '전혀',
#   '안바르시는',
#   '아빠한테',
#   '피부',
#   '관리',
#   '안하면',
#   '더',
#   '나이',
#   '들어서',
#   '주름자',
#   '글자글해진다고',
#   '지금부터라도',
#   '기초를',
#   '발라야',
#   '한다면서',
#   '이거랑',
#   '로션',
#   '사드렸는데',
#   '지금',
#   '거의',
#   '다',
#   '써간다',
#   '색깔은',
#   '우유',
#   '같은데',
#   '별트러블',
#   '없이',
#   '무난하게',
#   '쓰시는',
#   '거',
#   '같다'],
#  ['남친에게', '포레스트', '맨', '스킨케어', '세트로', '선물', '줬어요.', '만족하고', '잘', '쓰고', '있습니다'],
#  ['남편이', '쭉', '쓰는', '스킨', '상쾌해서', '좋다고', '함'],
#  ['남자친구', '선물', '해줬는데', '좋아해요'],
#  ['오빠가',
#   '화장품',
#   '뭐가',
#   '좋냐고',
#   '물어보길래',
#   '인터넷에서',
#   '순위',
#   '보고',
#   '세트로',
#   '사다줬는데',
#   '냄새도',
#   '독하지',
#   '않고',
#   '트러블',
#   '약간',
#   '있는',
#   '피부인데',
#   '많이',
#   '안난다고',
#   '무난하다고',
#   '지금',
#   '세트로',
#   '네',
#   '번째',
#   '구매하고',
#   '있네요',
#   '질리지',
#   '않냐고',
#   '다른',
#   '거',
#   '사보라고',
#   '해도',
#   '이게',
#   '좋다고',
#   '안',
#   '바꾸거라고요'],
#  ['구닌',
#   '남친이',
#   '쓰는',
#   '스킨로션',
#   '워낙',
#   '얼굴에',
#   '뭘',
#   '바르는',
#   '걸',
#   '싫어해서..',
#   '근데',
#   '이건',
#   '향이',
#   '정말',
#   '좋아요',
#   '진하지',
#   '않고',
#   '아빠',
#   '스키',
#   '냄시도',
#   '아니고',
#   '은은',
#   '하이',
#   '뽀뽀하고',
#   '싶어지는',
#   '향..',
#   '좋아용'],
#  ['아빠께',
#   '사다',
#   '드렸는데',
#   '잘',
#   '쓰시고',
#   '계시네요',
#   '향도',
#   '괜찮구',
#   '가격대비도',
#   '괜찮은',
#   '거',
#   '같아요'],
#  ['남친', '이거', '쓴다', '가격대비', '짱'],
#  ['친구가',
#   '촉촉하고',
#   '산뜻하다고',
#   '매번',
#   '자기',
#   '남친',
#   '사주는',
#   '제품',
#   '나는',
#   '남친이',
#   '없어서',
#   '옆에서',
#   '조용히',
#   '계산하는',
#   '거',
#   '구경함'],
#  ['남친이',
#   '만족하면서',
#   '써요',
#   '촉촉하면서',
#   '끈적이지도',
#   '않고',
#   '번들거리지도',
#   '않아서',
#   '좋대요',
#   '그리고',
#   '쓰고',
#   '나서',
#   '남친',
#   '피부결도',
#   '확실히',
#   '예전보다',
#   '좋아진',
#   '듯',
#   '예전엔',
#   '아무것도',
#   '안발라서',
#   '그랬던',
#   '탓도',
#   '있겠지만'],
#  ['남자친구',
#   '선물',
#   '해줬는데',
#   '잘',
#   '쓴당.',
#   '그때',
#   '사면서',
#   '화장솜',
#   '샘플로',
#   '받았는데',
#   '남자친구가',
#   '써보고',
#   '좋아서',
#   '나도',
#   '잘',
#   '안쓰는',
#   '화장솜을',
#   '사서',
#   '쓴다..',
#   '굿'],
#  ['어',
#   '버이날에',
#   '아빠',
#   '생신',
#   '선물로',
#   '이거',
#   '세트',
#   '사다',
#   '드렸었는데',
#   '원래',
#   '성격이',
#   '뭘',
#   '잘',
#   '안바르시는',
#   '성격이라',
#   '...T.',
#   'T',
#   '딸래미의',
#   '성의를',
#   '봐서',
#   '몇',
#   '번',
#   '사용하시다가',
#   '귀찮으셔서',
#   '결국',
#   '안바르시고',
#   '화장대에',
#   '덩그러니...',
#   '아까워서',
#   '거즘',
#   '내',
#   '피부에',
#   '사용하면서',
#   '가끔씩',
#   '아빠',
#   '피부에도',
#   '직접',
#   '발라주고',
#   '이랬었는데',
#   '아빠',
#   '나',
#   '나나',
#   '무난',
#   '무난하니',
#   '큰',
#   '트러블',
#   '없이',
#   '잘',
#   '사용했다.',
#   '용량도',
#   '많아서',
#   '넉넉히',
#   '썼는데',
#   '향은',
#   '개인적으로',
#   '계속',
#   '맡다보면',
#   '남성스킨향..',
#   '엄청',
#   '좋아하는',
#   '향은',
#   '아니라',
#   '그냥',
#   '그랬다.',
#   '향',
#   '빼고는',
#   '용량도',
#   '많고',
#   '산뜻한',
#   '타입.'],
#  ['어느',
#   '피부에도',
#   '다',
#   '사용이',
#   '가능한',
#   '스킨인',
#   '것',
#   '같아요',
#   '피부가',
#   '예민한',
#   '저로선',
#   '정말',
#   '좋게',
#   '사용하고',
#   '잇어요'],
#  ['남자친구', '선물로', '줬는데', '되게', '만족스럽다고', '한다'],
#  ['솜과', '함께', '사용하는데', '정말', '만족하고', '있습니다'],
#  ['남편은', '토너', '하나만', '발라도', '충분하다네요', '촉촉한가봐요'],
#  ['남자가', '사용하기에', '무난한', '제품..', '그냥', '일반', '토너', '특별한', '기능', '없음'],
#  ['지성',
#   '피부가',
#   '바르기에',
#   '좋은',
#   '거',
#   '같고,',
#   '건성',
#   '피부엔',
#   '좀',
#   '약할',
#   '듯',
#   '합니다.',
#   '바른',
#   '순간에는',
#   '알콜',
#   '향이',
#   '나는',
#   '편이라',
#   '사람마다',
#   '호불호가',
#   '갈릴',
#   '듯',
#   '합니다.',
#   '그래도',
#   '알콜향은',
#   '금방',
#   '날아가고',
#   '남은',
#   '잔향은',
#   '좋은',
#   '편입니다.'],
#  ['내가',
#   '써본',
#   '토너',
#   '중에',
#   '최고',
#   '그냥',
#   '말해',
#   '뭐해',
#   '에요',
#   '정말',
#   '질이',
#   '좀',
#   '떨어지는',
#   '토너들은',
#   '그냥',
#   '종말',
#   '물바르는',
#   '건가',
#   '싶기도',
#   '하고',
#   '시간이',
#   '지날수록',
#   '얼굴이',
#   '마르는',
#   '느낌인데',
#   '이',
#   '토너는',
#   '그냥',
#   '바를',
#   '때부터',
#   '깊게',
#   '흡수되는',
#   '느낌이에요',
#   '향도',
#   '정말',
#   '예민한',
#   '사람인데도',
#   '향이',
#   '참',
#   '좋더라고요..',
#   '정말',
#   '인생',
#   '토너',
#   '강추한다',
#   '이',
#   '말이에요'],
#  ['이거',
#   '쓴지',
#   '이년',
#   '되어가는데',
#   '넘',
#   '좋아요',
#   '촉촉하고',
#   '바르고',
#   '난',
#   '뒤에',
#   '항이',
#   '정말',
#   '좋어요'],
#  ['선물로',
#   '참',
#   '좋아함.',
#   '일단',
#   '향이',
#   '시원하고',
#   '가볍다.',
#   '마치',
#   '정말',
#   '가벼운',
#   '코롱같은',
#   '향은',
#   '금방',
#   '날아간다.',
#   '나오는',
#   '제형을',
#   '봤을',
#   '때',
#   '에센스',
#   '인줄',
#   '알았는데',
#   '토너였다.',
#   '점도가',
#   '있는',
#   '편이다.',
#   '수분감이',
#   '많고',
#   '제일',
#   '좋은',
#   '것은',
#   '바르고',
#   '끈적이지',
#   '않는다.',
#   '가격이',
#   '조금',
#   '비싸',
#   '별',
#   '하나',
#   '뺌.'],
#  ['아주', '좋아요', '촉촉해서', '좋습니다.', '만족', '짱짱입니단'],
#  ['우리',
#   '아빠는',
#   '향이',
#   '진한',
#   '걸',
#   '싫어해서',
#   '엄마가',
#   '남자용',
#   '스킨',
#   '사주면',
#   '그거',
#   '안쓰고',
#   '엄마꺼',
#   '몰래',
#   '몰래',
#   '사용했는뎈',
#   '이거',
#   '선물로',
#   '사주니까',
#   '향도',
#   '맘에',
#   '들고',
#   '가볍다고',
#   '맨날',
#   '바를',
#   '때마다',
#   '나한테',
#   '와서',
#   '톡톡톡',
#   'cf',
#   '찍으심',
#   '아빠한테',
#   '이쁨',
#   '받을',
#   '수',
#   '있는',
#   '좋은',
#   '제품임'],
#  ['아빠',
#   '템',
#   '사요',
#   '남성화장품',
#   '평소에',
#   '비오템을',
#   '좋아해서',
#   '아빠도',
#   '사드렸는데',
#   '잘',
#   '쓰시더라구요',
#   '토너라서',
#   '가벼운',
#   '사용감과',
#   '진하지',
#   '않은',
#   '향이',
#   '나서',
#   '좋았어욤',
#   '만족'],
#  ['남편이', '연애시절', '부터', '재겨두고', '늘', '쓰는', '제품이에요.'],
#  ['아빠', '생신', '선물로', '보습을', '위해', '사드렸는데', '정말', '좋아하셨어요'],
#  ['남편이',
#   '무난하게',
#   '잘',
#   '맞는다고',
#   '해서',
#   '꾸준히',
#   '사는',
#   '제품이예요',
#   '대신',
#   '가격',
#   '때문에',
#   '면세점에서만',
#   '구입하는',
#   '편이예요'],
#  ['제품은',
#   '무난한데',
#   '향이세고',
#   '가격이',
#   '너무',
#   '쎄여',
#   '피부에',
#   '잘',
#   '맞는다면',
#   '쓰겠지만',
#   '그냥',
#   '무난한',
#   '제품',
#   '같아요'],
#  ['이거', '바르고', '피부', '뒤집어져서', '고생함.....', '유명한데', '저랑은', '안맞는듯'],
#  ['항상',
#   '헬스하고',
#   '나서',
#   '가볍게',
#   '바르는',
#   '제품입니다.',
#   '제가',
#   '지성이다',
#   '보니',
#   '특히',
#   '여름에',
#   '답답한',
#   '것을',
#   '견디지',
#   '못하는데,',
#   '여름에는',
#   '이거',
#   '하나만',
#   '발라도',
#   '촉촉하고',
#   '향기도',
#   '좋아서',
#   '여자친구도',
#   '좋아합니다'],
#  ['이거',
#   '파란색도',
#   '잇음.',
#   '이름은',
#   '아쿠',
#   '아파워',
#   '똑같은데',
#   '통이',
#   '파란색임.',
#   '근데',
#   '말야',
#   '이거',
#   '여름에',
#   '냉장고에',
#   '넣어두고',
#   '쓰면',
#   '스킨브레이서',
#   '만큼',
#   '얼굴',
#   '소독되고',
#   '시원한데',
#   '너무',
#   '얼굴에서',
#   '금방',
#   '마르니까',
#   '양을',
#   '듬뿍',
#   '써야',
#   '함.',
#   '생각해보면',
#   '200ml고',
#   '성분이',
#   '젤이라서',
#   '물타입',
#   '액체보다',
#   '많은',
#   '양이',
#   '필요한데',
#   '엄청',
#   '비쌈.',
#   '54000원은',
#   '아니고',
#   '더',
#   '싸게는',
#   '살수',
#   '있지만',
#   '무슨',
#   '부자집',
#   '도련님',
#   '스킨',
#   '같음.',
#   '너무',
#   '비쌈.',
#   '이거',
#   '좋긴',
#   '한데',
#   '월급이',
#   '300만원',
#   '이',
#   '하이면',
#   '안쓰는게',
#   '나음.',
#   '가격',
#   '성분이나',
#   '원가에',
#   '비해',
#   '너무',
#   '비쌈.',
#   '취향을',
#   '존중하므로',
#   '월급이',
#   '적더라도',
#   '사용하실',
#   '분은',
#   '사용해도',
#   '됨.',
#   '비싸서',
#   '탈락',
#   '그리고',
#   '성분을',
#   '보면',
#   '가격에',
#   '비해',
#   '좋은',
#   '성분이',
#   '아니라',
#   '알러지',
#   '유발',
#   '성분',
#   '등',
#   '안좋은',
#   '게',
#   '있어서',
#   '가격대비',
#   '완전',
#   '탈락',
#   '이',
#   '니스프리가',
#   '요즘',
#   '유해성분이',
#   '거의',
#   '아주',
#   '없는',
#   '것들',
#   '만드는데',
#   '다른',
#   '화장품에',
#   '비해',
#   '가격대비',
#   '제일',
#   '좋음.',
#   '이',
#   '니스프리',
#   '광고하는',
#   '사람',
#   '아님',
#   '진실을',
#   '말하는',
#   '자',
#   '임'],
#  ['쿨링감이나', '보습감은', '괜찮은데', '너무', '비싸요..'],
#  ['아빠께', '사드렸는데', '크게', '좋은', '걸', '못느끼셨데요..'],
#  ['이제품은',
#   '진짜',
#   '오래',
#   '쓰던',
#   '제품인데',
#   '가격이',
#   '좀',
#   '있지만',
#   '그래도',
#   '제품력만큼은',
#   '인정',
#   '하는',
#   '제품입니다.',
#   '최고',
#   '지금',
#   '다른',
#   '걸',
#   '사용하고',
#   '있는데',
#   '기회가',
#   '되면',
#   '다시',
#   '꼭',
#   '써보고',
#   '싶은',
#   '제품이예요'],
#  ['누나가', '사줘서', '써봤는데', '전', '비오템', '화장품', '향기가', '좋더라구요..'],
#  ['토너', '향이', '너무', '좋음', '헬스하고', '나서', '보습력도', '괜춘'],
#  ['남친', '선물로', '샀는데', '엄청', '좋아해요', '촉촉하고', '향도', '괜찮아요'],
#  ['여름에',
#   '이거',
#   '하나만',
#   '발라도',
#   '보습이',
#   '충분해지는',
#   '느낌',
#   '향이',
#   '강해서',
#   '향수',
#   '뿌린',
#   '것',
#   '처럼',
#   '얼굴에서',
#   '냄새',
#   '나고',
#   '개인적으론',
#   '아저씨',
#   '냄새',
#   '될랑',
#   '말랑하는',
#   '냄새',
#   '그냥',
#   '흔히들',
#   '알고',
#   '있는',
#   '남자',
#   '스킨',
#   '냄새',
#   '발림감이',
#   '산뜻하고',
#   '좋네요'],
#  ['수분감이',
#   '부족햇던',
#   '때에',
#   '썻었습니다',
#   '세정',
#   '후',
#   '이것만',
#   '발라도',
#   '꽉',
#   '채워주는',
#   '느낌이라',
#   '면도',
#   '후에도',
#   '잘',
#   '썻엇네여',
#   '자체',
#   '애프터',
#   '쉐이브',
#   '효과',
#   '대박'],
#  ['신랑이', '끈적이는', '걸', '싫어해서', '요것만', '써요', '향은', '좋아요'],
#  ['전', '좀', '끈적였는데', '자극은', '덜', '하긴', '했어요'],
#  ['정석',
#   '남자스킨',
#   '냄새',
#   '건성은',
#   '사용',
#   '어려울듯...',
#   '머',
#   '비오템',
#   '전부',
#   '다',
#   '그렇지만요',
#   '저',
#   '자극이',
#   '긴',
#   '해여'],
#  ['시원하고', '순하고', '자극', '없어서', '아주', '잘', '씁니다'],
#  ['인천공항에서',
#   '토너',
#   '로션',
#   '아이크림',
#   '세트로',
#   '구매하였고',
#   '운동후에',
#   '사용중입니다.',
#   '자극도',
#   '덜한',
#   '편이고',
#   '수분감을',
#   '채워줍니다',
#   '향도',
#   '마음에',
#   '들고요',
#   '운동이나',
#   '야외활동',
#   '하고',
#   '샤워',
#   '후에',
#   '사용하니',
#   '너무',
#   '좋습니다'],
#  ['남친한테',
#   '선물해줬는데',
#   '유분기는',
#   '많으면서',
#   '엄청',
#   '건성이라',
#   '지멋대로였음',
#   '피부가',
#   '좀',
#   '안좋은',
#   '편이였는데',
#   '이거',
#   '쓰고',
#   '회복중,',
#   '귀차니즘',
#   '이시라',
#   '내가',
#   '맨날',
#   '바르는',
#   '걸',
#   '꾸준히',
#   '관리함',
#   '진짜',
#   '남성',
#   '스킨',
#   '인생템이',
#   '다',
#   '거기다',
#   '내가',
#   '선물해줬지만',
#   '향도',
#   '너무',
#   '좋고',
#   '바르고',
#   '나면',
#   '맨날',
#   '코박고',
#   '안고',
#   '있음.',
#   '너무',
#   '매력적이다',
#   '피부에도',
#   '도움',
#   '많이',
#   '돼고,',
#   '트러블도',
#   '많은데',
#   '유분기',
#   '심하지',
#   '않아서',
#   '역효과도',
#   '없고',
#   '너무',
#   '좋음.',
#   '가벼워서',
#   '발림성도',
#   '좋다.',
#   '하지만',
#   '겨울은',
#   '좀',
#   '많이',
#   '건조해지는',
#   '계절이라',
#   '수분크림을',
#   '같이',
#   '쓰거나',
#   '다른',
#   '토너',
#   '써야',
#   '할',
#   '거',
#   '같긴',
#   '함',
#   '그래서',
#   '내',
#   '수분크림을',
#   '건',
#   '내주었지'],
#  ['비싼', '가격', '만큼', '아주', '훌륭한', '제품', '향도', '좋고', '끈적임도', '덜해서', '만족스럽다'],
#  ['여친이', '사줘서', '쓰는', '중인데', '3년째', '아이오템것만', '쓰다가', '이걸로', '갈아탐'],
#  ['짱.', '완전', '좋음.', '비싼', '것이', '흠'],
#  ['남친이',
#   '뾰루지',
#   '올라와서',
#   '면세찬스로',
#   '티쀼르',
#   '세트',
#   '사줌',
#   '증정용으로',
#   '따라옴',
#   '냄새는',
#   '남자스킨',
#   '냄새',
#   '내',
#   '코엔',
#   '다',
#   '똑같음',
#   '효과는',
#   '잘',
#   '모르겟음',
#   '쿨링',
#   '느낌이',
#   '강함'],
#  ['여름', '철엔', '괜츈하네요'],
#  ['와',
#   '타시노',
#   '남친',
#   '30대',
#   '후반.',
#   '일평생',
#   '스킨',
#   '로션',
#   '같은',
#   '거',
#   '안바르고',
#   '살았다길래',
#   '경악해서',
#   '선물해줌.',
#   '근데',
#   '타고나길',
#   '피부가',
#   '좋은',
#   '건지',
#   '트러블',
#   '하나',
#   '없고',
#   '뽀얀',
#   '피부였음.',
#   '스킨',
#   '로션',
#   '안바르고',
#   '잘',
#   '살아왔는데',
#   '행여나',
#   '내가',
#   '준',
#   '거',
#   '바르고',
#   '피부',
#   '뒤집어지진',
#   '않을까',
#   '걱정했는데',
#   '엄청',
#   '잘',
#   '쓰고',
#   '있음.',
#   '본인도',
#   '피부가',
#   '부드럽고',
#   '촉촉해졌다고',
#   '매우',
#   '만족하며',
#   '사용',
#   '중.',
#   '이거랑',
#   '같이',
#   '사서',
#   '쓰게',
#   '한',
#   '제품들도',
#   '리뷰하러',
#   '가야징.'],
#  ['가격대는', '있지만', '향도', '좋고', '흡수가', '잘', '됩니다', '좋네요'],
#  ['남편',
#   '주려고',
#   '샀는데요.',
#   '남편도',
#   '좋아하고',
#   '꾸준히',
#   '사용하는',
#   '토너에요',
#   '비오템이',
#   '남자든',
#   '여자든',
#   '가볍게',
#   '바르기',
#   '좋은',
#   '거',
#   '같아요'],
#  ['남자',
#   '화장품',
#   '특유의',
#   '강한',
#   '알콜향이',
#   '아닌',
#   '상쾌한',
#   '향이',
#   '좋아서',
#   '자주',
#   '사용한다고',
#   '함',
#   '발림성도',
#   '좋지만',
#   '가벼운',
#   '텍스처라',
#   '겨울보다는',
#   '여름에',
#   '추천함'],
#  ['향이', '너무', '좋아요', '최고입니다'],
#  ['남자친구',
#   '선물했는데',
#   '약간',
#   '생긴',
#   '게',
#   '순하게',
#   '생기고향도',
#   '무난할거라고',
#   '생각했는데',
#   '생각보다',
#   '남자스킨',
#   '냄새',
#   '나는',
#   '스킨이었고',
#   '남친이',
#   '여성화장품',
#   '또는',
#   '자극',
#   '없는',
#   '순한',
#   '제품을',
#   '선호하는',
#   '편이어서',
#   '그런지',
#   '별로',
#   '좋아하는',
#   '거',
#   '같지',
#   '않았어요',
#   '생각보다',
#   '화한',
#   '느낌이라고',
#   '했고',
#   '저',
#   '자극은',
#   '아닌',
#   '듯'],
#  ['냄새',
#   '맡는',
#   '순간',
#   '알콜',
#   '냄새',
#   '확..',
#   '알콜',
#   '샤워에',
#   '자극적이고',
#   '지성피부도',
#   '건조하게',
#   '만드는...',
#   '열대국가',
#   '사람에게',
#   '나',
#   '추천할만한...'],
#  ['신랑한테',
#   '세트',
#   '사줬더니',
#   '너무',
#   '좋아함.',
#   '하지만',
#   '비싸서',
#   '기념일',
#   '선물로만',
#   '사줄',
#   '예정.',
#   '향도',
#   '내가',
#   '좋아하는',
#   '스킨향이고',
#   '멋있어',
#   '보이는',
#   '효과가'],
#  ['바르면', '촉촉하니', '좋음', '근데', '가격대가', '쫌', '있긴', '함'],
#  ['초아', '초아초아요', '자극', '없어요.', '머가', '마니', '나긴', '하지만요...'],
#  ['남친',
#   '사줌',
#   '귀찮아서',
#   '잘',
#   '안바르는데',
#   '어쩌다',
#   '가끔',
#   '면도하고',
#   '얼굴',
#   '당긴다며',
#   '바르고',
#   '나오는',
#   '날은',
#   '뽀뽀하다',
#   '심장',
#   '멎음',
#   '보고',
#   '싶네',
#   '좀'],
#  ['우리',
#   '신랑',
#   '극지성인데',
#   '이',
#   '니스프리',
#   '쓰다가',
#   '이라인으로',
#   '갈아탐',
#   '적당히',
#   '유수분',
#   '잘',
#   '잡아주고',
#   '얼굴',
#   '열감이',
#   '안느껴지는',
#   '제품.',
#   '진짜',
#   '진짜',
#   '좋음.'],
#  ['비싸지만', '않으면'],
#  ['남친이',
#   '스킨로션',
#   '안바르는',
#   '사람이라',
#   '나이도',
#   '들고',
#   '건조해지는',
#   '것',
#   '같아서',
#   '스킨',
#   '로션세트로',
#   '사줌',
#   '남친',
#   '말로는',
#   '신기하게',
#   '이거',
#   '바르고',
#   '회사',
#   '사람들이',
#   '피부',
#   '좋아졌다는',
#   '소릴',
#   '5명에',
#   '2명꼴로',
#   '했다고',
#   '함.',
#   '요즘',
#   '신이',
#   '나셔서',
#   '크림에도',
#   '관심',
#   '갖고',
#   '있음'],
#  ['남편은',
#   '이게',
#   '가장',
#   '좋대요',
#   '남성화장품',
#   '유명한',
#   '것도',
#   '쓰게',
#   '해봤지만',
#   '결국은',
#   '이게',
#   '좋대요'],
#  ['아빠가',
#   '쓰시는데',
#   '걍',
#   '무난해요',
#   '근데',
#   '내',
#   '화장품이면',
#   '이거',
#   '안',
#   '살듯....',
#   '너무',
#   '비싸요'],
#  ['역시', '비오템...', '흡수가', '잘되는', '듯'],
#  ['비오템',
#   '입문하자마자',
#   '떠나게',
#   '한',
#   '제품',
#   '피부에',
#   '신경',
#   '안쓰던',
#   '적에',
#   '올',
#   '인원',
#   '제품',
#   '하나만',
#   '겨울에',
#   '바를만큼',
#   '무신경했는데',
#   '요',
#   '라인은',
#   '참을',
#   '수',
#   '없이',
#   '건조했다..',
#   '아무것도',
#   '모를적',
#   '비오템',
#   '유명하고',
#   '수분라인이니',
#   '좋겠지',
#   '하고',
#   '샀는데',
#   '이런',
#   '게',
#   '바로',
#   '로드샵만',
#   '못한',
#   '가격만',
#   '붙은',
#   '백화점',
#   '상품..'],
#  ['촉촉함,', '세수하고', '바로', '발라주기', '좋음', '가격이', '좀', '센게', '흠'],
#  ['개굿.',
#   '저',
#   '자극에',
#   '피부결',
#   '정돈',
#   '좋음.',
#   '다만',
#   '애프터',
#   '쉐이브',
#   '기능이',
#   '없어서',
#   '면도',
#   '후',
#   '바르면',
#   '뭔가',
#   '아쉬움.',
#   '티쀼르보다',
#   '좋아요'],
#  ['흡수', '빠르고', '향도', '무난', '건성은', '건조하겟지만', '난', '중성이라', '안건조', '햇음'],
#  ['흡수',
#   '빠르고',
#   '향',
#   '좋고',
#   '좋음.',
#   '하지만',
#   '아쿠아라고',
#   '하기엔',
#   '지속력이',
#   '떨어짐.',
#   '화학',
#   '성분',
#   '잔뜩..',
#   '아침마다',
#   '뾰루지',
#   '올라올까',
#   '불안함'],
#  ['남자친구를',
#   '직접',
#   '데리고',
#   '백화점을',
#   '둘러다니면서',
#   '여기',
#   '저기',
#   '화장품을',
#   '써보게',
#   '했는데',
#   '이게',
#   '가장',
#   '마음에',
#   '든다고',
#   '하더라구요',
#   '산뜻하니',
#   '흡수도',
#   '빠르고',
#   '향도',
#   '은은해',
#   '부담없이',
#   '아침에',
#   '세수하고도',
#   '쓰더라구요',
#   '참고로',
#   '남자친구는',
#   '티존',
#   '지성',
#   '나머지',
#   '얼굴',
#   '부분은',
#   '건성인',
#   '복합성입니당_'],
#  ['남편이',
#   '지금',
#   '쓰는',
#   '보닌',
#   '쓰기',
#   '전에',
#   '신혼때부터',
#   '썼던',
#   '제품이에요',
#   '과한',
#   '스킨향은',
#   '싫은데',
#   '비오템은',
#   '향도',
#   '순하고',
#   '느낌도',
#   '좋다고',
#   '했던',
#   '거',
#   '같아요.',
#   '가격이',
#   '좀',
#   '한다는',
#   '게',
#   '단점'],
#  ['특유의', '비오템', '향이', '나서', '좋음', '근데', '쫌', '번들거리는', '느낌이', '있음'],
#  ['여름', '철', '지친피부에', '너무', '좋아요'],
#  ['남친',
#   '선물',
#   '해줬는데',
#   '오빠가',
#   '향이',
#   '좀',
#   '쏘는',
#   '그런',
#   '향이라고',
#   '하는데',
#   '시원하다고',
#   '하네요',
#   '끈적이지',
#   '않고',
#   '흡수는',
#   '빠른데',
#   '정말',
#   '촉촉하대요'],
#  ['향', '좋고', '빠르게', '흡수되요', '근데', '막', '너무', '무난한', '느낌'],
#  ['좋아요', '얼굴이', '환해지는', '느낌', '받음'],
#  ['비오템', '시원하고', '좋습니다', '끈적거림도', '없고', '보습력도', '좋은', '듯', '향도', '깔끔하네요'],
#  ['향도',
#   '좋고',
#   '끈적거리지',
#   '않아',
#   '자주',
#   '애용하는',
#   '제품입니다.',
#   '보습',
#   '효과가',
#   '좋아',
#   '로션대용으로도',
#   '사용하고',
#   '있습니다.',
#   '뚜껑이랑',
#   '통이',
#   '아',
#   '다리가',
#   '안맞아',
#   '줄줄',
#   '새는',
#   '점',
#   '말곤',
#   '다',
#   '좋네요.'],
#  ['키엘만의',
#   '피부가',
#   '좋아지는',
#   '자연스러운',
#   '토너에요.',
#   '카렌듈라',
#   '잎이',
#   '피부',
#   '속',
#   '끝까지',
#   '부드럽게',
#   '잡아주는',
#   '느낌이',
#   '들',
#   '정도로',
#   '키엘에서',
#   '유명한',
#   '제품이라고',
#   '생각합니다',
#   '칼렌듈라',
#   '폼클렌',
#   '저도',
#   '좋지만',
#   '이',
#   '토너와',
#   '함께',
#   '사용한다면',
#   '더',
#   '부드러운',
#   '피부를',
#   '만들',
#   '수',
#   '있어요'],
#  ['그냥', '그래요..', '그리고', '안에', '들어있는', '건더기..', '저는', '너무', '비위', '상합니다', '윽'],
#  ['제',
#   '피부엔',
#   '너무',
#   '잘',
#   '맞았어요',
#   '향도',
#   '홍차향처럼',
#   '좋은',
#   '향이',
#   '나고',
#   '제형은',
#   '완전',
#   '물',
#   '같은데',
#   '신기하게',
#   '보습감이',
#   '느껴졌어요.',
#   '다른',
#   '물같은',
#   '토너들은',
#   '바르고',
#   '나면',
#   '건조하다고',
#   '느꼈었거든요',
#   '그래서',
#   '꾸준히',
#   '사용하고',
#   '싶은데',
#   '가격이',
#   '나가는',
#   '편이라',
#   '좀',
#   '아쉽네여'],
#  ['뭐가',
#   '좋은',
#   '건지',
#   '잘',
#   '모르겠지만',
#   '확실히',
#   '순한',
#   '건',
#   '맞는',
#   '것',
#   '같아요.',
#   '아세톤이',
#   '없는',
#   '건지',
#   '잘',
#   '모르겠지만',
#   '상처난',
#   '부위에',
#   '토너가',
#   '지나가',
#   '더',
#   '따갑지',
#   '않아요.',
#   '양도',
#   '잘',
#   '안줄어서',
#   '냉장고에',
#   '넣어놓고',
#   '토너팩으로',
#   '쓰면',
#   '좋을',
#   '것',
#   '같아요'],
#  ['꿀물향',
#   '같은',
#   '게',
#   '나는데',
#   '왠지',
#   '기분',
#   '좋아요',
#   '가끔',
#   '화장솜에',
#   '적셔서',
#   '얼굴에',
#   '올려놓으면',
#   '피부가',
#   '부들부들하고',
#   '넘',
#   '좋아요'],
#  ['솔직히',
#   '쓸게요...',
#   '수부지',
#   '피부입니다',
#   '백원도',
#   '할인',
#   '안받고',
#   '정가',
#   '주고',
#   '사서',
#   '썼는데요',
#   '뭐가',
#   '좋다는',
#   '건지',
#   '1도',
#   '모르겟어요',
#   '저는',
#   '모든',
#   '스킨을',
#   '화장폼에',
#   '부어서',
#   '닦아내면서',
#   '사용하는데',
#   '방법이',
#   '잘못된',
#   '건가요',
#   '아까워서',
#   '한통',
#   '다',
#   '쓰고',
#   '딴',
#   '스킨으로',
#   '바꿨습니다'],
#  ['원래',
#   'sk2를',
#   '사용하다가',
#   '갈아탔는데',
#   '순한',
#   '거',
#   '같기는',
#   '하나',
#   '그렇게',
#   '피부가',
#   '좋아지는데',
#   '도움을',
#   '주는',
#   '거는',
#   '크게',
#   '못',
#   '느꼈어요',
#   '무난한',
#   '사용감이긴',
#   '해요'],
#  ['가격이',
#   '좀',
#   '쎄긴',
#   '하지만',
#   '가격값',
#   '하는',
#   '것',
#   '같아요.',
#   '2년',
#   '전에',
#   '얼굴에',
#   '뭐가',
#   '많이',
#   '나서',
#   '좋은',
#   '거',
#   '없나',
#   '찾아보다가',
#   '이거',
#   '쓰기',
#   '시작했는데',
#   '정착하고',
#   '있어요.',
#   '트러블도',
#   '확실히',
#   '줄었고요'],
#  ['면세로',
#   '항상',
#   '대용량으로',
#   '구입하는',
#   '제품',
#   '제',
#   '가격',
#   '주고',
#   '사기엔',
#   '가성비가',
#   '떨어지지만',
#   '면세점',
#   '가격',
#   '정도면',
#   '항상',
#   '쟁여두고',
#   '쓸',
#   '가치가',
#   '있는',
#   '제품',
#   '피부가',
#   '예민해져',
#   '있을',
#   '때',
#   '진정하는',
#   '용으로',
#   '좋음'],
#  ['면세찬스로만',
#   '구입해야',
#   '하는..',
#   '근데',
#   '너무',
#   '좋은',
#   '얼굴에',
#   '열내려주거나',
#   '자극',
#   '받았을',
#   '때',
#   '스킨',
#   '팩해주면',
#   '진짜',
#   '좋아요'],
#  ['너무',
#   '따가워요...',
#   '쓰다보면',
#   '나아지겠거니',
#   '했는데',
#   '똑같이',
#   '따가워버려...',
#   '이',
#   '제품',
#   '쓰면서',
#   '정말',
#   '하나도',
#   '안',
#   '따가',
#   '울',
#   '수가',
#   '있나요',
#   '피부과에서',
#   '필링하면',
#   '지옥같은',
#   '고통이',
#   '한',
#   '차례',
#   '지나가고,',
#   '남아있는',
#   '잔고통',
#   '정도의',
#   '따끔함...',
#   '전',
#   '포기요'],
#  ['좀',
#   '비싸서',
#   '살',
#   '때',
#   '손',
#   '떨리지만',
#   '막상',
#   '사고',
#   '나면',
#   '잘',
#   '쓰는',
#   '제품',
#   '가격',
#   '때문에',
#   '다른',
#   '거',
#   '잠깐',
#   '사용하다가도',
#   '이만한',
#   '게',
#   '없다',
#   '싶어',
#   '다시',
#   '사용하게',
#   '됨',
#   '그래도',
#   '아까워서',
#   '아직',
#   '스킨팩은',
#   '한번도',
#   '못해봄...',
#   '향은',
#   '썩',
#   '향기로운',
#   '향은',
#   '아니지만',
#   '딱',
#   '꽃잎',
#   '같은',
#   '냄새',
#   '스킨',
#   '다',
#   '써갈',
#   '때',
#   '쯤이면',
#   '내용물에',
#   '있는',
#   '꽃잎들도',
#   '같이',
#   '나온다',
#   '비주얼은',
#   '좀',
#   '그렇지만',
#   '민감성',
#   '피부에',
#   '짱짱인듯'],
#  ['좋아요',
#   '좋아요',
#   '피부가',
#   '완전',
#   '뒤집어졌을',
#   '때',
#   '피부에',
#   '좋다는',
#   '토너들을',
#   '찾다가',
#   '우연히',
#   '발견하게',
#   '되었습니다',
#   '가격은',
#   '엄청나게',
#   '비싸지만',
#   '그래도',
#   '한',
#   '번',
#   '써볼만',
#   '해요',
#   '쓸',
#   '때',
#   '살짝',
#   '따가',
#   '울',
#   '때도',
#   '있지만',
#   '괜찮은',
#   '것',
#   '같습니다'],
#  ['굳이', '이걸', '써야', '하는', '점을', '못', '느꼈음', '아무런', '장점도', '단점도', '못', '느낌'],
#  ['가격만',
#   '놓고',
#   '보면',
#   '정말',
#   '별로인데',
#   '사용하다보면',
#   '꽤나',
#   '피부에',
#   '잘',
#   '맞아서',
#   '쭈욱',
#   '쓰게',
#   '되는',
#   '토너입니다.',
#   '진정효과가',
#   '좋고',
#   '자극이',
#   '없다는',
#   '점,',
#   '은근히',
#   '촉촉하다는',
#   '부분이',
#   '만족스러워요.',
#   '저는',
#   '화장솜으로',
#   '닦토',
#   '한',
#   '차례하고',
#   '손에',
#   '덜어서',
#   '한',
#   '번',
#   '촵촵',
#   '흡수시키는데',
#   '때때로',
#   '피부',
#   '자극이',
#   '심한',
#   '날엔',
#   '크림으로',
#   '마무리하지',
#   '않아도',
#   '심하게',
#   '건조하지',
#   '않아서',
#   '좋더라구요.',
#   '다만',
#   '사용하다보면',
#   '자꾸',
#   '꽃잎이',
#   '나와서',
#   '귀찮아요'],
#  ['그냥',
#   '순하고',
#   '닦토하기',
#   '좋은데',
#   '자꾸',
#   '꽃잎이',
#   '나와요..',
#   '이',
#   '정도',
#   '느낌으로',
#   '쓰려면',
#   '솔직히',
#   '로드샵에서도',
#   '많이',
#   '구하실수',
#   '있을',
#   '거',
#   '같아요'],
#  ['괜찮게',
#   '쓸만해요.',
#   '그냥',
#   '솜으로',
#   '닦아내는데',
#   '그냥',
#   '저냥',
#   '쓸만은',
#   '한데',
#   '다른',
#   '저렴이들',
#   '중',
#   '괜찮은',
#   '것들이랑',
#   '큰',
#   '차이가',
#   '없네요.',
#   '평범',
#   '무난'],
#  ['비싸게', '샀는데', '쓰자마자', '바로', '뒤집혔습니다'],
#  ['거의',
#   '10통',
#   '넘게',
#   '쓰고',
#   '있음.',
#   '가벼워서',
#   '안쓴거랑',
#   '별',
#   '차이',
#   '없다고',
#   '느낄',
#   '수도',
#   '있겠지만',
#   '화장솜으로',
#   '한',
#   '번',
#   '닦아내고',
#   '토너',
#   '그대로',
#   '얼굴에',
#   '챱챱',
#   '흡수시캬주면',
#   '좋음.',
#   '가볍게',
#   '쓰기',
#   '좋다'],
#  ['친구가',
#   '엄청',
#   '좋다고',
#   '추천해줘서',
#   '면세',
#   '찬스로',
#   '시중가격보다',
#   '저렴하게',
#   '사서',
#   '사용해봤어요',
#   '트러블',
#   '피부에',
#   '좋다고',
#   '입소문이',
#   '나서',
#   '잔뜩',
#   '기대하고',
#   '써봤어요',
#   '그치만.....',
#   '저에겐',
#   '딱',
#   '물같은',
#   '느낌이었습니다...',
#   '좁쌀트러블은',
#   '여전했고,',
#   '한통',
#   '다',
#   '쓸',
#   '때까지',
#   '딱히',
#   '좋은지',
#   '모르겠더라구요',
#   '제',
#   '친구한테는',
#   '인생템이었지만,',
#   '저는',
#   '잘',
#   '모르겠습니다'],
#  ['그냥',
#   '저냥',
#   '보습도',
#   '잘되고',
#   '냄새도',
#   '좋고',
#   '나쁘지',
#   '않은',
#   '토너였어요',
#   '근데',
#   '가격대비로',
#   '치먄',
#   '그렇게',
#   '좋지는',
#   '않은',
#   '것',
#   '같구요...'],
#  ['좋아요', '비싼만큼', '촉촉하고', '정말', '좋습니다', '키엘', '최고'],
#  ['제일',
#   '유명하고',
#   '좋은',
#   '토너래요..',
#   '하지만',
#   '1년',
#   '동안',
#   '계속',
#   '쓰고',
#   '있는데도',
#   '모공',
#   '수축',
#   '효과',
#   '잘',
#   '안',
#   '보이고',
#   '돈이',
#   '아깝다'],
#  ['가격',
#   '빼고는',
#   '다',
#   '좋은',
#   '토너에요.',
#   '토너',
#   '바르면',
#   '피부가',
#   '촉촉해져요.',
#   '가격',
#   '때문에',
#   '쓰기',
#   '망설여져요'],
#  ['가격만',
#   '조금',
#   '저렴했다면',
#   ',,,,',
#   '갑자기',
#   '피부',
#   '뒤집히거나',
#   '하면',
#   '화장솜에',
#   '아침',
#   '저녁으로',
#   '팩',
#   '하듯이',
#   '해주면',
#   '며칠',
#   '안에',
#   '금방',
#   '괜찮아져서',
#   '좋았는데',
#   ',,,',
#   '팩처럼',
#   '너무',
#   '막',
#   '써서',
#   '그런지',
#   '너무',
#   '빨리',
#   '다',
#   '써서',
#   '면세점에서',
#   '사기',
#   '딱',
#   '좋은',
#   '제품입니다'],
#  ['피부가',
#   '지성이면서',
#   '민감성이라서',
#   '오랫동안',
#   '시행착오를',
#   '겪다가',
#   '정착한',
#   '아이에요',
#   '가격이',
#   '있는',
#   '편이라서',
#   '면세찬스로',
#   '쟁이고',
#   '있습니다',
#   '저와',
#   '같은',
#   '피부타입이신',
#   '분께',
#   '추천해요'],
#  ['순하고,',
#   '끈적임',
#   '없고,',
#   '수분도',
#   '적당히',
#   '채워주는',
#   '느낌이',
#   '어서',
#   '재구매는',
#   '해볼',
#   '생각이에요'],
#  ['여드름에',
#   '좋다고',
#   '추천',
#   '받아서',
#   '썼는데',
#   '딱히',
#   '효과는',
#   '못',
#   '느꼈어요.',
#   '이거도',
#   '사람마다',
#   '다른',
#   '건지',
#   '그냥',
#   '여드름이',
#   '더',
#   '나진',
#   '않지만',
#   '나아지게',
#   '하는',
#   '거도',
#   '아닌',
#   '느낌'],
#  ['피부에',
#   '트러블이',
#   '올라',
#   '왔을',
#   '때',
#   '썼는데',
#   '그',
#   '다음',
#   '날',
#   '진정된',
#   '느낌을',
#   '받아서',
#   '좋았음'],
#  ['흡수',
#   '빠르고',
#   '까먹고',
#   '크림안발라도',
#   '그다지',
#   '당김',
#   '없음',
#   '화장대',
#   '디피용으로도',
#   '넘',
#   '예븝니다',
#   '근데',
#   '냄새는',
#   '도무지',
#   '적응이',
#   '안됨....'],
#  ['한통을', '다', '쓰긴', '했는데', '재구매', '의사', '없구', '카렌', '듈라', '들어간', '건', '안사요..'],
#  ['그저',
#   '물이군요.',
#   '이',
#   '쯤',
#   '끝내야',
#   '꽃잎이',
#   '예쁘게',
#   '남을',
#   '것',
#   '같으니',
#   '그만',
#   '쓸게요.',
#   '차라리',
#   '장식품으로',
#   '남아주시어요.',
#   '키엘',
#   '당신은',
#   '내게',
#   '인생',
#   '클렌',
#   '저',
#   '하나와',
#   '수많은',
#   '쓸모없템',
#   '들을',
#   '동시에',
#   '안기는',
#   '모순',
#   '덩어리.'],
#  ['저는',
#   '이게',
#   '제',
#   '인생',
#   '토너인',
#   '거',
#   '같아요',
#   '냄새는',
#   '되게',
#   '별로고',
#   '꽃잎도',
#   '올굴에',
#   '잘',
#   '묻어나는데',
#   '이거만큼',
#   '피부진정에',
#   '좋은',
#   '애가',
#   '없어서',
#   '떠날',
#   '수가',
#   '없네요',
#   '가',
#   '겨은',
#   '비싸긴',
#   '한데',
#   '면세가는',
#   '살만하고',
#   '면세점에서',
#   '구매하면',
#   '클렌자도',
#   '주니까',
#   '면세에서',
#   '사세요'],
#  ['홍차',
#   '냄새',
#   '같은게',
#   '남',
#   '이',
#   '토너는',
#   '지성한테',
#   '좋다길래',
#   '써볼수',
#   '밖에',
#   '없엇음',
#   '근데',
#   '파라',
#   '벤이',
#   '들어잇엇다니',
#   '그러나',
#   '토너만',
#   '발라도',
#   '넘',
#   '기름',
#   '졋는데',
#   '이거',
#   '바르면',
#   '피부',
#   '깔끔한',
#   '느낌',
#   '나고',
#   '여드름도',
#   '안나여',
#   '근딩',
#   '250미리',
#   '짜리',
#   '삿는데',
#   '1달이면',
#   '다',
#   '쓸듯',
#   '아껴',
#   '써야징'],
#  ['토너로서의',
#   '기능에',
#   '충실하다',
#   '하지만',
#   '너무',
#   '비싼',
#   '가격...',
#   '피부',
#   '진정시키기에',
#   '참',
#   '좋다',
#   '그러기에',
#   '참',
#   '비싸긴',
#   '하다',
#   '스킨',
#   '팩하기에도',
#   '좋고',
#   '7스킨',
#   '하기에도',
#   '좋다',
#   '근데',
#   '좀',
#   '많이',
#   '비싸다...'],
#  ['여름이',
#   '되면',
#   '속당',
#   '김이',
#   '심해',
#   '항상',
#   '사용하는',
#   '제품.',
#   '성분이',
#   '순해',
#   '진정도',
#   '되고',
#   '속당김도',
#   '좋아짐'],
#  ['좁쌀',
#   '여드름이나',
#   '뾰루지가',
#   '나올',
#   '때',
#   '솜에',
#   '적신',
#   '토너로',
#   '진정해주면',
#   '좋습니다',
#   '워낙',
#   '천연성분으로',
#   '유명한',
#   '브랜드라',
#   '믿고',
#   '사용하고',
#   '있습니다',
#   '사용감',
#   '자체는',
#   '산뜻한',
#   '거',
#   '보다는',
#   '쫀쫀했습니다',
#   '가격대가',
#   '워낙',
#   '있는',
#   '브랜드라',
#   '양도',
#   '적고',
#   '사용하기',
#   '아까워요',
#   '가성비',
#   '생각했을',
#   '때',
#   '별로라고',
#   '생각이',
#   '드네요'],
#  ['꽃잎이',
#   '들어있대서',
#   '한번',
#   '써봤는데',
#   '생각보다',
#   '촉촉하지',
#   '않고',
#   '건조해요',
#   '이',
#   '니스프리',
#   '블루베리',
#   '토너랑',
#   '비교해서',
#   '꽃잎이',
#   '나오는',
#   '건',
#   '신기한데',
#   '가격',
#   '생각하면',
#   '재구매는',
#   '안할...'],
#  ['매우',
#   '비싼',
#   '제품이죠...',
#   '면세점으로',
#   '샀는데',
#   '저에게',
#   '여드름을',
#   '선사한',
#   '제품...',
#   '만약',
#   '자신이',
#   '민감하다면',
#   '추천을',
#   '안드립니다',
#   '이',
#   '꽃',
#   '자체가',
#   '안맞나',
#   '봐요'],
#  ['토너를',
#   '딱',
#   '보면',
#   '그냥',
#   '일단',
#   '너무',
#   '이뻐요',
#   '저는',
#   '건성이라',
#   '기초를',
#   '단단히',
#   '하는',
#   '편이에요',
#   '스킨',
#   '단독으로',
#   '쓰지',
#   '않기',
#   '때문에',
#   '당김은',
#   '모르겠었고',
#   '사용감',
#   '무난했어요',
#   '향도',
#   '그럭저럭..',
#   '화장품',
#   '아무거나',
#   '써도',
#   '트러블',
#   '거의',
#   '안나는',
#   '피부에요',
#   '스킨',
#   '팍팍',
#   '쓰고',
#   '싶은데',
#   '가격',
#   '때문에',
#   '신경',
#   '쓰여요'],
#  ['역시',
#   '비싼',
#   '건',
#   '비싼데',
#   '이유가',
#   '있죠',
#   '속당김',
#   '해결이',
#   '엄청',
#   '돼요',
#   '몇',
#   '번',
#   '두들겨주면',
#   '다른',
#   '제품',
#   '없이도',
#   '스킨로션',
#   '다',
#   '바른',
#   '느낌',
#   '향은',
#   '약간',
#   '나무차',
#   '향이',
#   '나는데',
#   '그건',
#   '화장',
#   '하고',
#   '나면',
#   '다',
#   '없어져서',
#   '괜찮고',
#   '근데',
#   '안에',
#   '들어있는',
#   '꽃이',
#   '거슬려요'],
#  ['토너',
#   '안에',
#   '진짜',
#   '꽃잎이',
#   '들어있어요',
#   '이런',
#   '제품을',
#   '처음',
#   '사용해봐서',
#   '그런지',
#   '신기하고',
#   '좋더라구요.',
#   '안에',
#   '들어있는',
#   '꽃잎이',
#   '딸려',
#   '나오기도',
#   '해서',
#   '뭔가',
#   '꽃잎물을',
#   '바르는',
#   '느낌이',
#   '들어서',
#   '좋아요.',
#   '향은',
#   '인공적인',
#   '꽃향이',
#   '아니라',
#   '꽃.',
#   '자연',
#   '그대로의',
#   '향이',
#   '나요.',
#   '약간',
#   '차',
#   '향',
#   '아무튼',
#   '허브향',
#   '비슷한',
#   '향이',
#   '나는데',
#   '자연적인',
#   '느낌이',
#   '들어서',
#   '좋더라구요',
#   '자극적이지',
#   '않고',
#   '순하면서',
#   '건조함도',
#   '잡아주고',
#   '촉촉해요.',
#   '흡수도',
#   '잘되고',
#   '끈적임이',
#   '남는',
#   '게',
#   '없어요.',
#   '피부',
#   '정돈하고',
#   '수분감',
#   '보충하는',
#   '토너로서',
#   '아주',
#   '만족스러웠네요',
#   '또',
#   '좋았던',
#   '게',
#   '피부가',
#   '편안하게',
#   '진정되는',
#   '느낌이',
#   '든다는',
#   '점이었어요.',
#   '주기적으로',
#   '트러블이',
#   '나는데',
#   '그때에는',
#   '최대한',
#   '제품',
#   '가지',
#   '수를',
#   '줄이고',
#   '순한',
#   '제품',
#   '위주로',
#   '쓰는',
#   '편이에요.',
#   '트러블',
#   '나서',
#   '예민해진',
#   '부분에',
#   '스킨',
#   '팩해서',
#   '사용했는데',
#   '조금',
#   '진정되는',
#   '느낌이',
#   '들어서',
#   '좋았어요',
#   '흡수시켜서',
#   '사용해줘도',
#   '좋고',
#   '화장솜에',
#   '적혀서',
#   '스킨팩으로',
#   '사용해도',
#   '좋더라구요.'],
#  ['레이어드',
#   '해서',
#   '바르니까',
#   '촉촉한',
#   '느낌이',
#   '나고',
#   '확실히',
#   '당김이',
#   '없었어요',
#   '근데',
#   '여러',
#   '번',
#   '바를',
#   '정도로',
#   '가성비가',
#   '좋지',
#   '못해서',
#   '아쉬웠어요',
#   '그래도',
#   '써보니',
#   '키엘',
#   '유명한',
#   '이유가',
#   '있어요'],
#  ['와',
#   '진짜',
#   '피부가',
#   '한번에',
#   '흡수해서',
#   '지성인',
#   '저에겐',
#   '찐덕거리지도',
#   '않고',
#   '산뜻해서',
#   '너무',
#   '좋아요'],
#  ['선물',
#   '받아서',
#   '사용해봤는데',
#   '알코올도',
#   '없고',
#   '무엇보다',
#   '토너이지만',
#   '너무',
#   '촉촉해요',
#   '현재',
#   '다',
#   '쓰고',
#   '있는',
#   '거',
#   '다',
#   '쓰고',
#   '제',
#   '돈',
#   '내고',
#   '사려구요',
#   '재구매의사',
#   '100',
#   '입니당'],
#  ['성분이',
#   '완전',
#   '좋은',
#   '건',
#   '아니지만',
#   '예민한',
#   '피부임에도',
#   '불구하고',
#   '자극적이지',
#   '않아서',
#   '데일리로',
#   '좋았어요',
#   '카렌듈라라서',
#   '그런가',
#   '향이',
#   '좋고',
#   '촉촉해서',
#   '피부결',
#   '정돈이',
#   '되서',
#   '괜찮았어요.',
#   '다만',
#   '진정효과가',
#   '있는지는',
#   '모르겠어요.',
#   '그냥',
#   '닦토로',
#   '쓰기',
#   '좋은',
#   '것',
#   '같아요'],
#  ['닦토로', '좋은데', '가성비가', '별로...'],
#  ['일단',
#   '다른',
#   '토너들과',
#   '다르게',
#   '물같은',
#   '가벼운',
#   '토너임에도',
#   '흡수력이',
#   '굉장히',
#   '좋습니다.',
#   '5스킨',
#   '법을',
#   '사용하였는데',
#   '산뜻하게',
#   '마무리',
#   '됩니다.',
#   '이외에',
#   '닦토로',
#   '사용하여도,',
#   '차갑게',
#   '하여',
#   '화장솜에',
#   '묻혀',
#   '토너팩으로',
#   '사용해도,',
#   'N스킨',
#   '법으로',
#   '사용해도',
#   '좋았습니다.',
#   '닦토로',
#   '사용할',
#   '때는',
#   '세안',
#   '후',
#   '남아있는',
#   '잔',
#   '여물을',
#   '말끔하게',
#   '닦아주는',
#   '느낌으로',
#   '정리하는',
#   '느낌이',
#   '좋았고,',
#   '특히',
#   '토너를',
#   '차갑게',
#   '하여',
#   '스킨팩을',
#   '올려두니',
#   '피부의',
#   '열감을',
#   '내리거나,',
#   '진정용으로',
#   '사용하기에',
#   '너무',
#   '좋은',
#   '토너',
#   '입니다.',
#   '카렌듈라',
#   '토너',
#   '특유의',
#   '꽃향이',
#   '더해진',
#   '토너라서',
#   '인위적이지',
#   '않아서',
#   '좋았습니다.',
#   '대용량',
#   '토너',
#   '가격이',
#   '10만원을',
#   '넘던데',
#   '가격대에',
#   '비해',
#   '성분이',
#   '안',
#   '좋습니다.',
#   '요새',
#   '무',
#   '파라',
#   '벤을',
#   '지향하는',
#   '시대에',
#   '대놓고',
#   '파라',
#   '벤',
#   '성분이라니...',
#   '심지어',
#   '이런',
#   '가격에...',
#   '제',
#   '돈주고',
#   '살',
#   '것',
#   '같진',
#   '않습니다.',
#   '이',
#   '가격대보다',
#   '훨씬',
#   '저렴한',
#   '가격으로',
#   '좋은',
#   '성분의',
#   '토너들은',
#   '이미',
#   '시중에',
#   '충분히',
#   '많으니까요',
#   '파라벤',
#   '성분은',
#   '접촉성',
#   '피부염',
#   '알레르기',
#   '피부를',
#   '가지신',
#   '분들에게',
#   '치명적입니다.',
#   '또한',
#   '저처럼',
#   '민감한',
#   '피부를',
#   '가지신',
#   '분들은',
#   '샘플로',
#   '테스트',
#   '후',
#   '구매',
#   '사용하시길',
#   '권장해드립니다.',
#   '처음',
#   '3일',
#   '정도',
#   '사용할',
#   '때는',
#   '피부에',
#   '맞는',
#   '줄',
#   '알았습니다.',
#   '닦토후에',
#   '5스킨',
#   '법으로',
#   '여러',
#   '번',
#   '레이어드해서',
#   '바르곤',
#   '했는데',
#   '어느',
#   '날',
#   '부터인가',
#   '볼쪽에',
#   '여드름이',
#   '하나씩',
#   '올라오더니',
#   '5일쯤',
#   '사용한',
#   '날부터는',
#   '우수수',
#   '올라오더라구여',
#   '바뀐',
#   '화장품은',
#   '키엘',
#   '토너',
#   '하나뿐이였는데...',
#   '아쉽지만',
#   '이후로',
#   '사용',
#   '중단',
#   '하였습니다.'],
#  ['아무래도',
#   '가격이',
#   '아쉬워',
#   '처음',
#   '쓰시는',
#   '분들은',
#   '부담스럽다고',
#   '하시지만',
#   '저처럼',
#   '써본',
#   '사람은',
#   '쓰고',
#   '나서',
#   '가격이',
#   '생각이',
#   '안난다고',
#   '하시는',
#   '분들도',
#   '많더라구요',
#   '일단',
#   '피부가',
#   '밝아지고',
#   '피부결이',
#   '좋아진다는',
#   '느낌을',
#   '많이',
#   '받았어요',
#   '예전에',
#   '써보고',
#   '토너',
#   '유목민으로',
#   '살다가',
#   '다시',
#   '정착하게',
#   '되었는데',
#   '피부에',
#   '처음',
#   '닿는',
#   '제품이',
#   '제일',
#   '중요한데',
#   '정말',
#   '좋은',
#   '거',
#   '같아요'],
#  ['키엘',
#   '다른',
#   '제품',
#   '살때',
#   '샘플로',
#   '받아서',
#   '몇',
#   '번',
#   '써봄',
#   '꽃향이',
#   '나고',
#   '용기',
#   '밑에',
#   '꽃잎들도',
#   '좀',
#   '깔려있고',
#   '향',
#   '좋음',
#   '그러나',
#   '나는',
#   '토너에게',
#   '화장솜에',
#   '묻혀',
#   '피부',
#   '정돈하는',
#   '정도를',
#   '바라지',
#   '그',
#   '이상의',
#   '기능을',
#   '바라지',
#   '않기',
#   '때문에',
#   '내',
#   '돈주고',
#   '이',
#   '가격으로',
#   '토너를',
#   '사지는',
#   '않을',
#   '듯...'],
#  ['키엘',
#   '특유의',
#   '깔끔한',
#   '패키지가',
#   '예뻐요',
#   '성분이',
#   '완전',
#   '순한',
#   '건',
#   '아니지만,',
#   '개인적으로',
#   '안맞는',
#   '성분',
#   '몇',
#   '개만',
#   '피하면',
#   '트러블',
#   '없는',
#   '타입이라',
#   '아',
#   '제품',
#   '잘',
#   '쓰고',
#   '있어요',
#   '흔들면',
#   '꽃잎이',
#   '하늘하늘',
#   '보이는',
#   '게',
#   '포인트예요',
#   '향도',
#   '좋고',
#   '촉촉하고',
#   '데일리로',
#   '쓰기',
#   '좋은',
#   '거',
#   '같아요',
#   '칼렌듈라',
#   '로',
#   '만든',
#   '화장품',
#   '중엔',
#   '제일',
#   '먼저',
#   '생각나는',
#   '아이템'],
#  ['성분은',
#   '그렇게',
#   '좋은',
#   '건',
#   '아니지만',
#   '자극적이지',
#   '않고',
#   '은은한',
#   '꽃향이',
#   '코를',
#   '맴돌며',
#   '가벼워',
#   '데',
#   '일리',
#   '토너로',
#   '딱이다.'],
#  ['진정',
#   '효과',
#   '있고',
#   '수분감도',
#   '있고',
#   '계속',
#   '쓰면',
#   '얼굴도',
#   '살짝',
#   '환해지긴',
#   '하는데',
#   '4스킨',
#   '이상',
#   '하면',
#   '피부에',
#   '자극이',
#   '되고,',
#   '가격도',
#   '비싼',
#   '편인데',
#   '마지막에',
#   '꽃잎이',
#   '남아서',
#   '자꾸',
#   '탈출하는',
#   '것도',
#   '싫어요.'],
#  ['나',
#   '피부',
#   '디게',
#   '좋았음',
#   '하얗고',
#   '잡티도',
#   '거의',
#   '없었음',
#   '근데',
#   '어느',
#   '날',
#   '갑자기',
#   '얼굴에',
#   '한두개씩',
#   '올라옴',
#   '평소와',
#   '같이',
#   '곧',
#   '없어지겠지',
#   '하면서',
#   '대수롭게',
#   '넘김',
#   '근데',
#   '그게',
#   '아님',
#   '더',
#   '심해짐...',
#   '그래서',
#   '로션',
#   '바꿔봄',
#   '키엘',
#   '수분크림',
#   '쓰는',
#   '중이라',
#   '토너도',
#   '키엘로',
#   '바꿨음',
#   '향',
#   '좋음',
#   '향만',
#   '좋음',
#   '내',
#   '얼굴엔',
#   '안',
#   '좋음',
#   '내',
#   '얼굴',
#   '난리남',
#   '칼렌듈라가',
#   '나랑',
#   '안맞는',
#   '건지..',
#   '그래도',
#   '누가',
#   '이기나',
#   '해보자',
#   '하며',
#   '끝까지',
#   '써봄',
#   '냉장고에',
#   '넣어서',
#   '차갑게',
#   '팩처럼',
#   '씀',
#   '첨보단',
#   '나아졌지만',
#   '나랑은',
#   '아닌',
#   '듯..',
#   '가격대비',
#   '너무',
#   '별루얌'],
#  ['여드름이', '사용', '4달만에', '거의', '없어져서', '완전', '추천해요', '7스킨하면', '쫀쫀해요'],
#  ['화농성', '여드름이', '많이', '났는데', '이거', '바르고', '완전', '좋아졌어요'],
#  ['면세점',
#   '갈',
#   '때마다',
#   '사는',
#   '아이템',
#   '중',
#   '하나에요',
#   '키엘껀',
#   '진리에요',
#   '특히',
#   '카렌듈라는',
#   '피부진정',
#   '보습에',
#   '너무',
#   '좋고',
#   '500미리',
#   '용량이라서',
#   '화장하기',
#   '전에',
#   '화장솜에',
#   '잔뜩',
#   '적셔서',
#   '피부위에',
#   '올려주면',
#   '화장이',
#   '너무',
#   '잘',
#   '먹어요',
#   '트러블',
#   '전혀',
#   '없고',
#   '닦토로',
#   '쓰기에도',
#   '굿',
#   '근데',
#   '가격이',
#   '사악해서',
#   '아껴',
#   '써룡',
#   '히히'],
#  ['좋긴',
#   '좋은데',
#   '솔직히',
#   '이',
#   '가격',
#   '주고',
#   '살',
#   '정도는',
#   '아니에요.',
#   '피부에',
#   '드라마',
#   '틱한',
#   '효과가',
#   '보이는',
#   '정도도',
#   '아니고',
#   '백화점이랑',
#   '로드샵,',
#   '드럭',
#   '스토어에도',
#   '이정도',
#   '혹은',
#   '이것보다',
#   '좋은',
#   '토너들',
#   '있고',
#   '아무리',
#   '비싸도',
#   '가격이',
#   '이렇게는',
#   '아뉜데....',
#   '가격에',
#   '늘',
#   '의문이',
#   '가는',
#   '제품입니다.'],
#  ['차게',
#   '해서',
#   '얹으면',
#   '진정효과도',
#   '있는데',
#   '빨리',
#   '닳는',
#   '편이고',
#   '무엇보다..',
#   '꽃잎..',
#   '때문에',
#   '피부',
#   '정돈이',
#   '잘',
#   '안되는',
#   '것',
#   '같습니다.',
#   '재구매',
#   '의사는',
#   '없음'],
#  ['가격이',
#   '사악한',
#   '게',
#   '단점이지만',
#   '데일리토너로',
#   '아주',
#   '굿임.',
#   '자극',
#   '없이',
#   '순하고',
#   '촉촉함.',
#   '화장솜',
#   '적셔서',
#   '팩으로',
#   '얹어두면',
#   '촤악',
#   '진정됨.',
#   '꽃잎이',
#   '들어있어서',
#   '괜히',
#   '더',
#   '자연친화적인',
#   '느낌은',
#   '덤이랄까'],
#  ['스킨',
#   '팩',
#   '하고',
#   '난',
#   '뒤',
#   '진정',
#   '효과',
#   '때문에',
#   '떨어지면',
#   '사고',
#   '떨어지면',
#   '사는',
#   '제품입니다',
#   '스킨팩으로',
#   '해야',
#   '매력이',
#   '보여요'],
#  ['일단',
#   '용량이',
#   '완전',
#   '많아서',
#   '오래',
#   '잘',
#   '쓸거',
#   '같아요',
#   '향은',
#   '카렌듈라',
#   '향인데',
#   '진하게',
#   '안나고',
#   '거의',
#   '안나는',
#   '정도',
#   '완전',
#   '물제형이구요',
#   '카렌듈라라',
#   '조금',
#   '보습을',
#   '생각했는데',
#   '그래서',
#   '겨울에',
#   '써야',
#   '하는',
#   '줄',
#   '알았는데',
#   '진정에',
#   '좋다고',
#   '해서',
#   '흠',
#   '했어요',
#   '걍',
#   '무난한',
#   '토너이고',
#   '가격이',
#   '좀',
#   '사악해요'],
#  ['믿고',
#   '쓰는',
#   '브랜드인',
#   '키엘.',
#   '특히',
#   '카란튤라',
#   '토너는',
#   '토너중',
#   '갑오브',
#   '갑인듯.',
#   '피부에',
#   '자극',
#   '없고',
#   '속건성',
#   '바로',
#   '잡아줘서',
#   '넘나',
#   '좋은',
#   '것.',
#   '500미리',
#   '대용량으로',
#   '데일리',
#   '토너로',
#   '안성맞춤.',
#   '다만',
#   '가격이',
#   '10만원라는',
#   '사악함',
#   '흑흑',
#   '그래도',
#   '이',
#   '토너가',
#   '좋아서',
#   '맨날',
#   '직구로',
#   '구매함'],
#  ['수분',
#   '크림',
#   '구매하면서',
#   '받은',
#   '샘플만',
#   '사용해봤는데',
#   '개인적으로',
#   '좋았어요',
#   '제형도',
#   '좋고,',
#   '흡수도',
#   '잘',
#   '되고',
#   '좋게',
#   '사용했었어요',
#   '근데',
#   '가격은',
#   '이제',
#   '봤는데..',
#   '단점이라면',
#   '가격이겠네요'],
#  ['그냥',
#   '진정효과도',
#   '좋고',
#   '향도',
#   '좋도',
#   '여름에',
#   '쓰기',
#   '좋아요.',
#   '하지만',
#   '가격이',
#   '오바에요.',
#   '휴.....',
#   '너무',
#   '비싸서',
#   '못쓰겠어요.',
#   '그래서',
#   '이',
#   '가격에는',
#   '그닥이라는',
#   '생각도',
#   '들어요.',
#   '하지만',
#   '또',
#   '쓸',
#   '거',
#   '같기도...',
#   '일단',
#   '왠만한',
#   '토너들보다는',
#   '효과가',
#   '좋으닠가',
#   '욕도',
#   '못하고,',
#   '근데',
#   '가격은',
#   '비싸고'],
#  ['비싸지만',
#   '정말',
#   '좋습니다.',
#   '설명서처럼',
#   '정말로',
#   '피지',
#   '조절에',
#   '도움되는',
#   '스킨은',
#   '처음이네요.',
#   '가볍고',
#   '수분까지',
#   '채워줌.'],
#  ['칼렌듈라',
#   '꽃잎이',
#   '들어있어서',
#   '사용할',
#   '때',
#   '마다',
#   '기분',
#   '좋아지는',
#   '토너예요',
#   '향도',
#   '향긋하고',
#   '민감',
#   '피부에',
#   '확실히',
#   '잠재워',
#   '주는',
#   '것',
#   '같아서',
#   '너무',
#   '좋아요'],
#  ['보습력은', '좋았지만', '민감성', '피부인', '저는', '제형이', '무거워서', '인지', '트러블이', '났어요'],
#  ['진정에',
#   '좋다고',
#   '해서',
#   '수분팩',
#   '용도로',
#   '쓰려고',
#   '샀는데',
#   '저는',
#   '효과는',
#   '그저',
#   '그랬어요.',
#   '너무',
#   '기대했나봐요.',
#   '냉장고에',
#   '넣어두고',
#   '여름에',
#   '열',
#   '올랐을',
#   '때',
#   '한번씩',
#   '쓰려구요.'],
#  ['여름이', '다', '왔다니까', '시원해요'],
#  ['가격이',
#   '너무',
#   '사악하지만',
#   '토너중',
#   '가장',
#   '촉촉하다고',
#   '느끼는',
#   '제품',
#   '쓰고',
#   '나면',
#   '얼굴이',
#   '환해져서',
#   '좋음'],
#  ['여름', '되면', '생각나는', '화장품', '가격만', '덜', '사악했으면', '좋을텐데', '피부진정에', '좋은', '스킨'],
#  ['은은한',
#   '꽃향이',
#   '좋아요.',
#   '순해서',
#   '좋아요.',
#   '근데',
#   '마지막에',
#   '꽃잎이',
#   '자꾸',
#   '탈출을',
#   '해서',
#   '입구에',
#   '붙고',
#   '말라서',
#   '좀',
#   '더러워',
#   '보여요...',
#   '그거',
#   '외에는',
#   '좋아요.'],
#  ['토너라고',
#   '다',
#   '같은',
#   '토너가',
#   '아님을',
#   '알게',
#   '해준',
#   '제품',
#   '비싼',
#   '값을',
#   '하는',
#   '제품',
#   '35스킨',
#   '하고',
#   '나면',
#   '피부가',
#   '정말',
#   '완전',
#   '촉촉해져요',
#   '다른',
#   '저렴이',
#   '토너랑',
#   '그',
#   '느낌',
#   '자체가',
#   '다릅니다',
#   '일반',
#   '중저가',
#   '워터에센스에서도',
#   '느끼지',
#   '못한',
#   '깊은',
#   '수분감이',
#   '피부에서',
#   '느껴지는',
#   '신세계를',
#   '경험했어요'],
#  ['저',
#   '이거',
#   '완전',
#   '좋다고',
#   '할',
#   '수',
#   '있어요',
#   '트러블이',
#   '가장',
#   '많이',
#   '났을시기에',
#   '이것만큼',
#   '편안하게',
#   '피부에',
#   '올릴',
#   '수',
#   '있는',
#   '것도',
#   '없었구요',
#   '카렌듈라',
#   '꽃잎',
#   '때문인지',
#   '피부진정도',
#   '빠르게',
#   '되었어요',
#   '지금은',
#   '피부가',
#   '변해서',
#   '이게',
#   '잘',
#   '받지',
#   '않게',
#   '되었지만...',
#   '그래도',
#   '정말',
#   '추천하고픈',
#   '아이입니다'],
#  ['여드름',
#   '짜고',
#   '이걸로',
#   '스킨',
#   '팩했는데',
#   '그',
#   '짓물을',
#   '좀',
#   '흡수해주고',
#   '피부를',
#   '진정시켜주는',
#   '거',
#   '같아요',
#   '좋아요',
#   '근데',
#   '가격에',
#   '비해',
#   '양이',
#   '좀',
#   '적은',
#   '거',
#   '같아요'],
#  ['저는',
#   '미스트로',
#   '사용했는데',
#   '얼굴이',
#   '화끈거렸어요.',
#   '그리고',
#   '향도',
#   '호불호가',
#   '갈릴',
#   '것',
#   '같아요.'],
#  ['순하고', '산뜻해요', '가격은', '비싼', '편이지만', '흡수도', '잘되고', '잘', '쓰고', '있어요'],
#  ['스킨', '팩할', '때', '좋아요', '요즘', '가치', '미세먼지', '쩌는', '날', '피부에게', '휴식을', '주기'],
#  ['커밋',
#   '뷰티페스티벌에서',
#   '샘플',
#   '받아',
#   '쓰고',
#   '있는데',
#   '우와.',
#   '이건',
#   '진짜다.',
#   '라는',
#   '생각이',
#   '뙇.',
#   '세안',
#   '후',
#   '이',
#   '토너만',
#   '발라줬는데',
#   '겉도',
#   '촉촉하고',
#   '속',
#   '건조도',
#   '잘',
#   '잡아줘서',
#   '전혀',
#   '당김',
#   '현상',
#   '없었어요.',
#   '완전',
#   '개건성피부인데',
#   '앰플이나',
#   '크림',
#   '발라주지',
#   '않아도',
#   '될',
#   '정도',
#   '향도',
#   '인공향이',
#   '아니라서',
#   '좋았구요.',
#   '가격이',
#   '최대',
#   '진입장',
#   '벽인데',
#   '본품구매의사',
#   '100입니다.',
#   '미스트',
#   '샘플',
#   '같이',
#   '받았는데,',
#   '본품',
#   '사서',
#   '미스트로',
#   '사용할',
#   '거예요',
#   '가격',
#   '땜에',
#   '굿굿'],
#  ['커밋뷰티',
#   '페스티벌에서',
#   '받아온',
#   '샘플인데',
#   '향이',
#   '칼렌듈라',
#   '꽃잎',
#   '냄새가',
#   '나는',
#   '거',
#   '같은데',
#   '처음에는',
#   '조금',
#   '거부감이',
#   '들었는데',
#   '계속',
#   '쓰다보니',
#   '적응됨',
#   '다만',
#   '아쉬운',
#   '건',
#   '토너에서',
#   '꽃잎도',
#   '같이',
#   '흘러나와서',
#   '얼굴에',
#   '붙을',
#   '때가',
#   '있음',
#   '나이트용으로는',
#   '괜찮지만',
#   '메이크업',
#   '할',
#   '때는',
#   '좀....',
#   '꽃잎',
#   '흘러나오는',
#   '건',
#   '보완되었으면....'],
#  ['칠스킨',
#   '하려고',
#   '대용량으로',
#   '사서',
#   '사용중인데',
#   '진짜',
#   '좋아요',
#   '순하고',
#   '은은',
#   '한향기로',
#   '바를',
#   '때마다',
#   '기분도',
#   '좋아',
#   '집니다',
#   '다만',
#   '덜어낼',
#   '때',
#   '꽃잎이',
#   '같이',
#   '딸려',
#   '나와서',
#   '그게',
#   '조금',
#   '불편해요'],
#  ['이',
#   '토너가',
#   '트러블에도',
#   '좋고',
#   '홍조에도',
#   '좋고',
#   '여러모로',
#   '가격값한다길래',
#   '구입해서',
#   '지금',
#   '2주정도',
#   '사용중인데',
#   '그냥',
#   '무난',
#   '무난한',
#   '거',
#   '같아요.',
#   '찻잎',
#   '자연적인',
#   '냄새가',
#   '나서',
#   '향은',
#   '너무',
#   '맘에',
#   '들어요',
#   '어차피',
#   '토너는',
#   '정제수가',
#   '전성분의',
#   '대다수를',
#   '차지할텐데',
#   '가격이',
#   '좀',
#   '아쉽구요..',
#   '파라',
#   '벤이',
#   '전성분',
#   '앞쪽에',
#   '위치하는',
#   '것도',
#   '별로',
#   '입니당..',
#   '이건',
#   '왜',
#   '그런지',
#   '모르겠는데',
#   '이',
#   '토너는',
#   '뭔가',
#   '덧바르면',
#   '덧바를',
#   '수록',
#   '더',
#   '건조한',
#   '거',
#   '같아요',
#   '그래서',
#   '23스킨만',
#   '해주고',
#   '있어용',
#   '어떤',
#   '분들은',
#   '꽃잎을',
#   '트러블',
#   '부위에',
#   '올려놓으면',
#   '진정이',
#   '잘',
#   '된다길래',
#   '시도해봤지만,,,',
#   '저는',
#   '아닌',
#   '걸로,,,',
#   '써본지',
#   '얼마',
#   '안돼서',
#   '아직',
#   '진가를',
#   '발휘를',
#   '못하는',
#   '걸',
#   '수도',
#   '있으니',
#   '한달',
#   '이상',
#   '사용해봐야',
#   '할',
#   '거',
#   '같아요',
#   '아직까진',
#   '딱히',
#   '좋은',
#   '점도',
#   '나쁜',
#   '점도',
#   '없는고',
#   '같아요'],
#  ['꽃잎',
#   '이나',
#   '꽃성분이',
#   '안맞아서',
#   '불안했지만,',
#   '2년',
#   '동안',
#   '빠짐없이',
#   '사용하는',
#   '활용성',
#   '있는',
#   '토너',
#   '민감성피부',
#   '화장품',
#   '7스킨',
#   '법팩',
#   '키트',
#   '미스트로',
#   '사용가능'],
#  ['사요',
#   '가격이',
#   '살벌하긴',
#   '하지만',
#   '진짜',
#   '가격값',
#   '제대로',
#   '해요',
#   '초등학생',
#   '때부터',
#   '몇',
#   '통',
#   '째',
#   '쓰고',
#   '있는데',
#   '용량이',
#   '큰',
#   '만큼',
#   '오래',
#   '쓸',
#   '수',
#   '있고',
#   '이마에',
#   '트러블',
#   '올라오려',
#   '한다',
#   '하면',
#   '자기',
#   '전에',
#   '이마에는',
#   '딱',
#   '이',
#   '토너만',
#   '바르고',
#   '자요',
#   '자고',
#   '일어나면',
#   '트러블',
#   '올라오려던',
#   '거',
#   '싹',
#   '다',
#   '내려가',
#   '있어요',
#   '진짜',
#   '추천합니당'],
#  ['진정효과',
#   '진짜',
#   '좋아요',
#   '가격',
#   '해외에서',
#   '사서',
#   '한국',
#   '가격',
#   '10만원',
#   '넘는',
#   '건',
#   '몰랐는데',
#   '저',
#   '가격이어도',
#   '재구매할',
#   '거에요',
#   '화농성',
#   '여드름인지',
#   '뭔지',
#   '하룻밤',
#   '사이에',
#   '엄청',
#   '심하게',
#   '올라와서',
#   '아침에',
#   '열감',
#   '엄청',
#   '느껴졌을',
#   '때',
#   '이거',
#   '화장솜에',
#   '듬뿍',
#   '적셔서',
#   '올려서',
#   '진정시켜주니까',
#   '열감',
#   '빠르게',
#   '내려갔어요..',
#   '순하고',
#   '트러블도',
#   '안',
#   '나고',
#   '촉촉하고',
#   '향도',
#   '좋습니다',
#   '가끔',
#   '꽃잎',
#   '튀어나와서',
#   '사용하기',
#   '불편한',
#   '것만',
#   '빼면',
#   '정말',
#   '좋아요'],
#  ['가격',
#   '빼고는',
#   '완벽한',
#   '제품.',
#   '물스킨인데',
#   '여러',
#   '번',
#   '덧바르면',
#   '또',
#   '나름',
#   '건조하지도',
#   '않고',
#   '칼렌듈라',
#   '토너인',
#   '만큼',
#   '진정효과가',
#   '최고에요.',
#   '저는',
#   '에센스나',
#   '앰플보단',
#   '3',
#   '토너',
#   '정도',
#   '한',
#   '후',
#   '크림을',
#   '바로',
#   '발라주는',
#   '편이라',
#   '토너를',
#   '많이',
#   '써서',
#   '그런지',
#   '가격이',
#   '좀',
#   '부담스럽지만',
#   '면세이용할',
#   '일',
#   '있을',
#   '땐',
#   '크림이랑',
#   '토너',
#   '꼭꼭',
#   '구매해요.',
#   '스킨에',
#   '듬뿍',
#   '묻혀',
#   '팩',
#   '대신',
#   '사용하면',
#   '좋아요.',
#   '민감성',
#   '분들',
#   '진정용',
#   '토너로',
#   '엄청',
#   '엄청',
#   '추천해요'],
#  ['저한테는',
#   '너무',
#   '나도',
#   '좋았던',
#   '제품',
#   '진짜',
#   '좋아용',
#   '가격이',
#   '좀',
#   '비싸긴',
#   '하지만',
#   '대용량이라,,',
#   '굿굿',
#   '무난하게',
#   '좋은',
#   '거',
#   '같아용',
#   '향두',
#   '딱히',
#   '호불호',
#   '갈리는',
#   '향두',
#   '아닌',
#   '거',
#   '같구',
#   '추천합니당'],
#  ['글로리',
#   '추천템',
#   '완전',
#   '촉촉하구',
#   '바르는',
#   '순간',
#   '쿨링감도',
#   '있어요',
#   '미스트',
#   '공병에',
#   '담아서',
#   '건조하다',
#   '싶을',
#   '때',
#   '마다',
#   '뿌려주면',
#   '좋아요',
#   '우연히',
#   '친구꺼',
#   '써봤다가',
#   '구매해서',
#   '쓰는',
#   '제품이에요'],
#  ['2019',
#   '커밋뷰티',
#   '키',
#   '엘부스에서',
#   '40ml',
#   '받아서',
#   '스킨팩으로',
#   '써봤음....',
#   '그리고',
#   '난',
#   '생각했다...',
#   '이거..',
#   '사야겠다....',
#   '요즘',
#   '피부상태',
#   '그지였음..',
#   '아픈',
#   '트러블에',
#   '간지러운',
#   '트러블',
#   '아주',
#   '난리',
#   '뽕짝',
#   '그',
#   '자체...',
#   '그런데',
#   '스킨팩',
#   '한',
#   '번으로',
#   '눈에',
#   '보이게',
#   '트러블이',
#   '조져짐',
#   '믿기지',
#   '않겠지만',
#   '리얼임',
#   '40ml로',
#   '매일',
#   '스킨팩미스트로',
#   '추가적으로',
#   '흡수시킴....',
#   '스킨팩',
#   '땜시',
#   '양이',
#   '미친듯이',
#   '줄긴',
#   '하던데',
#   '효과오져버려서..',
#   '멈출',
#   '수',
#   '없었음..',
#   '그래서',
#   '난',
#   '온라인',
#   '키엘',
#   '가입해서',
#   '150ml로',
#   '싸게',
#   '사려고',
#   '블래미',
#   '쉬스팟트리트먼트를',
#   '같이',
#   '삼',
#   '솔직히',
#   '중딩때',
#   '엄마가',
#   '키엘',
#   '립밤준',
#   '거',
#   '존좋까진',
#   '못느끼고',
#   '존내',
#   '비싸기만',
#   '하구',
#   '먼',
#   '이래서',
#   '별',
#   '느낌',
#   '없었는디',
#   '칼렌듈라',
#   '토너로',
#   '신앙심',
#   '생겨버림',
#   '이거',
#   '왜',
#   '3점대인지',
#   '고민',
#   '좀',
#   '해봤는데',
#   '건성한테는',
#   '좀',
#   '건조할',
#   '것',
#   '같기도',
#   '하고',
#   '가격이',
#   '미쳐',
#   '돌아감',
#   '그래서',
#   '나도',
#   '가격',
#   '땜시',
#   '짱짱에서',
#   '굿굿',
#   '줌'],
#  ['꽃잎',
#   '나온',
#   '거만',
#   '빼면',
#   '좋은',
#   '거',
#   '같아요',
#   '어느',
#   '정도',
#   '진정도',
#   '되고',
#   '수분감도',
#   '돌고',
#   '좋아용',
#   '솜에',
#   '묻혀서',
#   '닦아내거나',
#   '미스트',
#   '병에',
#   '담아서',
#   '쓰기도',
#   '좋은',
#   '거',
#   '같아요',
#   '외국에서만',
#   '사서',
#   '한국에서',
#   '얼마인지',
#   '몰랐는데',
#   '글픽',
#   '보고',
#   '놀랐어요',
#   '비싸긴',
#   '해도',
#   '좋아요'],
#  ['엄마가',
#   '사주셨는데',
#   '진짜',
#   '좋아요',
#   '꽃잎이',
#   '가끔',
#   '같이',
#   '나와서',
#   '조금',
#   '불편하긴',
#   '한데',
#   '그',
#   '점만',
#   '빼면',
#   '좋습니다.'],
#  ['아침,',
#   '저녁',
#   '토너팩으로',
#   '사용하기에',
#   '정말',
#   '좋아욧',
#   '피부',
#   '자극을',
#   '완화시키고,',
#   '피부',
#   '밸런스를',
#   '업해주는데',
#   '도움을',
#   '줍니당.'],
#  ['꽃잎이', '있어서', '좋지만', '자극됨'],
#  ['비싸지만',
#   '좋아요',
#   '꽃잎이',
#   '그래로',
#   '나와서',
#   '뭔가',
#   '더',
#   '신뢰가',
#   '가요',
#   '가격만',
#   '조금',
#   '낮으면',
#   '더',
#   '좋을텐데'],
#  ['산뜻하게',
#   '쓰긴',
#   '좋지만',
#   '산뜻한',
#   '가격은',
#   '아닌..',
#   '이',
#   '가격으로',
#   '다른',
#   '걸',
#   '사겠다',
#   '싶은',
#   '제품'],
#  ['꽃잎도',
#   '들어있고',
#   '색도',
#   '추출물',
#   '같아서',
#   '미관상',
#   '보기는',
#   '예쁜데..',
#   '진짜',
#   '별다른',
#   '효과를',
#   '모르겠는',
#   '제품이라',
#   '닦토로',
#   '써야',
# ...
#   '얼굴에',
#   '발라보니까',
#   '묽다고',
#   '해서',
#   '피부에',
#   '바로',
#   '다',
#   '흡수되서',
#   '다시',
#   '건조해지는',
#   '게',
#   '아니라',
#   '피부에선',
#   '쫀쫀한',
#   '제형으로',
#   '변하는',
#   '느낌적인',
#   '느낌',
#   '쫀쫀해서',
#   '그런지',
#   '이거',
#   '바르고',
#   '베이스',
#   '매이크업하면',
#   '더',
#   '잘',
#   '먹는다',
#   '그리고',
#   '무엇보다',
#   '일단',
#   '각질케어에',
#   '한몫하는',
#   '제품',
#   '원래',
#   '봄가을에',
#   '피부에',
#   '각질',
#   '올라와서',
#   '화장하면',
#   '금방',
#   '떠서',
#   '늘',
#   '불편했는데',
#   '하루',
#   '전날에',
#   '듬뿍',
#   '바르고',
#   '잔뒤에',
#   '아침에',
#   '이거',
#   '한번',
#   '더',
#   '바르고',
#   '나서',
#   '화장하니까',
#   '피부표현',
#   '완전',
#   '대박적으로',
#   '그',
#   '어느',
#   '때보다',
#   '성공했어요',
#   '남성용',
#   '로션이라서',
#   '아빠',
#   '드릴까',
#   '생각했지만',
#   '그냥',
#   '내가',
#   '쓸게',
#   '아빠',
#   ',,',
#   '넘',
#   '좋은',
#   '거류',
#   '난',
#   '진짜',
#   '진짜',
#   '대만족해서',
#   '다',
#   '쓰면',
#   '한번',
#   '더',
#   '살의향도',
#   '있다는'],
#  ['평가단',
#   '제품',
#   '제형은',
#   '로션과',
#   '에센스',
#   '그',
#   '어딘가..',
#   '에',
#   '멀젼',
#   '같은',
#   '느낌..',
#   '향도',
#   '좋고',
#   '트러블도',
#   '유발하지',
#   '않는',
#   '듯한',
#   '모양이더라구요.',
#   '보습력은',
#   '올',
#   '인원이라는',
#   '점을',
#   '감안하면',
#   '괜찮은',
#   '것',
#   '같구요,',
#   '지성분들은',
#   '사용하기엔',
#   '조금',
#   '번들거릴',
#   '것',
#   '같습니다.',
#   '보통',
#   '여성',
#   '화장품에',
#   '비하면',
#   '역시',
#   '못',
#   '미치는',
#   '것',
#   '같지만서도',
#   '제',
#   '피부는',
#   '보통',
#   '남자',
#   '뺨치게',
#   '두껍고..',
#   '화장품을',
#   '이것저것',
#   '안',
#   '가리는데',
#   '제가',
#   '괜찮을',
#   '정도면',
#   '다들',
#   '무난하게',
#   '잘',
#   '사용하실듯',
#   '올',
#   '인원',
#   '치고는',
#   '간',
#   '편함만',
#   '내세우는',
#   '게',
#   '아니라',
#   '보습력에도',
#   '신경',
#   '쓴',
#   '것',
#   '같아',
#   '만족합니다.',
#   '게다가',
#   '양도',
#   '많고',
#   '용기가',
#   '이쁘고',
#   '사용하기에',
#   '좋아',
#   '선물용으로',
#   '안성맞춤인듯',
#   '해요.',
#   '무난하게',
#   '다들',
#   '잘',
#   '사용하실듯',
#   '추가',
#   '구성으로',
#   '온',
#   '선스틱은',
#   '노랗더라구요..',
#   '그래도',
#   '그냥',
#   '제가',
#   '양',
#   '조절해서',
#   '섀딩용으로',
#   '써볼까',
#   '하는',
#   '중입니다.',
#   '뜨지고',
#   '않고',
#   '밀착되고',
#   '지속력도',
#   '나쁘진',
#   '않은데',
#   '남자도',
#   '얼굴에',
#   '그냥',
#   '바르기에는',
#   '좀',
#   '어중간한',
#   '색이',
#   '아닌가',
#   '싶네요.',
#   '톤만',
#   '여러',
#   '개',
#   '잘',
#   '뽑으면',
#   '되게',
#   '괜찮을',
#   '것',
#   '같아요.'],
#  ['체험단으로',
#   '받아본',
#   '제품입니다.',
#   '일단',
#   '제형은',
#   '흰색에',
#   '묽은',
#   '로션',
#   '제형이고',
#   '올',
#   '인원이라',
#   '그런지',
#   '약간의',
#   '유분감이',
#   '느껴졌어요.',
#   '대략',
#   '수분4',
#   '유분6',
#   '정도로',
#   '생각되고',
#   '보통',
#   '남성분들은',
#   '건성보다는',
#   '지성이',
#   '많은',
#   '걸',
#   '감안하면',
#   '스킨케어',
#   '맨',
#   '마지막',
#   '단계에',
#   '추가하시면',
#   '가장',
#   '적절하지',
#   '않을까',
#   '싶습니다.',
#   '향도',
#   '생각보다',
#   '진하지',
#   '않은',
#   '편이에요.',
#   '수분',
#   '유지력이나',
#   '수분감은',
#   '솔직히',
#   '여성화장품들',
#   '처럼',
#   '매우',
#   '대단하다거나',
#   '뛰어나다는',
#   '느낌은',
#   '받지',
#   '못했어요',
#   '그래도',
#   '전체적으로',
#   '봤을',
#   '때',
#   '평균은',
#   '되는',
#   '것',
#   '같네요',
#   '개인적으로는',
#   '남성화장품은',
#   '기본적인',
#   '보습력도',
#   '무시하고',
#   '무조건',
#   '간편함만',
#   '내세우는',
#   '경향이',
#   '있어서',
#   '좀',
#   '미심쩍었는데',
#   '그',
#   '정도는',
#   '아닌',
#   '것',
#   '같아서',
#   '다행입니다.',
#   '그래도',
#   '이것만',
#   '바르고',
#   '끝내기엔',
#   '수분',
#   '감면에서',
#   '부족할',
#   '수',
#   '있으니',
#   '수분위주',
#   '제품을',
#   '추가해서',
#   '쓰시는',
#   '게',
#   '좋을',
#   '듯',
#   '하네요',
#   '추가구성으로',
#   '받은',
#   '선스틱도',
#   '생각보다',
#   '괜찮았습니다.',
#   '여자인',
#   '제가',
#   '쓰기엔',
#   '조금',
#   '노랗고',
#   '어두웠는데',
#   '사람마다',
#   '피부색이',
#   '다르니',
#   '이부분은',
#   '테스트',
#   '해보시면',
#   '될',
#   '것',
#   '같네요.',
#   '커버력은',
#   '거의',
#   '없지만',
#   '그냥',
#   '선스틱이라고',
#   '생각하면',
#   '적당하고',
#   '생각만큼',
#   '많이',
#   '끈적이지도',
#   '않았고',
#   '밀착력도',
#   '나쁘진',
#   '않네요.',
#   '심한',
#   '지성이시라면',
#   '되게',
#   '금방',
#   '지워지겠지만',
#   '덧바르는',
#   '게',
#   '중요하니',
#   '오히려',
#   '선스틱',
#   '테스트해보시길',
#   '추천할게요'],
#  ['평가단체험',
#   '운',
#   '좋게',
#   '평가단체험에',
#   '당첨되어서',
#   '제품을',
#   '받아보았습니다',
#   '제형은',
#   '하얗고',
#   '일반',
#   '로션이랑',
#   '비슷했습니다',
#   '발라봤을',
#   '때',
#   '촉촉하고',
#   '두드리면',
#   '흡수가',
#   '어느',
#   '정도',
#   '됐고',
#   '유분이',
#   '좀',
#   '도는',
#   '조금',
#   '묵직한',
#   '제형인',
#   '것',
#   '같아',
#   '건성에게',
#   '추천드려요',
#   '저는',
#   '남자친구에게',
#   '줄',
#   '예정입니다'],
#  ['체험단',
#   '선정되어서',
#   '체험해볼',
#   '수',
#   '있었습니다',
#   '저는',
#   '남자친구',
#   '선물',
#   '해줬구요',
#   '남자친구는',
#   '티존부위는',
#   '지성,',
#   '볼',
#   '턱은',
#   '건성인',
#   '복합성',
#   '피부입니다',
#   '올',
#   '인원',
#   '크림이라',
#   '무거운',
#   '제형일',
#   '줄',
#   '알았는데',
#   '생각보다',
#   '묽어서',
#   '의외였어요',
#   '남자친구가',
#   '향에',
#   '예민한데',
#   '향',
#   '좋다고',
#   '하더라구요',
#   '그런데',
#   '이틀',
#   '정도',
#   '써보더니',
#   '바르고',
#   '나면',
#   '찐득거리는',
#   '느낌이',
#   '난다고',
#   '하네요.',
#   '그거',
#   '말고는',
#   '같이',
#   '온',
#   '셋트',
#   '구성품들도',
#   '다',
#   '만족스럽고',
#   '좋았습니다'],
#  ['이것저것',
#   '바르기',
#   '귀찮을',
#   '때',
#   '하나만',
#   '바르면',
#   '되니',
#   '간',
#   '편해서',
#   '좋았고',
#   '깔끔한',
#   '용기',
#   '디자인과',
#   '컴팩트한',
#   '용량도',
#   '마음에',
#   '들었다',
#   '다만',
#   '건성용이나',
#   '전',
#   '피부용',
#   '이라서',
#   '그런지',
#   '지복합성인',
#   '나에겐',
#   '살짝',
#   '번들거렸다',
#   '그래도',
#   '좁쌀이나',
#   '피부가',
#   '뒤집어지진',
#   '않았고',
#   '올',
#   '인원이라',
#   '보습감이나',
#   '기능이',
#   '떨어질지',
#   '알았는데',
#   '아니여서',
#   '너무',
#   '마음에',
#   '들었다',
#   '건성에게는',
#   '추천'],
#  ['겨울동안',
#   '쓰던',
#   '크림이',
#   '거의',
#   '떨어져',
#   '갈',
#   '쯤',
#   '좋은',
#   '기회가',
#   '되어서',
#   '상품',
#   '사용해',
#   '봤습니다.',
#   '제형은',
#   '흰색에',
#   '로션과',
#   '에센스',
#   '중간정도',
#   '묽기였어요.',
#   '올',
#   '인원답게',
#   '보습력이',
#   '좋아서',
#   '지복합성',
#   '피부에게',
#   '하나만',
#   '발라도',
#   '딱히',
#   '부족하진',
#   '않았습니다.',
#   '보습',
#   '제가',
#   '안맞거나',
#   '조금이라도',
#   '무거우면',
#   '좁쌀이',
#   '나는',
#   '편인데',
#   '그런',
#   '부작용',
#   '없이',
#   '깔끔하게',
#   '보습',
#   '잘',
#   '되는',
#   '제품',
#   '같네요.',
#   '올',
#   '인원',
#   '제품은',
#   '처음',
#   '사용해보는데',
#   '산뜻한',
#   '사용감에',
#   '준수한',
#   '보습력이',
#   '장점인',
#   '것',
#   '같아요',
#   '미백',
#   '효과와',
#   '주름',
#   '개선',
#   '효과가',
#   '있다는',
#   '데',
#   '한',
#   '통은',
#   '다',
#   '비워봐야',
#   '효과를',
#   '알',
#   '수',
#   '있을',
#   '것',
#   '같네요.',
#   '다',
#   '쓰고',
#   '나면',
#   '구매',
#   '의향',
#   '있습니다.'],
#  ['평가단',
#   '남자친구',
#   '줬습니다',
#   '남자친구는',
#   '아마',
#   '중성',
#   '귀찮아서',
#   '스킨로션',
#   '잘',
#   '안바름',
#   '냄새에',
#   '민감',
#   '먼저',
#   '런칭',
#   '기념으로',
#   '본품이랑',
#   '선',
#   '비비',
#   '스틱,',
#   '그루밍',
#   '키트가',
#   '같이',
#   '들어있었는데요,',
#   '본품의',
#   '경우',
#   '흰',
#   '색의',
#   '에',
#   '멀젼',
#   '제형으로',
#   '향은',
#   '거의',
#   '없었습니다.',
#   '다만',
#   '제가',
#   '지금',
#   '코감기라',
#   '냄새에',
#   '둔해져',
#   '있는',
#   '상태라',
#   '그렇게',
#   '느낀',
#   '걸',
#   '수도...',
#   '제형은',
#   '적당히',
#   '수분감이',
#   '있고',
#   '발랐을',
#   '때',
#   '끈적임이',
#   '크지',
#   '않아서',
#   '보통',
#   '끈적한',
#   '느낌',
#   '싫다고',
#   '스킨로션',
#   '안쓰는',
#   '남자들도',
#   '잘',
#   '쓸',
#   '것',
#   '같아요.',
#   '같이',
#   '들어있는',
#   '선비비의',
#   '경우',
#   '립스틱',
#   '보다',
#   '좀',
#   '큰',
#   '크기인데',
#   '커버력이나',
#   '발림성은',
#   '뛰어난',
#   '건',
#   '아니지만',
#   '대충',
#   '톤',
#   '정리',
#   '하는',
#   '용도로는',
#   '알',
#   '맞을',
#   '것',
#   '같아요.',
#   '다만',
#   '비비',
#   '안쓰는',
#   '남자들한텐',
#   '별로',
#   '일듯.',
#   '그루밍',
#   '키트의',
#   '경우',
#   '손발톱',
#   '깎이랑',
#   '귀이개',
#   '등이',
#   '들어있는',
#   '세트인데',
#   '특별한',
#   '점은',
#   '없지만',
#   '생필품이니만큼',
#   '잘',
#   '쓸',
#   '것',
#   '같아요'],
#  ['남성용이지만',
#   '여성이',
#   '사용해도',
#   '무난한',
#   '것',
#   '같아요.',
#   '저도',
#   '화장할',
#   '때',
#   '귀차니즘',
#   '발동할',
#   '때',
#   '많거든요.',
#   '매일',
#   '에센스에',
#   '크림',
#   '바르는',
#   '거',
#   '귀찮아서',
#   '써봤는데.',
#   '흡수도',
#   '빠르고',
#   '뭣보다도',
#   '끈적이지',
#   '않아서',
#   '좋네요.',
#   '겨울이지만',
#   '보습은',
#   '챙기면서',
#   '촉촉해서',
#   '좋아요',
#   '향도',
#   '무난하고',
#   '오히려',
#   '여성',
#   '제품보다',
#   '반했어요'],
#  ['여드름', '있는', '트러블', '피부에는', '안', '맞아요', '.'],
#  ['제가',
#   '광고',
#   '보고',
#   '혹',
#   '해서',
#   '사봤는데요..',
#   '다른',
#   '사람은',
#   '모르겠는데',
#   '피부',
#   '민감한',
#   '사람은',
#   '절대',
#   '쓰지',
#   '마세요',
#   '저는',
#   '어쩔',
#   '수',
#   '없이',
#   '일주일',
#   '동안',
#   '쓰게',
#   '됐는데..',
#   '얼굴이',
#   '빨게지고',
#   '따갑고..',
#   '민감한',
#   '피부',
#   '절대',
#   '절대',
#   '쓰지',
#   '마세요.'],
#  ['피부가',
#   '예민하고',
#   '기름기가',
#   '많은',
#   '20대',
#   '여성입니다.',
#   '남성',
#   '제품임에도',
#   '오빠꺼를',
#   '몰래',
#   '써봤는데',
#   '잘',
#   '맞아서',
#   '산뜻하고',
#   '촉촉하며',
#   '양도',
#   '많아서',
#   '3년째',
#   '쓰고',
#   '있네요',
#   '데헷'],
#  ['피부',
#   '건성인',
#   '아버지께서',
#   '한통',
#   '다',
#   '쓰시고',
#   '말씀하시는',
#   '아부지',
#   '후기',
#   '향이',
#   '좋다.',
#   '물을',
#   '바른',
#   '것처럼',
#   '묽어서',
#   '한참을',
#   '두드려야',
#   '한다.',
#   '바르면',
#   '촉촉하다.',
#   '근데',
#   '로션',
#   '바른',
#   '거',
#   '같지',
#   '않고',
#   '바디',
#   '로션',
#   '바른',
#   '거',
#   '같다.',
#   '미끌미끌하다.',
#   '물기가',
#   '많으니까',
#   '남은',
#   '양',
#   '목이랑',
#   '팔도',
#   '바르게',
#   '된다.',
#   '향이',
#   '좋다',
#   '해석',
#   '흡수력이',
#   '좋은',
#   '제품은',
#   '아니다.',
#   '향이',
#   '좋다.',
#   '촉촉한',
#   '제품이다.'],
#  ['아부지',
#   '선물',
#   '드렸는데',
#   '첨엔',
#   '스킨은',
#   '없냐고',
#   '왜',
#   '한가지냐고',
#   '하시더니',
#   '한통',
#   '다',
#   '쓰고',
#   '또',
#   '사달라',
#   '하셨어요',
#   '그런',
#   '말씀',
#   '한번도',
#   '없으셨던',
#   '분인데',
#   '편하고',
#   '적당하기론',
#   '짱인',
#   '것',
#   '같아요'],
#  ['남자친구', '선물', '해줬는데', '촉촉하다고', '좋아했어요'],
#  ['지성용을',
#   '물타입이라서',
#   '쓰기',
#   '불편하다고',
#   '하지만',
#   '중성용은',
#   '점성',
#   '있어서',
#   '하나',
#   '쓰기',
#   '좋고',
#   '얼굴',
#   '트는',
#   '것도',
#   '없어진다네요',
#   '아빠랑',
#   '동생이'],
#  ['아빠한테', '선물했는데', '이거', '하나만', '발라도', '될만큼', '촉촉하다고', '좋아하셨어요'],
#  ['남친이가',
#   '워낙',
#   '건성이라',
#   '얼굴이',
#   '터서',
#   '사줬는데',
#   '이거',
#   '바르고',
#   '이틀만에',
#   '각질튼살',
#   '동면',
#   '시킴.',
#   '세수한',
#   '후',
#   '대충',
#   '바르면',
#   '되니',
#   '편한지',
#   '잘씀.',
#   '이제',
#   '튼살은',
#   '빠염',
#   '만족만족'],
#  ['아빠',
#   '선물해',
#   '드렸는데',
#   '조금',
#   '끈적거리는',
#   '것',
#   '말고는',
#   '다',
#   '좋다고',
#   '하시네용',
#   '올',
#   '인원이라',
#   '편해서',
#   '더',
#   '좋은',
#   '것',
#   '같아요'],
#  ['올리브',
#   '영추천템',
#   '글로',
#   '우픽보고',
#   '남친',
#   '선물로',
#   '줬어요',
#   '남자친구가',
#   '완전',
#   '지성이',
#   '어서',
#   '지성용',
#   '올',
#   '인원으로',
#   '구매했어요',
#   '남자친구가',
#   '완전',
#   '좋다고',
#   '산뜻하다고',
#   '매우',
#   '좋아하네요',
#   '피부에',
#   '트러블',
#   '생기지도',
#   '않고',
#   '여러',
#   '개바를',
#   '필요없으니',
#   '딱',
#   '좋아요'],
#  ['처음엔',
#   '올',
#   '인원이라',
#   '반신',
#   '반의하며',
#   '썼었는데',
#   '트러블',
#   '1도',
#   '안나고',
#   '좋아요.',
#   '올',
#   '인원이라',
#   '편한데',
#   '트러블도',
#   '없고',
#   '끈적임도',
#   '없어서',
#   '이것만',
#   '씁니다.',
#   '이미',
#   '3개째',
#   '쓰고',
#   '잇고',
#   '한번에',
#   '대량',
#   '구매로',
#   '싸게',
#   '쟁여두면서',
#   '쓰는',
#   '중이에요'],
#  ['기름기',
#   '생각보다',
#   '너무',
#   '많습니다',
#   '복합성',
#   '피부에',
#   '피부가',
#   '예민한데',
#   '바르고',
#   '난',
#   '후',
#   '간지럽고',
#   '기름기가',
#   '너무',
#   '많아',
#   '좀',
#   '부담스러웠습니다',
#   '가벼운',
#   '트러블도',
#   '올라왔구요'],
#  ['가격에',
#   '비해서는',
#   '좀',
#   '별로',
#   '같네요',
#   '올',
#   '인원이라서',
#   '편하긴',
#   '하지만',
#   '저는',
#   '그냥',
#   '다른',
#   '거',
#   '여러',
#   '개',
#   '쓰는',
#   '게',
#   '나을',
#   '것',
#   '같아요'],
#  ['가격은',
#   '좀',
#   '나가는데에',
#   '비해서',
#   '좋진',
#   '않은',
#   '것',
#   '같아요.',
#   '남자친구가',
#   '사용했는데',
#   '올',
#   '인원이라도',
#   '그냥',
#   '다른',
#   '거',
#   '여러',
#   '개',
#   '쓰는',
#   '게',
#   '나을',
#   '것',
#   '같대용'],
#  ['이거',
#   '광고도',
#   '많이',
#   '하고,',
#   '올',
#   '인원이라',
#   '뭘',
#   '바르는',
#   '걸',
#   '귀찮아',
#   '하시는',
#   '아빠한테',
#   '딱',
#   '인거',
#   '같아서',
#   '선물',
#   '해드렸는데...',
#   '냄새가',
#   '너무',
#   '별로래요.',
#   '아빠가',
#   '원래',
#   '쓰시던',
#   '것들도',
#   '냄새가',
#   '막',
#   '순하고',
#   '그런게',
#   '아니라',
#   '일반적인',
#   '남성스킨',
#   '냄새였는데,',
#   '그것보다',
#   '별론가',
#   '봐요',
#   '잘',
#   '안쓰셔요'],
#  ['스킨치고는',
#   '점성이',
#   '있고',
#   '로션이라',
#   '하기에는',
#   '약간',
#   '묽고',
#   '잘',
#   '스며',
#   '들어요.',
#   '올',
#   '인원이라서',
#   '여러',
#   '제품',
#   '안',
#   '발라도',
#   '되서',
#   '아빠가',
#   '참',
#   '편하게',
#   '쓰셨습니다.',
#   '사요'],
#  ['남자친구가',
#   '몇',
#   '년',
#   '째',
#   '쓰는',
#   '스킨입니다.',
#   '여름에는',
#   '이것만',
#   '바르고',
#   '끝내더라구요.',
#   '제가',
#   '쓰기에는',
#   '이것만',
#   '가지고는',
#   '부족하지만',
#   '스킨과',
#   '로션',
#   '중간',
#   '정도의',
#   '느낌입니다.'],
#  ['18살',
#   '남동생이',
#   '있는데',
#   '귀찮은',
#   '거',
#   '안',
#   '좋아해서',
#   '몇',
#   '년째',
#   '이거',
#   '하나만',
#   '발랐어요',
#   '간',
#   '편하다고',
#   '좋아하네요',
#   '근데',
#   '요즘은',
#   '이거만',
#   '바르기엔',
#   '건조한가봐요',
#   '얼굴이',
#   '좀',
#   '땡기는',
#   '것',
#   '같다고',
#   '뭘',
#   '더',
#   '찾네요',
#   '..',
#   '그래서',
#   '라로슈',
#   '포제',
#   '시카플라스트밤까지',
#   '바르고',
#   '있어요',
#   '둘',
#   '다',
#   '동생이',
#   '꽤나',
#   '만족하는',
#   '제품입니다'],
#  ['일본',
#   '다녀올',
#   '때마다',
#   '두어',
#   '개씩',
#   '사오는데',
#   '무난',
#   '무난함',
#   '나쁜',
#   '것은',
#   '하나도',
#   '없지만',
#   '특별한',
#   '좋음은',
#   '없다는',
#   '점',
#   '양으로',
#   '치덕치덕하는',
#   '게',
#   '참',
#   '조아'],
#  ['제품명에서',
#   '느껴지듯이',
#   '스킨처럼',
#   '묽으면서',
#   '동시에',
#   '점성이',
#   '있는',
#   '제품이에요',
#   '콧물제형에',
#   '가까운',
#   '듯해요.',
#   '그래서',
#   '아주',
#   '약간',
#   '끈적이다는',
#   '느낌은',
#   '들지만',
#   '불편할',
#   '정도는',
#   '아니에요.',
#   '또',
#   '제형',
#   '덕분에',
#   '찹찹',
#   '피부에',
#   '잘',
#   '달라붙는',
#   '느낌이',
#   '들었어요',
#   '그리고',
#   '겨울보다는',
#   '여름에',
#   '사용하기',
#   '더',
#   '적합한',
#   '것',
#   '같아요',
#   '촉촉하기는',
#   '하지만',
#   '올',
#   '인원으로',
#   '이거',
#   '하나만',
#   '바르기에는',
#   '부족한',
#   '느낌이',
#   '들었습니다'],
#  ['피부에',
#   '별로',
#   '신경',
#   '안쓰시는',
#   '남자분들도',
#   '잘',
#   '쓸',
#   '수',
#   '있는',
#   '제품이에요.',
#   'All',
#   'in',
#   'one이라',
#   '간',
#   '편합니다',
#   '냄새도',
#   '나쁘지',
#   '않아요'],
#  ['아빠께', '사드렸는데', '촉촉하고', '바르기', '편하다고', '좋아하세요.', '재구매', '의사', '있습니다'],
#  ['신랑이',
#   '올',
#   '인원만',
#   '써서',
#   '잘',
#   '쓰고',
#   '있는데',
#   '겨울에는',
#   '다소',
#   '부족한',
#   '느낌이래요.',
#   '봄가을',
#   '얘만',
#   '쓰다가',
#   '겨울엔',
#   '크림',
#   '하나',
#   '추가해서',
#   '바릅니다.'],
#  ['장점',
#   '올',
#   '인원',
#   '제품이라',
#   '귀차니즘',
#   '남성',
#   '분들에게',
#   '좋네요',
#   '스킨',
#   '따로',
#   '필요',
#   '없이도',
#   '수분감이',
#   '적당히',
#   '느껴져요',
#   '단점',
#   '사용',
#   '후',
#   '약간의',
#   '속당',
#   '김이',
#   '있어요',
#   '건성이신',
#   '분들은',
#   '전체',
#   '도포',
#   '후',
#   '볼이나',
#   'T',
#   '존에',
#   '소량으로',
#   '한번씩',
#   '더',
#   '발라주시면',
#   '촉촉함이',
#   '오래갈',
#   '것',
#   '같아요',
#   '향',
#   '은은',
#   '한',
#   '향입니다',
#   '약냄새나',
#   '꽃냄새는',
#   '아니지만',
#   '살짝',
#   '시원한',
#   '느낌이',
#   '나는',
#   '향이네요',
#   '질감',
#   '묽어서',
#   '주르륵',
#   '흐르는',
#   '타입이네요',
#   '쫀쫀한',
#   '타입이',
#   '아니라',
#   '손억',
#   '덜어낸',
#   '후에는',
#   '바로',
#   '얼굴에',
#   '바르세요',
#   '유수분',
#   '밸런스',
#   '바르고',
#   '얼마',
#   '지나지',
#   '않아',
#   '약간',
#   '건조한',
#   '느낌이',
#   '드네요',
#   '봄ㆍ',
#   '여름에는',
#   '하나로',
#   '충분하지만',
#   '가을이나',
#   '겨울에는',
#   '질감이',
#   '묵직한',
#   '유분기',
#   '있는',
#   '크림을',
#   '함께',
#   '사용하는',
#   '게',
#   '좋을',
#   '것',
#   '같아요',
#   '당김이',
#   '있어서',
#   '제형이',
#   '쫀득한',
#   '수분크림도',
#   '구매했어요',
#   '지속력',
#   '바르고',
#   '피부',
#   '겉표면이',
#   '촉촉하긴',
#   '합니다',
#   '그치만',
#   '속에서',
#   '당김은',
#   '있고',
#   '약간',
#   '건조해요',
#   '한번',
#   '흡수',
#   '후',
#   '소량을',
#   '볼이나',
#   'T',
#   '존에',
#   '한번',
#   '더',
#   '바르면',
#   '촉촉함이',
#   '오래',
#   '지속될',
#   '것',
#   '같아요'],
#  ['남편이',
#   '우르',
#   '오스',
#   '노래를',
#   '불러서',
#   '사줬는데',
#   '아주',
#   '감탄을',
#   '하면서',
#   '쓰는',
#   '중',
#   '바디워시까지',
#   '우르',
#   '오스...',
#   '스킨로션',
#   '이것저것',
#   '바르기',
#   '귀찮아',
#   '하더니',
#   '매우',
#   '만족하면서',
#   '또',
#   '다시',
#   '구매예정'],
#  ['맨',
#   '처음',
#   '접했을',
#   '땐',
#   '빠르게',
#   '흡수되고',
#   '정말',
#   '좋았는데',
#   '시간이',
#   '지나면',
#   '지날수록',
#   '평범한',
#   '느낌임.',
#   '스킨로션',
#   '두가지를',
#   '하나로',
#   '합쳐서',
#   '좋았는데',
#   '겨울',
#   '철엔',
#   '로션을',
#   '사용해야',
#   '할',
#   '거',
#   '같음.',
#   '가격',
#   '대비',
#   '용량은',
#   '커서',
#   '오래',
#   '쓸',
#   '수',
#   '있음'],
#  ['무난하게', '쓰기', '좋은', '템'],
#  ['아버지',
#   '드렸는데',
#   '촉촉하고',
#   '좋다고',
#   '하시더라구요',
#   '무난',
#   '무난',
#   '트러블',
#   '안나고',
#   '적당히',
#   '좋은',
#   '템인',
#   '것',
#   '같아요'],
#  ['친구네', '놀러', '가서', '없는', '로션', '빌려써', '봤는데', '너무', '좋았습니당'],
#  ['평가',
#   '단에',
#   '당첨되어서',
#   '2주동안',
#   '써봤습니다.',
#   '제형은',
#   '흔히',
#   '쓰는',
#   '로션보다',
#   '조금',
#   '묽습니다.',
#   '향도',
#   '남자',
#   '화장품',
#   '특유의',
#   '시트러스계',
#   '향이',
#   '안나서',
#   '좋았습니다.',
#   '흡수가',
#   '빨라서',
#   '낮에',
#   '썬크림을',
#   '한',
#   '겹',
#   '더',
#   '올릴',
#   '때',
#   '쓰니까',
#   '빨리',
#   '스킨케어를',
#   '마칠',
#   '수',
#   '있어서',
#   '좋았습니다',
#   '다만',
#   '밤에는',
#   '조금',
#   '수분감이',
#   '부족해서',
#   '티존에만',
#   '바르고',
#   '다른',
#   '부위는',
#   '다른',
#   '제품을',
#   '사용했습니다',
#   '전체적으로',
#   '무난한',
#   '좋은',
#   '밸런스를',
#   '가진',
#   '제품이라',
#   '생각합니다'],
#  ['아버지가',
#   '써봤는데',
#   '되게',
#   '만족해',
#   '하시네요',
#   '일단',
#   '하나만',
#   '바르면',
#   '되니까',
#   '편리하고',
#   '산뜻하게',
#   '잘',
#   '발린데요',
#   '추천합니다'],
#  ['너무',
#   '그리지해요.',
#   '지성피부인데',
#   '너무',
#   '너무',
#   '오일리합니다.',
#   '향도',
#   '그닥',
#   '만족스럽지는',
#   '않아요.',
#   '가격은',
#   '좀',
#   '쎈',
#   '편인데',
#   '양은',
#   '꽤',
#   '있는',
#   '듯.',
#   '건성이면',
#   '모를까',
#   '지성피부에게는',
#   '절대',
#   '추천',
#   '안',
#   '합니다.',
#   '이거',
#   '쓰고',
#   '모공이',
#   '막혔는지',
#   '여드름도',
#   '더',
#   '나는',
#   '거',
#   '같고',
#   '홍조도',
#   '더',
#   '심해졌네요.',
#   '조만간',
#   '동생한테',
#   '넘길',
#   '제품.'],
#  ['아버지',
#   '드릴려고',
#   '신청햇는데',
#   '마침되서',
#   '써보시게',
#   '됬어요',
#   '아버지',
#   '피부는',
#   '제가',
#   '봤을',
#   '때',
#   '복합성인',
#   '것',
#   '같앗어요',
#   '향은',
#   '풀향',
#   '남자',
#   '화장품',
#   '스킨',
#   '향',
#   '알콜향',
#   '그런',
#   '냄새가',
#   '진하진',
#   '않지만',
#   '나요',
#   '묽은',
#   '로션',
#   '느낌에',
#   '발랏을',
#   '태',
#   '번들거리지',
#   '않고',
#   '흡수되서',
#   '끈적이는',
#   '느낌',
#   '자체를',
#   '별로',
#   '선호하지',
#   '않는',
#   '아버지께선',
#   '만족하셧으나',
#   '하나만',
#   '바르기엔',
#   '입가나',
#   '볼',
#   '주변이',
#   '좀',
#   '건조한',
#   '느낌이',
#   '드는',
#   '거',
#   '같아요.',
#   '그래서',
#   '크림으로',
#   '부족한',
#   '부분엔',
#   '덧발랐답니다',
#   '가격대비',
#   '그냥',
#   '소소해서',
#   '다',
#   '쓰면',
#   '재구매는',
#   '안하지',
#   '않을까',
#   '싶어요'],
#  ['평가단',
#   '선정되서',
#   '배송받자마자',
#   '남자친구에서',
#   '쓰라고',
#   '주고',
#   '오늘까지',
#   '딱',
#   '써본',
#   '느낌을',
#   '말해달라고',
#   '했어요',
#   '일단',
#   '남자친구는',
#   '향이',
#   '강한',
#   '제품을',
#   '정말',
#   '싫어하고,',
#   '로션을',
#   '발랐을',
#   '때',
#   '쫀득하게',
#   '남아있는',
#   '느낌을',
#   '싫어해요.',
#   '바르는',
#   '순간',
#   '바로',
#   '흡수되서',
#   '뽀송해져야',
#   '좋은',
#   '거라고',
#   '얘기하더라구요.',
#   '그래서',
#   '이거는',
#   '어땠냐니까',
#   '너무',
#   '너무',
#   '맘에',
#   '든대요',
#   '일단',
#   '올',
#   '인원이라',
#   '이거',
#   '하나만',
#   '바르면',
#   '되니',
#   '덜',
#   '귀찮고,',
#   '냄새도',
#   '그다지',
#   '강하지',
#   '않아서',
#   '너무',
#   '좋고,',
#   '무엇보다',
#   '바르자마자',
#   '바로',
#   '흡수되서',
#   '뽀송뽀송하지만',
#   '촉촉한',
#   '느낌이라는',
#   '게',
#   '너무',
#   '신기하고',
#   '좋대요',
#   '기초화장품에',
#   '3만원이라는',
#   '돈을',
#   '쓰는',
#   '걸',
#   '아까워',
#   '해서',
#   '이거',
#   '다',
#   '쓰고',
#   '난',
#   '뒤엔',
#   '사야할까',
#   '말아야',
#   '할까',
#   '고민하길래',
#   '다',
#   '쓰면',
#   '제가',
#   '한',
#   '번',
#   '사주려구요'],
#  ['많이', '손이', '가지는', '않나봐요', '생각보다', '건조해요'],
#  ['일본',
#   '여행',
#   '갔을',
#   '때',
#   '아빠께',
#   '선물',
#   '드렸던',
#   '제품이에요',
#   '당첨돼서',
#   '엄청',
#   '기뻤어요',
#   '꾸준히',
#   '사용하는',
#   '제품이라',
#   '더더욱',
#   '기뻤던',
#   '것',
#   '같아요',
#   '일단',
#   '올',
#   '인원이라는',
#   '점이',
#   '큰',
#   '장점이라고',
#   '생각해요',
#   '뭘',
#   '바르기',
#   '싫어하는',
#   '사람에겐',
#   '최고...',
#   '건조할까봐',
#   '걱정된다면',
#   '우르',
#   '오스에서',
#   '나온',
#   '중건성용',
#   '올',
#   '인원',
#   '바르면',
#   '돼용'],
#  ...]

# %%
model = FastText(size=100, window=5, min_count=5, sentences=splitted_texts)

# %%
from gensim.models  import FastText

# %%
import os
os.listdir('../code')
# Out:
# ['glowpick.py',
#  'main.py',
#  'model.bin',
#  'oliveyoung.py',
#  'reviews.py',
#  'test.py']

# %%
model.save('model.bin')

# %%
model_temp = FastText.load('model.bin')

# %%
model_temp.wv.most_similar('선물')
# Out:
# [('선물로도', 0.9998816251754761),
#  ('생일선물로', 0.9996999502182007),
#  ('물로', 0.9994733333587646),
#  ('선물해줬는데', 0.9994546175003052),
#  ('해드렸는데', 0.999070405960083),
#  ('사다줬는데', 0.9990596175193787),
#  ('아빠', 0.9989449381828308),
#  ('생신', 0.9989318251609802),
#  ('친구', 0.9989303350448608),
#  ('사드렸는데', 0.9987760186195374)]

# %%
model.wv.most_similar('선물')
# Out:
# [('선물로도', 0.9998816251754761),
#  ('생일선물로', 0.9996999502182007),
#  ('물로', 0.9994733333587646),
#  ('선물해줬는데', 0.9994546175003052),
#  ('해드렸는데', 0.999070405960083),
#  ('사다줬는데', 0.9990596175193787),
#  ('아빠', 0.9989449381828308),
#  ('생신', 0.9989318251609802),
#  ('친구', 0.9989303350448608),
#  ('사드렸는데', 0.9987760186195374)]

# %%
model.wv.most_similar('아빠')
# Out:
# [('생일선물로', 0.9993594884872437),
#  ('물로', 0.9992992877960205),
#  ('해드렸는데', 0.9992928504943848),
#  ('선물해줬는데', 0.9991929531097412),
#  ('남자친구가', 0.9991881847381592),
#  ('남자친구한테', 0.9991691708564758),
#  ('사다줬는데', 0.9991145133972168),
#  ('드렸는데', 0.9990746974945068),
#  ('친구', 0.9990213513374329),
#  ('사드렸는데', 0.9989744424819946)]

# %%
model.wv.most_similar('촉촉')
# Out:
# [('촉촉해', 0.9999401569366455),
#  ('촉촉히', 0.9998993873596191),
#  ('촉촉하면서', 0.9998915195465088),
#  ('촉촉하다는', 0.999889612197876),
#  ('촉촉한데', 0.9998733997344971),
#  ('촉촉함도', 0.9998700618743896),
#  ('촉촉함과', 0.9998592734336853),
#  ('흡수도', 0.9998571276664734),
#  ('촉촉함은', 0.9998496174812317),
#  ('촉촉해진', 0.9998490810394287)]

# %%
model.wv.most_similar('가성비')
# Out:
# [('남성분들에게는', 0.9999215602874756),
#  ('남성분들', 0.9999051690101624),
#  ('남성분들도', 0.9999027848243713),
#  ('남성분들은', 0.9998997449874878),
#  ('남성분들에게', 0.9998933672904968),
#  ('남성분들께', 0.9998932480812073),
#  ('남성분들을', 0.9998815059661865),
#  ('여름', 0.9998617768287659),
#  ('가성비는', 0.9998448491096497),
#  ('분들에게는', 0.9998434782028198)]

# %% [markdown]
# # 군집분석

# %%
from sklearn.cluster import KMeans
import matplotlib.pyplot as plt

from sklearn.manifold import TSNE

import seaborn as sns
from pyecharts import Scatter3D

from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()

# %%
sent_vec = np.zeros((len(splitted_texts), 100))
for i in range(len(splitted_texts)):
    sent_vec[i] = model.wv[splitted_texts[i]].sum(axis=0)

# %%
from scipy.spatial.distance import cosine

# %%
cosine(sent_vec[0], sent_vec[3])
# Out:
# 0.003672425017461123

# %%
sent_vec[[0]]
# Out:
# array([[ 3.0932734 , -2.35114551,  5.83721781,  3.78103638, -0.24044189,
#          6.41274166,  0.38254464, -5.6516161 , -0.97839987,  0.83765602,
#          4.7432766 ,  4.23942232,  2.29898214,  1.15867245, -1.49782109,
#         -0.01660961, -0.85812944,  0.34296197, -0.34782276,  2.7061801 ,
#          1.20345569, -1.91706407, -0.42440024, -3.02400875, -4.1600275 ,
#          0.02995355, -0.06352422, -0.53641456,  2.67076731, -5.2866478 ,
#         -3.3990798 , -1.73929787,  3.47195411, -0.73819357,  5.26400185,
#         -2.23734927,  5.32659388, -5.3778758 ,  2.70992494,  1.56451511,
#         -2.98991442, -4.14373541, -1.28319538,  3.73295021, -2.28126192,
#          0.2901479 , -0.3495484 ,  0.07504109,  1.67604482,  2.33400154,
#         -5.98371744,  5.68504095, -0.12401706, -0.01206111,  0.1294015 ,
#         -7.2796936 ,  2.49614978, -1.61590707,  2.19255924,  0.22357562,
#          0.68493223, -4.72330379, -2.40460348, -1.74064791,  1.55773795,
#         -1.05685127, -1.48446643,  1.70602369, -3.10104537,  1.2012012 ,
#          2.36308861, -0.5311259 , -1.17040396, -1.22400606,  1.08421504,
#         -3.97881079,  1.34406602, -1.41053641,  0.88519585, -2.25360942,
#          3.57478499,  1.25978899, -4.07791758,  3.90116811,  3.54291677,
#         -1.98491895,  4.69520473, -0.61197591, -1.61017919,  0.93034565,
#          4.02875376, -1.19834793,  2.67865276,  0.37689447,  3.08211732,
#         -4.01594734,  0.77104783,  3.17979646,  0.84217393,  1.85394681]])

# %%
scale_vec = scaler.fit_transform(sent_vec.T)
scale_vec = scale_vec.T

# %% [markdown]
# ## Join

# %%
reviews.rate.unique()
rate_dict = {
    'best':4,
    'good':3,
    'soso':2,
    'bad':1,
    'worst':0
}
reviews['rate_n'] = reviews.rate.map(rate_dict)

# %%
product_df = pd.read_csv('../dataset/glowpick_products.csv')
product_cat_df = product_df[['product_url','category']]

# %%
scale_vec_df = pd.DataFrame(scale_vec)
scale_vec_df.columns = [f'e{i}' for i in range(100)]

# %%
review_scale_df = pd.concat([reviews, scale_vec_df], axis=1)
review_cat_df = pd.merge(review_scale_df, product_cat_df, on='product_url', how='left')

# %%
cluster_df = pd.get_dummies(review_cat_df.iloc[:,9:])

# %% [markdown]
# ## K 정하기

# %%
inertia_lst = []
for i in range(1,10):
    km = KMeans(n_clusters=i, max_iter=300, random_state=223)
    km.fit(cluster_df)
    inertia_lst.append(km.inertia_)

# %%
plt.plot(range(1,10), inertia_lst)

# %% [markdown]
# ## K = 5 !!

# %%
km = KMeans(n_clusters=5, max_iter=300, random_state=223)
km.fit(cluster_df)
labels = km.predict(cluster_df)

# %%
embedding_df = cluster_df.copy()
embedding_df['labels'] = review_cat_df.labels

# %% [markdown]
# 군집을 4개로 했을때 크게 세가지로 묶이길래 5개로 묶어보니 크게 4개로 묶여서 이렇게함

# %%
embedding_df.labels.value_counts()
# Out:
# 1    2903
# 0    1466
# 2    1071
# 4     360
# 3       1
# Name: labels, dtype: int64

# %%
tsne1 = TSNE(n_components=2)
tsne_result1 = tsne1.fit_transform(embedding_df.iloc[:,:-1].values)

tsne_df1 = pd.DataFrame(tsne_result1)
tsne_df1['labels'] = labels
tsne_df1['labels'] = tsne_df1.labels.astype(str)
tsne_df1.columns = ['t1','t2','labels']

# %%
for i in range(5):
    sns.scatterplot(x='t1',y='t2',data=tsne_df1[tsne_df1.labels==str(i)], label=i)
plt.legend()

# %%
tsne2 = TSNE(n_components=3)
tsne_result2 = tsne2.fit_transform(embedding_df.iloc[:,:-1].values)

tsne_df2 = pd.DataFrame(tsne_result2)
tsne_df2['labels'] = labels
tsne_df2['labels'] = tsne_df2.labels.astype(str)
tsne_df2.columns = ['t2','t2','t3','labels']

# %%
scatter3D = Scatter3D(width=1200, height=700)
for i in range(5):
    temp = tsne_df2[tsne_df2.labels==str(i)].iloc[:,:-1].values
    scatter3D.add(f'class {i}',temp)

# %%
scatter3D
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts': '/nbextensions/echarts/echarts.min', 'echartsgl': '/nbextensions/echarts/echarts-gl.min'
#         }
#     });
# </script>
#     <div id="6ba217c844e44cf48f17f8643ed74802" style="width:1200px;height:700px;"></div>
#
#
# <script>
#     require(['echarts', 'echartsgl'], function(echarts) {
#
# var myChart_6ba217c844e44cf48f17f8643ed74802 = echarts.init(document.getElementById('6ba217c844e44cf48f17f8643ed74802'), 'light', {renderer: 'canvas'});
#
# var option_6ba217c844e44cf48f17f8643ed74802 = {
#     "title": [
#         {
#             "left": "auto",
#             "top": "auto",
#             "textStyle": {
#                 "fontSize": 18
#             },
#             "subtextStyle": {
#                 "fontSize": 12
#             }
#         }
#     ],
#     "toolbox": {
#         "show": true,
#         "orient": "vertical",
#         "left": "95%",
#         "top": "center",
#         "feature": {
#             "saveAsImage": {
#                 "show": true,
#                 "title": "\u4e0b\u8f7d\u56fe\u7247"
#             },
#             "restore": {
#                 "show": true
#             },
#             "dataView": {
#                 "show": true
#             }
#         }
#     },
#     "series_id": 7288176,
#     "tooltip": {
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "backgroundColor": "rgba(50,50,50,0.7)",
#         "borderColor": "#333",
#         "borderWidth": 0
#     },
#     "series": [
#         {
#             "type": "scatter3D",
#             "name": "class 0",
#             "data": [
#                 [
#                     -15.483535766601562,
#                     -4.098093509674072,
#                     18.956562042236328
#                 ],
#                 [
#                     -8.895133018493652,
#                     -9.065811157226562,
#                     14.784817695617676
#                 ],
#                 [
#                     -10.575784683227539,
#                     -7.31585693359375,
#                     18.077991485595703
#                 ],
#                 [
#                     -9.364298820495605,
#                     -8.336504936218262,
#                     15.143853187561035
#                 ],
#                 [
#                     -11.699529647827148,
#                     -7.872982978820801,
#                     16.23574447631836
#                 ],
#                 [
#                     -11.834729194641113,
#                     -7.59214973449707,
#                     16.806154251098633
#                 ],
#                 [
#                     -14.711763381958008,
#                     -6.182579517364502,
#                     13.614068984985352
#                 ],
#                 [
#                     -17.326744079589844,
#                     -2.067511796951294,
#                     16.038646697998047
#                 ],
#                 [
#                     -11.468254089355469,
#                     -6.31615686416626,
#                     18.48237419128418
#                 ],
#                 [
#                     -15.367105484008789,
#                     -6.555286884307861,
#                     13.795363426208496
#                 ],
#                 [
#                     -9.863755226135254,
#                     -8.06369400024414,
#                     15.031296730041504
#                 ],
#                 [
#                     -11.954487800598145,
#                     -7.551438808441162,
#                     16.962871551513672
#                 ],
#                 [
#                     -13.251029968261719,
#                     -4.120121479034424,
#                     19.097667694091797
#                 ],
#                 [
#                     -9.78124713897705,
#                     -7.699947834014893,
#                     16.326656341552734
#                 ],
#                 [
#                     -14.082194328308105,
#                     -5.888050079345703,
#                     18.656007766723633
#                 ],
#                 [
#                     -11.351825714111328,
#                     -6.520404815673828,
#                     18.234073638916016
#                 ],
#                 [
#                     -9.836400985717773,
#                     -8.084654808044434,
#                     15.112504005432129
#                 ],
#                 [
#                     -18.691837310791016,
#                     1.043803095817566,
#                     15.110069274902344
#                 ],
#                 [
#                     -8.765145301818848,
#                     -9.092947959899902,
#                     14.434381484985352
#                 ],
#                 [
#                     -15.749981880187988,
#                     -6.953476428985596,
#                     15.785560607910156
#                 ],
#                 [
#                     -14.768179893493652,
#                     -6.192117214202881,
#                     17.61905288696289
#                 ],
#                 [
#                     -14.276535987854004,
#                     -3.5021352767944336,
#                     18.690336227416992
#                 ],
#                 [
#                     -15.884419441223145,
#                     -5.367751598358154,
#                     18.141647338867188
#                 ],
#                 [
#                     -9.002900123596191,
#                     -8.859564781188965,
#                     14.717106819152832
#                 ],
#                 [
#                     -14.442667007446289,
#                     -7.369044303894043,
#                     17.19349479675293
#                 ],
#                 [
#                     -16.06689453125,
#                     -6.180852890014648,
#                     15.177165031433105
#                 ],
#                 [
#                     -10.39124584197998,
#                     -8.401213645935059,
#                     16.30255126953125
#                 ],
#                 [
#                     -14.578837394714355,
#                     -3.9353015422821045,
#                     18.806055068969727
#                 ],
#                 [
#                     -13.524643898010254,
#                     -6.55745267868042,
#                     18.47532081604004
#                 ],
#                 [
#                     -15.87957763671875,
#                     -6.586109638214111,
#                     15.67638111114502
#                 ],
#                 [
#                     -13.439247131347656,
#                     -5.701016426086426,
#                     18.705642700195312
#                 ],
#                 [
#                     -12.200995445251465,
#                     -5.113683700561523,
#                     18.699302673339844
#                 ],
#                 [
#                     -9.357215881347656,
#                     -6.1364827156066895,
#                     17.303199768066406
#                 ],
#                 [
#                     -11.212130546569824,
#                     -7.074772357940674,
#                     17.50522232055664
#                 ],
#                 [
#                     -12.11072063446045,
#                     -7.700715065002441,
#                     18.001689910888672
#                 ],
#                 [
#                     -15.378024101257324,
#                     -6.956881046295166,
#                     15.279733657836914
#                 ],
#                 [
#                     -15.802550315856934,
#                     -5.937451362609863,
#                     17.33582305908203
#                 ],
#                 [
#                     -15.287918090820312,
#                     -6.542959690093994,
#                     17.12470245361328
#                 ],
#                 [
#                     -15.163333892822266,
#                     -4.504635334014893,
#                     18.63025665283203
#                 ],
#                 [
#                     -11.091297149658203,
#                     -7.633707523345947,
#                     16.641082763671875
#                 ],
#                 [
#                     -14.062355041503906,

# %% [markdown]
# # 군집별 결과

# %%
kkma = Kkma()

temp = reviews.pre_content.apply(lambda x: ' '.join(kkma.nouns(x)))

temp_df = pd.DataFrame(temp)
temp_df['labels'] = labels
temp_df.head()

# %% [markdown]
# ## Cluster 1

# %%
label_0 = temp_df[temp_df.labels==0].pre_content.tolist()
label_0 = pd.Series(' '.join(label_0).split(' '))
label_0_df = pd.DataFrame(label_0, columns=['word'])
label_0_df['cnt'] = label_0.apply(lambda x: len(x))

label_0_df[label_0_df.cnt > 1].word.value_counts()[:30]

# %% [markdown]
# ## Cluster 2

# %%
label_1 = temp_df[temp_df.labels==1].pre_content.tolist()
label_1 = pd.Series(' '.join(label_1).split(' '))
label_1_df = pd.DataFrame(label_1, columns=['word'])
label_1_df['cnt'] = label_1.apply(lambda x: len(x))

label_1_df[label_1_df.cnt > 1].word.value_counts()[:30]

# %% [markdown]
# ## Cluster 3

# %%
label_2 = temp_df[temp_df.labels==2].pre_content.tolist()
label_2 = pd.Series(' '.join(label_2).split(' '))
label_2_df = pd.DataFrame(label_2, columns=['word'])
label_2_df['cnt'] = label_2.apply(lambda x: len(x))

label_2_df[label_2_df.cnt > 1].word.value_counts()[:30]

# %% [markdown]
# ## Cluster 4

# %%
label_3 = temp_df[temp_df.labels==3].pre_content.tolist()
label_3 = pd.Series(' '.join(label_3).split(' '))
label_3_df = pd.DataFrame(label_3, columns=['word'])
label_3_df['cnt'] = label_3.apply(lambda x: len(x))

label_3_df[label_3_df.cnt > 1].word.value_counts()[:30]

# %% [markdown]
# ## Cluster 5

# %%
label_4 = temp_df[temp_df.labels==4].pre_content.tolist()
label_4 = pd.Series(' '.join(label_4).split(' '))
label_4_df = pd.DataFrame(label_4, columns=['word'])
label_4_df['cnt'] = label_4.apply(lambda x: len(x))

label_4_df[label_4_df.cnt > 1].word.value_counts()[:30]
